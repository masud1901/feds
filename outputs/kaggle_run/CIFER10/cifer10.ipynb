# %% [markdown]
# # FEDS v10 - Unified Architecture + Server-Variance-Guided Sparsification
#
# ## Key changes from v9
#
# **1. UnifiedNet (~226K params) replaces dataset-specific models**
#
#     MNIST:   UnifiedNet(in_channels=1, num_classes=10)
#     CIFAR10: UnifiedNet(in_channels=3, num_classes=10)
#     Speech:  SpeechNet (1D audio, kept separate)
#
#     3-block CNN with BatchNorm + AdaptiveAvgPool -> same FC regardless of input size.
#     Same model capacity across datasets = fair comparison, no confounding.
#
# **2. Rank-based normalisation replaces max-normalisation**
#
#     p = rank(var) / (d-1)   maps to [0,1] uniformly
#     Prevents priority collapse when variance is highly concentrated
#     (was the root cause of CIFAR-10 failure in v8/v9)
#
# ## Algorithm summary
#
#     CLIENT: phi_j = |delta_j + e_j| * p_j[t-1]  -> top-K by phi
#             error e_j[t] = unselected residual (standard error feedback)
#     SERVER: p[t] = rank_normalise(Var_i(delta_i_j))  -> broadcast with w[t+1]
#
# ## Theoretical contribution vs DSFL
#
#     DSFL:  two-stage mask (LSS x TopK), CKA overhead, no convergence proof
#     FEDS:  single-stage selection, zero overhead, tighter error bound,
#            follows Karimireddy et al. 2019 error-feedback convergence
#
# **Run:** Cell 1 -> 2 -> 3 -> 4 -> 5 (smoke) -> 6 (full)

# %%
import subprocess, sys, os
IS_COLAB  = 'google.colab' in sys.modules or os.path.exists('/content')
IS_KAGGLE = os.path.exists('/kaggle')
PLATFORM  = 'colab' if IS_COLAB else ('kaggle' if IS_KAGGLE else 'local')
print(f'Platform: {PLATFORM}')
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                'torch', 'torchvision', 'torchaudio',
                'numpy', 'matplotlib', 'scipy', 'pandas'])
import torch, numpy as np
print(f'PyTorch : {torch.__version__}')
if torch.cuda.is_available():
    print(f'GPU     : {torch.cuda.get_device_name(0)}')
    print(f'VRAM    : {torch.cuda.get_device_properties(0).total_memory/1e9:.1f} GB')
    # Warm up CUDA context
    _ = torch.zeros(1).cuda()
    torch.cuda.synchronize()
    print('CUDA context warmed up ✅')
else:
    print('⚠️  No GPU — will run on CPU (slow)')
print('✅ ready')
# Out:
# Platform: colab
# PyTorch : 2.9.0+cu126
# GPU     : Tesla T4
# VRAM    : 15.6 GB
# CUDA context warmed up ✅
# ✅ ready

# %%
# Options: MNIST | CIFAR10 | Speech
DATASET      = 'CIFAR10'

NUM_ROUNDS   = 200
NUM_CLIENTS  = 10
LOCAL_EPOCHS = 1
BATCH_SIZE   = 256

LR           = 0.01
LR_DECAY     = 0.99
LR_MIN       = 1e-4
SEED         = 42

ALPHA_COMM   = 10
GAMMA_COMM   = 10
COMP_WARMUP  = 20
CKA_BATCHES  = 2    # DSFL baseline only
FEDS_EMA     = 0.7  # EMA smoothing for priority vector
EMA_SMOOTH   = 10   # figure smoothing window

RESULTS_DIR  = f'results_{DATASET}'
import torch, os, numpy as np
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
for sub in ['figures','tables','data']: os.makedirs(f'{RESULTS_DIR}/{sub}',exist_ok=True)
if DATASET == 'Speech': LOCAL_EPOCHS = 5
if DEVICE == 'cuda' and DATASET != 'Speech': torch.backends.cudnn.benchmark = True

print(f'Dataset : {DATASET}  Rounds: {NUM_ROUNDS}  Clients: {NUM_CLIENTS}')
print(f'Batch   : {BATCH_SIZE}  LR: {LR}  decay={LR_DECAY}')
print(f'alpha={ALPHA_COMM}  gamma={GAMMA_COMM}  warmup={COMP_WARMUP}')
print(f'FEDS_EMA={FEDS_EMA}  CKA_BATCHES={CKA_BATCHES} (DSFL only)')
print(f'Device  : {DEVICE}')
# Out:
# Dataset : CIFAR10  Rounds: 200  Clients: 10
# Batch   : 256  LR: 0.01  decay=0.99
# alpha=10  gamma=10  warmup=20
# FEDS_EMA=0.7  CKA_BATCHES=2 (DSFL only)
# Device  : cuda

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision.datasets import MNIST, CIFAR10
from torch.utils.data import DataLoader, Dataset
import numpy as np
import copy, json, time, random, pickle, os
from collections import OrderedDict
from scipy.stats import truncnorm


# ═══════════════════════════════════════════════════════
# REPRODUCIBILITY
# ═══════════════════════════════════════════════════════
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    # NOTE: benchmark=True (set in config) is faster but slightly non-deterministic
    # Set deterministic=True here only if exact reproducibility is required
    torch.backends.cudnn.deterministic = False


# ═══════════════════════════════════════════════════════
# MODELS — exact architectures from DSFL paper
# ═══════════════════════════════════════════════════════
class UnifiedNet(nn.Module):
    """
    Unified CNN for MNIST and CIFAR-10.
    ~226K parameters regardless of dataset.
    Handles 1-channel (MNIST) and 3-channel (CIFAR-10) input.
    AdaptiveAvgPool ensures same FC input size across spatial dims.

    MNIST : 1x28x28 -> ... -> 512 -> 256 -> 10
    CIFAR : 3x32x32 -> ... -> 512 -> 256 -> 10

    Approx param count:
      conv1: C_in*32*3*3  (288 or 864)
      conv2: 32*64*3*3    = 18,432
      conv3: 64*128*3*3   = 73,728
      BN layers:          ~ 384
      fc1: 512*256        = 131,072
      fc2: 256*num_cls    = 2,560 (CIFAR-10) or 2,560 (MNIST)
      Total               ~ 226K
    """
    def __init__(self, in_channels=3, num_classes=10):
        super().__init__()
        self.features = nn.Sequential(
            # Block 1
            nn.Conv2d(in_channels, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            # Block 2
            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            # Block 3
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d(2),   # -> [B, 128, 2, 2] = 512
        )
        self.classifier = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, num_classes),
        )
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)


class SpeechNet(nn.Module):
    """~27,303 params — DSFL ref [13]"""
    def __init__(self, n_input=1, n_output=35, stride=16, n_channel=32):
        super().__init__()
        self.conv1 = nn.Conv1d(n_input, n_channel, 80, stride=stride)
        self.bn1   = nn.BatchNorm1d(n_channel)
        self.pool1 = nn.MaxPool1d(4)
        self.conv2 = nn.Conv1d(n_channel, n_channel, 3)
        self.bn2   = nn.BatchNorm1d(n_channel)
        self.pool2 = nn.MaxPool1d(4)
        self.conv3 = nn.Conv1d(n_channel, 2*n_channel, 3)
        self.bn3   = nn.BatchNorm1d(2*n_channel)
        self.pool3 = nn.MaxPool1d(4)
        self.conv4 = nn.Conv1d(2*n_channel, 2*n_channel, 3)
        self.bn4   = nn.BatchNorm1d(2*n_channel)
        self.pool4 = nn.MaxPool1d(4)
        self.fc1   = nn.Linear(2*n_channel, n_output)
    def forward(self, x):
        x = self.pool1(F.relu(self.bn1(self.conv1(x))))
        x = self.pool2(F.relu(self.bn2(self.conv2(x))))
        x = self.pool3(F.relu(self.bn3(self.conv3(x))))
        x = self.pool4(F.relu(self.bn4(self.conv4(x))))
        x = F.avg_pool1d(x, x.shape[-1]).squeeze(-1)
        return self.fc1(x)




def get_model(dataset):
    if dataset == 'MNIST':   return UnifiedNet(in_channels=1, num_classes=10)
    if dataset == 'CIFAR10': return UnifiedNet(in_channels=3, num_classes=10)
    if dataset == 'Speech':  return SpeechNet()
    raise ValueError(dataset)



# ═══════════════════════════════════════════════════════
# DATA — label-pair non-IID (DSFL paper Section V)
# ═══════════════════════════════════════════════════════
class IndexedDataset(Dataset):
    def __init__(self, base, idx):
        self.base = base
        self.idx  = np.asarray(idx)
    def __len__(self):  return len(self.idx)
    def __getitem__(self, i): return self.base[int(self.idx[i])]


def label_pair_partition(dataset, num_clients, num_classes, rng):
    if hasattr(dataset, 'targets'):
        targets = np.array(dataset.targets)
    elif hasattr(dataset, 'labels'):
        targets = np.array(dataset.labels)
    else:
        targets = np.array([dataset[i][1] for i in range(len(dataset))])
    parts = []
    for cid in range(num_clients):
        la  = cid % num_classes
        lb  = (cid + 1) % num_classes
        idx = np.where((targets == la) | (targets == lb))[0].copy()
        rng.shuffle(idx)
        parts.append(idx)
    return parts



# ============================================================
# GPU TENSOR CACHE  —  THE REAL FIX FOR 26s/round
#
# Root cause: MNISTNet is 582K params. Each batch takes ~0.3ms
# GPU compute. But DataLoader transfers take ~100ms/batch.
# 230 batches/round x 100ms = 23s WASTED on CPU->GPU transfers.
#
# Fix: load entire dataset into GPU RAM ONCE before training.
# MNIST:  10 clients x ~6k x (1x28x28) x fp32 = 188MB (of 15GB)
# CIFAR10:10 clients x ~5k x (3x32x32) x fp32 = 565MB (of 15GB)
# Speech: variable-length, falls back to DataLoader
# ============================================================
class GPUTensorLoader:
    """Pre-batched GPU tensors. Zero CPU-GPU transfer during training."""
    def __init__(self, X_gpu, Y_gpu, batch_size, seed=0):
        self.X=X_gpu; self.Y=Y_gpu; self.bs=batch_size
        self.gen=torch.Generator(device=X_gpu.device); self.gen.manual_seed(seed)
        self.n=X_gpu.shape[0]
    def __iter__(self):
        idx=torch.randperm(self.n, device=self.X.device, generator=self.gen)
        for s in range(0, self.n-self.bs+1, self.bs):
            b=idx[s:s+self.bs]; yield self.X[b], self.Y[b]
    def __len__(self): return self.n // self.bs


def build_loaders(dataset_name, num_clients, seed, batch_size,
                  partition_dir='partitions', device='cpu'):
    os.makedirs(partition_dir, exist_ok=True)
    cache = f'{partition_dir}/{dataset_name}_nc{num_clients}_seed{seed}.pkl'
    rng   = np.random.default_rng(seed)

    if dataset_name == 'MNIST':
        tf = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.1307,),(0.3081,))])
        train_ds=MNIST('/tmp/data',train=True, download=True,transform=tf)
        test_ds =MNIST('/tmp/data',train=False,download=True,transform=tf)
        num_classes=10

    elif dataset_name == 'CIFAR10':
        tf = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.5,)*3,(0.5,)*3)])
        train_ds=CIFAR10('/tmp/data',train=True, download=True,transform=tf)
        test_ds =CIFAR10('/tmp/data',train=False,download=True,transform=tf)
        num_classes=10

    else:  # Speech  variable-length, use standard DataLoader
        import torchaudio
        from torchaudio.datasets import SPEECHCOMMANDS
        root=os.path.join(partition_dir,'speech'); os.makedirs(root,exist_ok=True)
        tr_raw=SPEECHCOMMANDS(root,download=True,subset='training')
        te_raw=SPEECHCOMMANDS(root,download=True,subset='testing')
        labels=sorted(set(d[2] for d in tr_raw)); num_classes=len(labels)
        rs=torchaudio.transforms.Resample(16000,8000)
        class SW(Dataset):
            def __init__(self,raw,labs,r): self.raw=raw;self.labs=labs;self.r=r
            def __len__(self): return len(self.raw)
            def __getitem__(self,i):
                wav,_,lab,*_=self.raw[i]; w=self.r(wav)
                if w.dim()==1: w=w.unsqueeze(0)
                return w,self.labs.index(lab)
        train_ds=SW(tr_raw,labels,rs); test_ds=SW(te_raw,labels,rs)
        def collate_fn(batch):
            xs=torch.nn.utils.rnn.pad_sequence(
                [b[0].squeeze(0) for b in batch],batch_first=True).unsqueeze(1)
            return xs,torch.tensor([b[1] for b in batch],dtype=torch.long)
        kw=dict(batch_size=batch_size,shuffle=True,drop_last=True,
                num_workers=2,pin_memory=False,persistent_workers=True,collate_fn=collate_fn)
        if os.path.exists(cache):
            with open(cache,'rb') as f: tr_parts=pickle.load(f)
        else:
            tr_parts=label_pair_partition(train_ds,num_clients,num_classes,rng)
            with open(cache,'wb') as f: pickle.dump(tr_parts,f)
        return [DataLoader(IndexedDataset(train_ds,idx),**kw) for idx in tr_parts], \
               DataLoader(test_ds,batch_size=batch_size*2,shuffle=False,
                          num_workers=2,collate_fn=collate_fn)

    # Partition
    if os.path.exists(cache):
        print('  Loaded partition cache')
        with open(cache,'rb') as f: tr_parts=pickle.load(f)
    else:
        print('  Creating label-pair partition...')
        tr_parts=label_pair_partition(train_ds,num_clients,num_classes,rng)
        tgts=np.array(train_ds.targets)
        for cid,idx in enumerate(tr_parts):
            labs,_=np.unique(tgts[idx],return_counts=True)
            print(f'  Client {cid}: labels={labs.tolist()}  n={len(idx)}')
        with open(cache,'wb') as f: pickle.dump(tr_parts,f)

    # Preload FULL dataset to GPU once
    print('  Preloading dataset to GPU...')
    loader_tmp=DataLoader(train_ds,batch_size=4096,shuffle=False,
                           num_workers=2,pin_memory=(device=='cuda'))
    Xs,Ys=[],[]
    for xb,yb in loader_tmp: Xs.append(xb); Ys.append(yb)
    all_X=torch.cat(Xs).to(device)
    all_Y=torch.cat(Ys).to(device)

    train_loaders=[
        GPUTensorLoader(all_X[idx], all_Y[idx], batch_size, seed=seed+cid)
        for cid,idx in enumerate(tr_parts)
    ]

    te_tmp=DataLoader(test_ds,batch_size=4096,shuffle=False,
                       num_workers=2,pin_memory=(device=='cuda'))
    teX,teY=[],[]
    for xb,yb in te_tmp: teX.append(xb); teY.append(yb)
    te_X=torch.cat(teX).to(device); te_Y=torch.cat(teY).to(device)
    test_loader=GPUTensorLoader(te_X, te_Y, batch_size*2, seed=0)

    if device=='cuda':
        print(f'  GPU memory used: {torch.cuda.memory_allocated()/1e6:.0f} MB')
    print(f'  Train: {num_clients} clients  batch={batch_size}  '
          f'~{sum(len(idx) for idx in tr_parts)//num_clients} samples/client')
    print(f'  Test : {len(te_Y)} samples on {device}')
    return train_loaders, test_loader


# ═══════════════════════════════════════════════════════
# LOCAL TRAIN / EVAL
# ═══════════════════════════════════════════════════════
def local_train(model, loader, epochs, lr, device):
    model.train()
    opt  = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=1e-4)
    crit = nn.CrossEntropyLoss()
    total, n = 0.0, 0
    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            opt.zero_grad(set_to_none=True)   # v5: set_to_none=True saves a memset
            loss = crit(model(x), y)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            opt.step()
            total += loss.item(); n += 1
    return total / max(n, 1)


def evaluate(model, loader, device):
    model.eval()
    crit = nn.CrossEntropyLoss()
    tl, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            out      = model(x)
            tl      += crit(out, y).item() * y.size(0)
            correct += (out.argmax(1) == y).sum().item()
            total   += y.size(0)
    return tl / max(total, 1), correct / max(total, 1)


# ═══════════════════════════════════════════════════════
# PARAMETER UTILITIES — v5: stay on GPU, avoid CPU round-trips
# ═══════════════════════════════════════════════════════
def split_state_dict(model):
    fp, ob = OrderedDict(), OrderedDict()
    for k, v in model.state_dict().items():
        (fp if v.is_floating_point() else ob)[k] = v
    return fp, ob

def get_float_shapes(model):
    fp, _ = split_state_dict(model)
    return [tuple(v.shape) for v in fp.values()]

def get_float_param_names(model):
    fp, _ = split_state_dict(model)
    return list(fp.keys())

def get_layer_map(model):
    fp, _ = split_state_dict(model)
    layer_map = []
    for layer_idx, (_, v) in enumerate(fp.items()):
        layer_map.extend([layer_idx] * v.numel())
    return np.array(layer_map, dtype=np.int32)

# v5: return GPU tensors directly — no .cpu().numpy()
def get_float_params_gpu(model, device):
    fp, _ = split_state_dict(model)
    return torch.cat([v.detach().to(device, non_blocking=True).float().flatten()
                      for v in fp.values()])  # → 1D tensor on device

def set_float_params_gpu(model, flat_gpu, shapes):
    """Set model float params from a 1D GPU tensor — no CPU round-trip."""
    fp, ob = split_state_dict(model)
    sd = OrderedDict()
    offset = 0
    for (k, _), s in zip(fp.items(), shapes):
        n = int(np.prod(s))
        sd[k] = flat_gpu[offset:offset+n].reshape(s)
        offset += n
    for k, v in ob.items():
        sd[k] = v.clone()
    model.load_state_dict(sd, strict=True)

# Keep numpy helpers for methods that still need numpy (topk, lss masks)
def params_to_flat(pl):
    return np.concatenate([p.flatten().astype(np.float32) for p in pl])

def flat_to_params(flat, shapes):
    out, i = [], 0
    for s in shapes:
        n = int(np.prod(s))
        out.append(flat[i:i+n].reshape(s).astype(np.float32))
        i += n
    return out

def get_float_params(model):
    fp, _ = split_state_dict(model)
    return [v.detach().cpu().float().numpy().copy() for v in fp.values()]

def set_float_params(model, params_list):
    fp, ob = split_state_dict(model)
    sd = OrderedDict()
    for (k, _), arr in zip(fp.items(), params_list):
        sd[k] = torch.tensor(arr, dtype=torch.float32)
    for k, v in ob.items():
        sd[k] = v.clone()
    model.load_state_dict(sd, strict=True)


# ═══════════════════════════════════════════════════════
# CKA SIMILARITY — v5: fully on GPU with PyTorch
# Linear CKA: HSIC(X,X)^{1/2} * HSIC(Y,Y)^{1/2} denominator
# ═══════════════════════════════════════════════════════
def linear_cka_gpu(X, Y):
    """X, Y: [n_samples, n_features] tensors on GPU. Returns scalar float."""
    X = X - X.mean(0, keepdim=True)
    Y = Y - Y.mean(0, keepdim=True)
    # Using Frobenius norm of X^T Y
    XtY = X.T @ Y
    XtX = X.T @ X
    YtY = Y.T @ Y
    top = torch.norm(XtY, 'fro') ** 2
    bot = torch.norm(XtX, 'fro') * torch.norm(YtY, 'fro')
    return (top / bot).item() if bot.item() > 1e-12 else 0.0


def compute_per_layer_cka(client_model, global_model, probe_loader,
                           device, max_batches=2):
    """v5: activations collected on GPU, CKA computed on GPU."""
    client_model.eval(); global_model.eval()
    fp_names    = get_float_param_names(client_model)
    mod_to_pidx = {}
    for pidx, pname in enumerate(fp_names):
        mname = pname.rsplit('.', 1)[0]
        if mname not in mod_to_pidx:
            mod_to_pidx[mname] = pidx

    c_acts, g_acts = {}, {}

    def hook_fn(store, key):
        def h(mod, inp, out):
            # Stay on GPU — reshape but don't move to CPU
            a = out.detach().float().reshape(out.size(0), -1)
            store[key] = torch.cat([store[key], a], dim=0) if key in store else a
        return h

    hooks  = []
    c_mods = dict(client_model.named_modules())
    g_mods = dict(global_model.named_modules())
    for mname, pidx in mod_to_pidx.items():
        if mname in c_mods and mname in g_mods:
            hooks.append(c_mods[mname].register_forward_hook(hook_fn(c_acts, pidx)))
            hooks.append(g_mods[mname].register_forward_hook(hook_fn(g_acts, pidx)))

    with torch.no_grad():
        for i, (x, _) in enumerate(probe_loader):
            if i >= max_batches: break
            x = x.to(device, non_blocking=True)
            client_model(x); global_model(x)

    for h in hooks: h.remove()

    result = {}
    for idx in c_acts:
        if idx in g_acts:
            result[idx] = linear_cka_gpu(c_acts[idx], g_acts[idx])
    return result


# ═══════════════════════════════════════════════════════
# K SAMPLING — DSFL eq. 8
# ═══════════════════════════════════════════════════════
def sample_k_list(d, n, alpha, gamma, rng):
    mu, sigma = d/alpha, d/gamma
    a_s, b_s  = (0-mu)/sigma, (d-mu)/sigma
    s = truncnorm.rvs(a_s, b_s, loc=mu, scale=sigma, size=n, random_state=rng)
    return [max(1, min(int(v), d)) for v in s]


# ═══════════════════════════════════════════════════════
# TOP-K SPARSIFICATION
# ═══════════════════════════════════════════════════════
def topk_sparse(delta, k):
    k    = max(1, min(int(k), len(delta)))
    mask = np.zeros_like(delta)
    mask[np.argpartition(np.abs(delta), -k)[-k:]] = 1.0
    return delta * mask, delta * (1.0 - mask)


# ═══════════════════════════════════════════════════════
# METHOD 1: FedAvg
# ═══════════════════════════════════════════════════════
def fedavg_aggregate(c_params):
    avg = [np.zeros_like(p) for p in c_params[0]]
    for ps in c_params:
        for i, p in enumerate(ps): avg[i] += p / len(c_params)
    return avg



# Server-side variance priority  (FEDS v9)
def compute_server_priority(c_deltas, d, ema_alpha=0.7, prev_priority=None):
    """
    Compute per-parameter priority from inter-client variance.
    Called SERVER-SIDE after receiving all client deltas.
    Cost: one pass over N*d floats - FREE during aggregation.

    sigma2_j = Var_i(delta_i_j)
    High variance -> clients disagree -> transmit next round
    Low variance  -> clients agree    -> safe to compress
    """
    stack = np.stack(c_deltas, axis=0)        # [N, d]
    mean  = stack.mean(axis=0)                # [d]
    var   = ((stack - mean)**2).mean(axis=0)  # [d]

    # Rank-based normalisation: maps to [0,1] uniformly
    # Avoids collapse when variance is highly concentrated
    # (e.g. small non-IID models where a few params dominate)
    ranks = np.argsort(np.argsort(var)).astype(np.float32)  # [0..d-1]
    p = ranks / max(d - 1, 1)                               # [0,1]

    # EMA smoothing across rounds for stability
    if prev_priority is not None:
        p = ema_alpha * p + (1.0 - ema_alpha) * prev_priority
    return p.astype(np.float32)


def priority_sparse(delta, priority, k):
    """
    FEDS client-side selection.
    phi_j = |delta_j| * p_j   -> top-K by phi
    Round 1: p=ones -> reduces to standard Top-K.
    """
    k = max(1, min(int(k), len(delta)))
    phi  = np.abs(delta) * priority
    mask = np.zeros_like(delta)
    mask[np.argpartition(phi, -k)[-k:]] = 1.0
    return delta * mask, delta * (1.0 - mask)

# ═══════════════════════════════════════════════════════
# METHOD 2: Fixed Top-K
# ═══════════════════════════════════════════════════════
def fixed_topk_aggregate(c_params, gflat, errors, shapes, k_fixed):
    sds, errs = [], []
    for i, ps in enumerate(c_params):
        delta = (params_to_flat(ps) - gflat) + errors[i]
        sd, lo = topk_sparse(delta, k_fixed)
        sds.append(sd); errs.append(lo)
    return flat_to_params(gflat + np.mean(sds, axis=0), shapes), \
           gflat + np.mean(sds, axis=0), errs


# ═══════════════════════════════════════════════════════
# LSS MASK — DSFL eq. 2-3
# ═══════════════════════════════════════════════════════
def lss_mask(delta, cka_scores, layer_map, rng):
    mask = np.ones(len(delta), dtype=np.float32)
    for lidx, sim in cka_scores.items():
        pos = np.where(layer_map == lidx)[0]
        if len(pos) == 0: continue
        keep_p = float(np.clip(1.0 - sim, 0.05, 1.0))
        mask[pos] = (rng.random(len(pos)) < keep_p).astype(np.float32)
    return delta * mask



# ═══════════════════════════════════════════════════════
# FEDS UNIFIED IMPORTANCE SPARSIFICATION  (v7)
#
# phi_j = |delta_j| * (1 - CKA[layer(j)])
#
# Single-stage deterministic selection. Reduces to:
#   standard Top-K  when all CKA = 0
#   layer-only sel. when all |delta_j| equal
# Provably minimises expected reconstruction error at server.
# ═══════════════════════════════════════════════════════
def layer_norm_sparse(delta, layer_map, k):
    """
    FEDS v8 - Layer-Normalised Importance Sparsification.

    Importance score:
        phi_j = |delta_j| * importance_weight[layer(j)]

    where importance_weight[l] = ||delta_l||_2 / sqrt(n_l)
                                  normalised across layers to [0,1]

    This is the per-parameter RMS change in layer l.
    Layers that changed a lot get high weight - transmit more from them.
    Layers that barely moved get low weight - they are already close to
    global model, fewer parameters needed.

    Key advantages over CKA:
      - Zero extra cost: delta is already computed before sparsification
      - No forward passes, no probe data, no matrix operations
      - Robust to small models and few layers (CKA is noisy there)
      - Self-consistent: uses the update signal to weight the update signal
    """
    k = max(1, min(int(k), len(delta)))

    # Compute per-layer RMS update magnitude
    unique_layers = np.unique(layer_map)
    layer_rms = np.zeros(unique_layers.max() + 1, dtype=np.float32)
    for l in unique_layers:
        pos = np.where(layer_map == l)[0]
        if len(pos) == 0: continue
        layer_rms[l] = np.sqrt(np.mean(delta[pos] ** 2))  # RMS of delta in layer l

    # Normalise to [0, 1] so weights are comparable across layers
    max_rms = layer_rms.max()
    if max_rms > 1e-12:
        layer_rms = layer_rms / max_rms
    # Floor at 0.1 so even stable layers can contribute
    layer_rms = np.clip(layer_rms, 0.1, 1.0)

    # Per-parameter importance weight
    layer_weight = layer_rms[layer_map]

    # Unified score: magnitude * layer importance
    phi = np.abs(delta) * layer_weight

    # Top-K selection by phi
    mask = np.zeros_like(delta)
    mask[np.argpartition(phi, -k)[-k:]] = 1.0
    return delta * mask, delta * (1.0 - mask)

# ═══════════════════════════════════════════════════════
# METHOD 3: DSFL
# ═══════════════════════════════════════════════════════
def dsfl_aggregate(c_params, gflat, errors, shapes, layer_map,
                   k_list, d, client_models, gref,
                   train_loaders, device, rng,
                   round_idx, comp_warmup, cka_batches=2):
    warmup_frac = min(1.0, round_idx / max(comp_warmup, 1))
    eff_k = [int(d//2 + warmup_frac * (ki - d//2)) for ki in k_list]

    sds, errs = [], []
    for i, ps in enumerate(c_params):
        flat  = params_to_flat(ps)
        delta = (flat - gflat) + errors[i]
        cka   = compute_per_layer_cka(client_models[i], gref,
                                       train_loaders[i], device, cka_batches)
        d_lss = lss_mask(delta, cka, layer_map, rng)
        sd, _ = topk_sparse(d_lss, eff_k[i])
        sds.append(sd)
        errs.append(delta - sd)

    new_flat = gflat + np.mean(sds, axis=0)
    return flat_to_params(new_flat, shapes), new_flat, errs, eff_k


# ═══════════════════════════════════════════════════════
# ═══════════════════════════════════════════════════════
# METHOD 4: FEDS v9  server-variance-guided sparsification
#
# CLIENT: phi_j = |delta_j| * p_j[t-1]  ->  top-K selection
# SERVER: p[t]  = normalised Var_i(delta_i_j)  ->  broadcast with w[t+1]
#
# p computed FREE during aggregation. No CKA, no forward passes.
# Provably prioritises parameters where clients disagree most.
def feds_aggregate(c_params, gflat, errors, shapes, d,
                   k_list, priority, round_idx, comp_warmup,
                   prev_priority, ema_alpha=0.7):
    warmup_frac = min(1.0, round_idx / max(comp_warmup, 1))
    eff_k = [int(d//2 + warmup_frac * (ki - d//2)) for ki in k_list]
    sds, errs, raw_deltas = [], [], []
    for i, ps in enumerate(c_params):
        flat  = params_to_flat(ps)
        delta = (flat - gflat) + errors[i]
        raw_deltas.append(delta.copy())
        sd, residual = priority_sparse(delta, priority, eff_k[i])
        sds.append(sd); errs.append(residual)
    new_flat     = gflat + np.mean(sds, axis=0)
    new_priority = compute_server_priority(
        raw_deltas, d, ema_alpha=ema_alpha, prev_priority=prev_priority)
    ka = np.array(eff_k)
    print(f'  [FEDS] K={ka.mean():.0f}  compress={1-ka.mean()/d:.1%}  '
          f'p_mean={new_priority.mean():.3f}', end='')
    return flat_to_params(new_flat, shapes), new_flat, errs, eff_k, new_priority


# ═══════════════════════════════════════════════════════
# MAIN SIMULATION RUNNER — v5
# ═══════════════════════════════════════════════════════
def run_simulation(dataset, method, num_rounds, num_clients,
                   local_epochs, lr, lr_decay, lr_min, device, seed,
                   alpha_comm, gamma_comm,
                   comp_warmup,
                   train_loaders, global_test_loader,
                   cka_batches=2,
                   feds_ema=0.7):

    set_seed(seed)
    rng = np.random.default_rng(seed)
    print(f'\n{"="*62}')
    print(f'  {method.upper():12s} | {dataset} | {num_rounds} rounds | {device}')
    print(f'{"="*62}')

    global_model  = get_model(dataset).to(device)
    shapes        = get_float_shapes(global_model)
    layer_map     = get_layer_map(global_model)
    global_params = get_float_params(global_model)
    global_flat   = params_to_flat(global_params)
    d             = len(global_flat)
    k_max, k_min  = d, max(100, d // 100)
    print(f'  d={d:,}  k_min={k_min:,}')

    # v5: persistent gref model — reuse every round, just update weights
    gref = get_model(dataset).to(device) if method == 'dsfl' else None

    errors      = [np.zeros(d, dtype=np.float32) for _ in range(num_clients)]
    priority    = np.ones(d, dtype=np.float32)  # p[0]=uniform, round 1 = Top-K
    current_lr  = lr

    if method == 'fixed_topk':
        k_sample = sample_k_list(d, num_clients, alpha_comm, gamma_comm, rng)
        k_fixed  = min(k_sample)
        print(f'  Fixed K={k_fixed} ({k_fixed/d:.1%})')
    elif method in ('dsfl', 'feds'):
        k_list = sample_k_list(d, num_clients, alpha_comm, gamma_comm, rng)
        ka = np.array(k_list)
        print(f'  Initial K: mean={ka.mean():.0f} ({ka.mean()/d:.1%})  '
              f'min={ka.min()}  max={ka.max()}')

    client_models = [get_model(dataset).to(device) for _ in range(num_clients)]

    log = dict(
        method=method, dataset=dataset, seed=seed,
        total_params=d, k_max=k_max, k_min=k_min,
        round=[], accuracy=[], loss=[],
        k_mean=[], k_std=[], k_min_r=[], k_max_r=[],
        train_loss=[], lr=[], elapsed=[]
    )

    t0 = time.time()
    for rnd in range(num_rounds):
        t_round = time.time()
        print(f'\n  Round {rnd+1:3d}/{num_rounds}  (lr={current_lr:.5f})', end='  ')

        # v5: distribute global model using GPU tensor copy (no CPU round-trip)
        global_flat_gpu = torch.tensor(global_flat, device=device, dtype=torch.float32)
        for cm in client_models:
            set_float_params_gpu(cm, global_flat_gpu, shapes)

        # Local training — sequential (GPU is busy the whole time per client)
        c_params, c_losses = [], []
        for cid in range(num_clients):
            tl = local_train(client_models[cid], train_loaders[cid],
                             local_epochs, current_lr, device)
            c_params.append(get_float_params(client_models[cid]))
            c_losses.append(tl)

        if any(np.isnan(cl) for cl in c_losses):
            print(f'\n  ⚠️  NaN in losses — STOPPING'); break

        # Aggregation
        if method == 'fedavg':
            global_params = fedavg_aggregate(c_params)
            global_flat   = params_to_flat(global_params)
            k_arr = np.full(num_clients, d, dtype=float)

        elif method == 'fixed_topk':
            global_params, global_flat, errors = fixed_topk_aggregate(
                c_params, global_flat, errors, shapes, k_fixed)
            k_arr = np.full(num_clients, k_fixed, dtype=float)

        elif method == 'dsfl':
            k_list = sample_k_list(d, num_clients, alpha_comm, gamma_comm, rng)
            # v5: reuse persistent gref — just update its weights
            set_float_params_gpu(gref, global_flat_gpu, shapes)
            global_params, global_flat, errors, eff_k = dsfl_aggregate(
                c_params, global_flat, errors, shapes, layer_map,
                k_list, d, client_models, gref, train_loaders,
                device, rng, rnd, comp_warmup, cka_batches)
            k_arr = np.array(eff_k, dtype=float)
            print(f'[DSFL] eff_K={k_arr.mean():.0f}  compress={1-k_arr.mean()/d:.1%}', end='')

        elif method == 'feds':
            k_list = sample_k_list(d, num_clients, alpha_comm, gamma_comm, rng)
            global_params, global_flat, errors, eff_k, priority = feds_aggregate(
                c_params, global_flat, errors, shapes, d,
                k_list, priority, rnd, comp_warmup,
                prev_priority=priority, ema_alpha=feds_ema)
            k_arr = np.array(eff_k, dtype=float)

        current_lr = max(lr_min, current_lr * lr_decay)

        set_float_params(global_model, global_params)
        ev_loss, acc = evaluate(global_model, global_test_loader, device)
        elapsed = time.time() - t0
        rtime   = time.time() - t_round

        log['round'].append(rnd+1)
        log['accuracy'].append(float(acc))
        log['loss'].append(float(ev_loss))
        log['k_mean'].append(float(k_arr.mean()))
        log['k_std'].append(float(k_arr.std()))
        log['k_min_r'].append(int(k_arr.min()))
        log['k_max_r'].append(int(k_arr.max()))
        log['train_loss'].append(float(np.mean(c_losses)))
        log['lr'].append(float(current_lr))
        log['elapsed'].append(elapsed)

        print(f'  Acc={acc:.4f}  Loss={ev_loss:.4f}  '
              f'TrainL={np.mean(c_losses):.4f}  '
              f'K={k_arr.mean():.0f}  round={rtime:.1f}s  total={elapsed:.0f}s')

    log['total_time'] = time.time() - t0
    print(f'\n  ✅ {method.upper()} done — '
          f'{log["total_time"]/60:.1f} min  '
          f'| Final acc: {log["accuracy"][-1]:.4f}')
    return log


print('All functions defined (v10 - UnifiedNet + rank-norm priority)')
print('Model param counts:')
for name, kwargs in [('MNIST',   {'in_channels':1, 'num_classes':10}),
                     ('CIFAR10', {'in_channels':3, 'num_classes':10})]:
    m = UnifiedNet(**kwargs)
    fp, _ = split_state_dict(m)
    print(f'  {name:8s}: {sum(v.numel() for v in fp.values()):,}')
m = SpeechNet()
fp, _ = split_state_dict(m)
print(f'  {"Speech":8s}: {sum(v.numel() for v in fp.values()):,}')
# Out:
# All functions defined (v10 - UnifiedNet + rank-norm priority)
# Model param counts:
#   MNIST   : 227,466
#   CIFAR10 : 228,042
#   Speech  : 27,299

# %% [markdown]
# ## Cell 4 - Load Data

# %%
import torch, time
t0=time.time()
train_loaders, global_test_loader = build_loaders(
    DATASET, NUM_CLIENTS, SEED, BATCH_SIZE, device=DEVICE
)
print(f'Load time: {time.time()-t0:.1f}s')
x, y = next(iter(train_loaders[0]))
print(f'x: {x.shape}  dtype={x.dtype}  device={x.device}')
if DATASET != 'Speech':
    assert str(x.device).startswith(DEVICE), f'Expected {DEVICE}, got {x.device}'
else:
    print('Speech: x moves to GPU inside local_train')
m = get_model(DATASET).to(DEVICE)
with torch.no_grad(): out = m(x.to(DEVICE))
loss_init = torch.nn.CrossEntropyLoss()(out, y.to(DEVICE)).item()
print(f'Init loss={loss_init:.4f}  (expect ~2.3)')
# Count params
fp,_ = split_state_dict(m)
n_params = sum(v.numel() for v in fp.values())
print(f'UnifiedNet params: {n_params:,}')
if DEVICE=='cuda':
    import time as _t; torch.cuda.synchronize(); t0=_t.time()
    for cid in range(NUM_CLIENTS): local_train(m,train_loaders[cid],1,LR,DEVICE)
    torch.cuda.synchronize(); tt=_t.time()-t0
    print(f'Benchmark: 10-client={tt:.2f}s  GPU={torch.cuda.memory_allocated()/1e6:.0f}MB')
print('Data ready')
# Out:
# 100%|██████████| 170M/170M [00:01<00:00, 102MB/s]
#   Creating label-pair partition...
#   Client 0: labels=[0, 1]  n=10000
#   Client 1: labels=[1, 2]  n=10000
#   Client 2: labels=[2, 3]  n=10000
#   Client 3: labels=[3, 4]  n=10000
#   Client 4: labels=[4, 5]  n=10000
#   Client 5: labels=[5, 6]  n=10000
#   Client 6: labels=[6, 7]  n=10000
#   Client 7: labels=[7, 8]  n=10000
#   Client 8: labels=[8, 9]  n=10000
#   Client 9: labels=[0, 9]  n=10000
#   Preloading dataset to GPU...
#   GPU memory used: 1977 MB
#   Train: 10 clients  batch=256  ~10000 samples/client
#   Test : 10000 samples on cuda
# Load time: 13.9s
# x: torch.Size([256, 3, 32, 32])  dtype=torch.float32  device=cuda:0
# Init loss=2.4071  (expect ~2.3)
# UnifiedNet params: 228,042
# Benchmark: 10-client=4.72s  GPU=1385MB
# Data ready

# %% [markdown]
# ## Cell 5 - Smoke Test (30 rounds)
#
# FEDS uses no CKA. Only DSFL uses the fast CKA proxy here.
# Watch p_mean - should stay in 0.3-0.7 range (rank normalisation ensures this).

# %%
# SMOKE_ROUNDS = 30
# LABELS = {'fedavg':'FedAvg','fixed_topk':'Fixed Top-K','dsfl':'DSFL','feds':'FEDS (Ours)'}

# # Fast CKA proxy for DSFL baseline only
# _real_cka = compute_per_layer_cka
# def _fast_cka(cm,gm,loader,device,max_batches=1):
#     names=get_float_param_names(cm)
#     mods=list(dict.fromkeys(n.rsplit('.',1)[0] for n in names)); nl=max(len(mods),1)
#     return {next(i for i,pn in enumerate(names) if pn.rsplit('.',1)[0]==mname):
#             float(np.clip(0.6*(1-rank/nl)+0.1,0,0.99))
#             for rank,mname in enumerate(mods)}
# compute_per_layer_cka = _fast_cka

# smoke_logs={}
# for method in ['fedavg','fixed_topk','dsfl','feds']:
#     smoke_logs[method]=run_simulation(
#         dataset=DATASET,method=method,num_rounds=SMOKE_ROUNDS,
#         num_clients=NUM_CLIENTS,local_epochs=LOCAL_EPOCHS,
#         lr=LR,lr_decay=LR_DECAY,lr_min=LR_MIN,device=DEVICE,seed=SEED,
#         alpha_comm=ALPHA_COMM,gamma_comm=GAMMA_COMM,
#         comp_warmup=min(10,SMOKE_ROUNDS//3),
#         train_loaders=train_loaders,global_test_loader=global_test_loader,
#         cka_batches=CKA_BATCHES, feds_ema=FEDS_EMA,
#     )
# compute_per_layer_cka = _real_cka

# print('\n-- Smoke Results --')
# print(f'{"Method":<16} {"R10":>7} {"R20":>7} {"R30":>7}')
# for m,log in smoke_logs.items():
#     acc=log['accuracy']
#     print(f'{LABELS.get(m,m):<16} {acc[9]*100:>6.1f}% {acc[19]*100:>6.1f}% {acc[-1]*100:>6.1f}%')
# finals=[round(log['accuracy'][-1],4) for log in smoke_logs.values()]
# if len(set(finals))==1: print('BUG: all methods identical')
# elif smoke_logs['feds']['accuracy'][-1] < 0.5 and DATASET=='MNIST':
#     print('WARNING: FEDS underperforming - check priority signal')
# else: print('Smoke OK - run Cell 6')

# %% [markdown]
# ## Cell 6 - Full Experiment (200 rounds)

# %%
import json
METHODS = ['fedavg','fixed_topk','dsfl','feds']
LABELS  = {'fedavg':'FedAvg','fixed_topk':'Fixed Top-K','dsfl':'DSFL','feds':'FEDS (Ours)'}

all_logs={}
for method in METHODS:
    log=run_simulation(
        dataset=DATASET,method=method,num_rounds=NUM_ROUNDS,
        num_clients=NUM_CLIENTS,local_epochs=LOCAL_EPOCHS,
        lr=LR,lr_decay=LR_DECAY,lr_min=LR_MIN,device=DEVICE,seed=SEED,
        alpha_comm=ALPHA_COMM,gamma_comm=GAMMA_COMM,
        comp_warmup=COMP_WARMUP,
        train_loaders=train_loaders,global_test_loader=global_test_loader,
        cka_batches=CKA_BATCHES, feds_ema=FEDS_EMA,
    )
    all_logs[method]=log
    with open(f'{RESULTS_DIR}/data/{method}_{DATASET}.json','w') as f: json.dump(log,f,indent=2)

d=next(iter(all_logs.values()))['total_params']
print('\nSummary:')
for m,log in all_logs.items():
    km=np.mean(log['k_mean'])
    cs=f'{(1-km/d)*100:.1f}%' if m!='fedavg' else 'N/A'
    print(f'{LABELS.get(m,m):<16} '
          f'best={max(log["accuracy"])*100:.2f}% '
          f'final={log["accuracy"][-1]*100:.2f}% '
          f'comm_save={cs} '
          f't={log["total_time"]/60:.1f}m')
# Out:
# ==============================================================
#   FEDAVG       | CIFAR10 | 200 rounds | cuda
# ==============================================================
#   d=228,042  k_min=2,280
#
#   Round   1/200  (lr=0.01000)    Acc=0.1619  Loss=2.2474  TrainL=0.7335  K=228042  round=4.3s  total=4s
#
#   Round   2/200  (lr=0.00990)    Acc=0.2679  Loss=2.1394  TrainL=0.5489  K=228042  round=4.2s  total=9s
#
#   Round   3/200  (lr=0.00980)    Acc=0.3406  Loss=2.0449  TrainL=0.4942  K=228042  round=4.2s  total=13s
#
#   Round   4/200  (lr=0.00970)    Acc=0.3408  Loss=1.9857  TrainL=0.4555  K=228042  round=4.2s  total=17s
#
#   Round   5/200  (lr=0.00961)    Acc=0.3495  Loss=1.9215  TrainL=0.4315  K=228042  round=4.2s  total=21s
#
#   Round   6/200  (lr=0.00951)    Acc=0.3560  Loss=1.9181  TrainL=0.4115  K=228042  round=4.2s  total=25s
#
#   Round   7/200  (lr=0.00941)    Acc=0.3357  Loss=1.9165  TrainL=0.3967  K=228042  round=4.2s  total=30s
#
#   Round   8/200  (lr=0.00932)    Acc=0.2680  Loss=2.0606  TrainL=0.3896  K=228042  round=4.2s  total=34s
#
#   Round   9/200  (lr=0.00923)    Acc=0.3184  Loss=2.1924  TrainL=0.3882  K=228042  round=4.2s  total=38s
#
#   Round  10/200  (lr=0.00914)    Acc=0.3338  Loss=2.1947  TrainL=0.4092  K=228042  round=4.2s  total=42s
#
#   Round  11/200  (lr=0.00904)    Acc=0.3204  Loss=2.1800  TrainL=0.4017  K=228042  round=4.3s  total=46s
#
#   Round  12/200  (lr=0.00895)    Acc=0.3252  Loss=2.2064  TrainL=0.3855  K=228042  round=4.3s  total=51s
#
#   Round  13/200  (lr=0.00886)    Acc=0.3446  Loss=2.1000  TrainL=0.3887  K=228042  round=4.3s  total=55s
#
#   Round  14/200  (lr=0.00878)    Acc=0.3392  Loss=1.9861  TrainL=0.3740  K=228042  round=4.3s  total=59s
#
#   Round  15/200  (lr=0.00869)    Acc=0.3391  Loss=2.0696  TrainL=0.3659  K=228042  round=4.3s  total=64s
#
#   Round  16/200  (lr=0.00860)    Acc=0.3379  Loss=1.9086  TrainL=0.3618  K=228042  round=4.3s  total=68s
#
#   Round  17/200  (lr=0.00851)    Acc=0.3399  Loss=1.9694  TrainL=0.3478  K=228042  round=4.3s  total=72s
#
#   Round  18/200  (lr=0.00843)    Acc=0.3497  Loss=1.7879  TrainL=0.3437  K=228042  round=4.3s  total=77s
#
#   Round  19/200  (lr=0.00835)    Acc=0.3698  Loss=1.8433  TrainL=0.3300  K=228042  round=4.3s  total=81s
#
#   Round  20/200  (lr=0.00826)    Acc=0.3623  Loss=1.7164  TrainL=0.3263  K=228042  round=4.4s  total=85s
#
#   Round  21/200  (lr=0.00818)    Acc=0.3936  Loss=1.7541  TrainL=0.3139  K=228042  round=4.4s  total=90s
#
#   Round  22/200  (lr=0.00810)    Acc=0.3905  Loss=1.6440  TrainL=0.3160  K=228042  round=4.4s  total=94s
#
#   Round  23/200  (lr=0.00802)    Acc=0.3891  Loss=1.7150  TrainL=0.3041  K=228042  round=4.4s  total=98s
#
#   Round  24/200  (lr=0.00794)    Acc=0.4245  Loss=1.6149  TrainL=0.3010  K=228042  round=4.4s  total=103s
#
#   Round  25/200  (lr=0.00786)    Acc=0.3786  Loss=1.7353  TrainL=0.2947  K=228042  round=4.4s  total=107s
#
#   Round  26/200  (lr=0.00778)    Acc=0.4147  Loss=1.5784  TrainL=0.2982  K=228042  round=4.4s  total=112s
#
#   Round  27/200  (lr=0.00770)    Acc=0.3820  Loss=1.7565  TrainL=0.2921  K=228042  round=4.4s  total=116s
#
#   Round  28/200  (lr=0.00762)    Acc=0.4102  Loss=1.6162  TrainL=0.2950  K=228042  round=4.5s  total=121s
#
#   Round  29/200  (lr=0.00755)    Acc=0.3854  Loss=1.7481  TrainL=0.2939  K=228042  round=4.5s  total=125s
#
#   Round  30/200  (lr=0.00747)    Acc=0.4219  Loss=1.6013  TrainL=0.2902  K=228042  round=4.5s  total=129s
#
#   Round  31/200  (lr=0.00740)    Acc=0.3861  Loss=1.7400  TrainL=0.2878  K=228042  round=4.5s  total=134s
#
#   Round  32/200  (lr=0.00732)    Acc=0.4011  Loss=1.6546  TrainL=0.2911  K=228042  round=4.4s  total=138s
#
#   Round  33/200  (lr=0.00725)    Acc=0.3627  Loss=1.7911  TrainL=0.2852  K=228042  round=4.4s  total=143s
#
#   Round  34/200  (lr=0.00718)    Acc=0.3942  Loss=1.6436  TrainL=0.2892  K=228042  round=4.4s  total=147s
#
#   Round  35/200  (lr=0.00711)    Acc=0.3747  Loss=1.7714  TrainL=0.2802  K=228042  round=4.4s  total=152s
#
#   Round  36/200  (lr=0.00703)    Acc=0.4003  Loss=1.6530  TrainL=0.2876  K=228042  round=4.4s  total=156s
#
#   Round  37/200  (lr=0.00696)    Acc=0.3853  Loss=1.7752  TrainL=0.2807  K=228042  round=4.4s  total=160s
#
#   Round  38/200  (lr=0.00689)    Acc=0.3983  Loss=1.6849  TrainL=0.2884  K=228042  round=4.4s  total=165s
#
#   Round  39/200  (lr=0.00683)    Acc=0.3839  Loss=1.8193  TrainL=0.2802  K=228042  round=4.4s  total=169s
#
#   Round  40/200  (lr=0.00676)    Acc=0.3992  Loss=1.7122  TrainL=0.2897  K=228042  round=4.4s  total=174s
#
#   Round  41/200  (lr=0.00669)    Acc=0.3914  Loss=1.8139  TrainL=0.2820  K=228042  round=4.4s  total=178s
#
#   Round  42/200  (lr=0.00662)    Acc=0.3939  Loss=1.7318  TrainL=0.2894  K=228042  round=4.4s  total=182s
#
#   Round  43/200  (lr=0.00656)    Acc=0.3900  Loss=1.7927  TrainL=0.2783  K=228042  round=4.4s  total=187s
#
#   Round  44/200  (lr=0.00649)    Acc=0.4096  Loss=1.7061  TrainL=0.2868  K=228042  round=4.4s  total=191s
#
#   Round  45/200  (lr=0.00643)    Acc=0.4096  Loss=1.7136  TrainL=0.2769  K=228042  round=4.4s  total=196s
#
#   Round  46/200  (lr=0.00636)    Acc=0.4098  Loss=1.6916  TrainL=0.2745  K=228042  round=4.4s  total=200s
#
#   Round  47/200  (lr=0.00630)    Acc=0.4137  Loss=1.6832  TrainL=0.2681  K=228042  round=4.4s  total=205s
#
#   Round  48/200  (lr=0.00624)    Acc=0.4315  Loss=1.6629  TrainL=0.2667  K=228042  round=4.4s  total=209s
#
#   Round  49/200  (lr=0.00617)    Acc=0.4245  Loss=1.6414  TrainL=0.2658  K=228042  round=4.4s  total=213s
#
#   Round  50/200  (lr=0.00611)    Acc=0.4385  Loss=1.6340  TrainL=0.2595  K=228042  round=4.4s  total=218s
#
#   Round  51/200  (lr=0.00605)    Acc=0.4331  Loss=1.6079  TrainL=0.2590  K=228042  round=4.4s  total=222s
#
#   Round  52/200  (lr=0.00599)    Acc=0.4338  Loss=1.6258  TrainL=0.2563  K=228042  round=4.4s  total=227s
#
#   Round  53/200  (lr=0.00593)    Acc=0.4414  Loss=1.5843  TrainL=0.2558  K=228042  round=4.4s  total=231s
#
#   Round  54/200  (lr=0.00587)    Acc=0.4484  Loss=1.5612  TrainL=0.2508  K=228042  round=4.4s  total=236s
#
#   Round  55/200  (lr=0.00581)    Acc=0.4666  Loss=1.5112  TrainL=0.2492  K=228042  round=4.4s  total=240s
#
#   Round  56/200  (lr=0.00575)    Acc=0.4573  Loss=1.5426  TrainL=0.2451  K=228042  round=4.4s  total=244s
#
#   Round  57/200  (lr=0.00570)    Acc=0.4676  Loss=1.5077  TrainL=0.2437  K=228042  round=4.4s  total=249s
#
#   Round  58/200  (lr=0.00564)    Acc=0.4640  Loss=1.5139  TrainL=0.2413  K=228042  round=4.4s  total=253s
#
#   Round  59/200  (lr=0.00558)    Acc=0.4849  Loss=1.4603  TrainL=0.2429  K=228042  round=4.4s  total=258s
#
#   Round  60/200  (lr=0.00553)    Acc=0.4736  Loss=1.4869  TrainL=0.2349  K=228042  round=4.4s  total=262s
#
#   Round  61/200  (lr=0.00547)    Acc=0.4895  Loss=1.4385  TrainL=0.2347  K=228042  round=4.4s  total=266s
#
#   Round  62/200  (lr=0.00542)    Acc=0.4897  Loss=1.4406  TrainL=0.2290  K=228042  round=4.4s  total=271s
#
#   Round  63/200  (lr=0.00536)    Acc=0.5026  Loss=1.3921  TrainL=0.2273  K=228042  round=4.4s  total=275s
#
#   Round  64/200  (lr=0.00531)    Acc=0.5072  Loss=1.3930  TrainL=0.2228  K=228042  round=4.4s  total=280s
#
#   Round  65/200  (lr=0.00526)    Acc=0.5225  Loss=1.3505  TrainL=0.2233  K=228042  round=4.4s  total=284s
#
#   Round  66/200  (lr=0.00520)    Acc=0.5049  Loss=1.4016  TrainL=0.2170  K=228042  round=4.4s  total=288s
#
#   Round  67/200  (lr=0.00515)    Acc=0.5158  Loss=1.3668  TrainL=0.2208  K=228042  round=4.4s  total=293s
#
#   Round  68/200  (lr=0.00510)    Acc=0.5053  Loss=1.3944  TrainL=0.2176  K=228042  round=4.4s  total=297s
#
#   Round  69/200  (lr=0.00505)    Acc=0.5316  Loss=1.3409  TrainL=0.2187  K=228042  round=4.4s  total=302s
#
#   Round  70/200  (lr=0.00500)    Acc=0.5246  Loss=1.3550  TrainL=0.2142  K=228042  round=4.4s  total=306s
#
#   Round  71/200  (lr=0.00495)    Acc=0.5296  Loss=1.3254  TrainL=0.2139  K=228042  round=4.4s  total=310s
#
#   Round  72/200  (lr=0.00490)    Acc=0.5242  Loss=1.3560  TrainL=0.2091  K=228042  round=4.4s  total=315s
#
#   Round  73/200  (lr=0.00485)    Acc=0.5420  Loss=1.3114  TrainL=0.2101  K=228042  round=4.4s  total=319s
#
#   Round  74/200  (lr=0.00480)    Acc=0.5294  Loss=1.3340  TrainL=0.2057  K=228042  round=4.4s  total=324s
#
#   Round  75/200  (lr=0.00475)    Acc=0.5452  Loss=1.2918  TrainL=0.2079  K=228042  round=4.4s  total=328s
#
#   Round  76/200  (lr=0.00471)    Acc=0.5390  Loss=1.3126  TrainL=0.2053  K=228042  round=4.4s  total=333s
#
#   Round  77/200  (lr=0.00466)    Acc=0.5504  Loss=1.2774  TrainL=0.2048  K=228042  round=4.4s  total=337s
#
#   Round  78/200  (lr=0.00461)    Acc=0.5376  Loss=1.3134  TrainL=0.2039  K=228042  round=4.4s  total=341s
#
#   Round  79/200  (lr=0.00457)    Acc=0.5469  Loss=1.2857  TrainL=0.2009  K=228042  round=4.4s  total=346s
#
#   Round  80/200  (lr=0.00452)    Acc=0.5494  Loss=1.2941  TrainL=0.1979  K=228042  round=4.4s  total=350s
#
#   Round  81/200  (lr=0.00448)    Acc=0.5531  Loss=1.2658  TrainL=0.2013  K=228042  round=4.4s  total=355s
#
#   Round  82/200  (lr=0.00443)    Acc=0.5565  Loss=1.2714  TrainL=0.1949  K=228042  round=4.4s  total=359s
#
#   Round  83/200  (lr=0.00439)    Acc=0.5573  Loss=1.2500  TrainL=0.1986  K=228042  round=4.4s  total=363s
#
#   Round  84/200  (lr=0.00434)    Acc=0.5687  Loss=1.2505  TrainL=0.1942  K=228042  round=4.4s  total=368s
#
#   Round  85/200  (lr=0.00430)    Acc=0.5593  Loss=1.2419  TrainL=0.1931  K=228042  round=4.4s  total=372s
#
#   Round  86/200  (lr=0.00426)    Acc=0.5768  Loss=1.2262  TrainL=0.1919  K=228042  round=4.4s  total=377s
#
#   Round  87/200  (lr=0.00421)    Acc=0.5687  Loss=1.2288  TrainL=0.1908  K=228042  round=4.4s  total=381s
#
#   Round  88/200  (lr=0.00417)    Acc=0.5713  Loss=1.2472  TrainL=0.1903  K=228042  round=4.4s  total=385s
#
#   Round  89/200  (lr=0.00413)    Acc=0.5645  Loss=1.2330  TrainL=0.1910  K=228042  round=4.4s  total=390s
#
#   Round  90/200  (lr=0.00409)    Acc=0.5725  Loss=1.2434  TrainL=0.1893  K=228042  round=4.4s  total=394s
#
#   Round  91/200  (lr=0.00405)    Acc=0.5746  Loss=1.2150  TrainL=0.1874  K=228042  round=4.4s  total=399s
#
#   Round  92/200  (lr=0.00401)    Acc=0.5690  Loss=1.2451  TrainL=0.1822  K=228042  round=4.4s  total=403s
#
#   Round  93/200  (lr=0.00397)    Acc=0.5825  Loss=1.1954  TrainL=0.1845  K=228042  round=4.4s  total=408s
#
#   Round  94/200  (lr=0.00393)    Acc=0.5675  Loss=1.2439  TrainL=0.1810  K=228042  round=4.4s  total=412s
#
#   Round  95/200  (lr=0.00389)    Acc=0.5818  Loss=1.1914  TrainL=0.1853  K=228042  round=4.4s  total=416s
#
#   Round  96/200  (lr=0.00385)    Acc=0.5757  Loss=1.2259  TrainL=0.1812  K=228042  round=4.4s  total=421s
#
#   Round  97/200  (lr=0.00381)    Acc=0.5892  Loss=1.1827  TrainL=0.1828  K=228042  round=4.4s  total=425s
#
#   Round  98/200  (lr=0.00377)    Acc=0.5701  Loss=1.2480  TrainL=0.1792  K=228042  round=4.4s  total=430s
#
#   Round  99/200  (lr=0.00373)    Acc=0.5971  Loss=1.1568  TrainL=0.1805  K=228042  round=4.4s  total=434s
#
#   Round 100/200  (lr=0.00370)    Acc=0.5803  Loss=1.2097  TrainL=0.1777  K=228042  round=4.4s  total=438s
#
#   Round 101/200  (lr=0.00366)    Acc=0.5992  Loss=1.1512  TrainL=0.1776  K=228042  round=4.4s  total=443s
#
#   Round 102/200  (lr=0.00362)    Acc=0.5836  Loss=1.2071  TrainL=0.1747  K=228042  round=4.4s  total=447s
#
#   Round 103/200  (lr=0.00359)    Acc=0.6009  Loss=1.1444  TrainL=0.1740  K=228042  round=4.4s  total=452s
#
#   Round 104/200  (lr=0.00355)    Acc=0.5780  Loss=1.2190  TrainL=0.1738  K=228042  round=4.4s  total=456s
#
#   Round 105/200  (lr=0.00352)    Acc=0.5988  Loss=1.1389  TrainL=0.1740  K=228042  round=4.4s  total=461s
#
#   Round 106/200  (lr=0.00348)    Acc=0.5731  Loss=1.2253  TrainL=0.1726  K=228042  round=4.4s  total=465s
#
#   Round 107/200  (lr=0.00345)    Acc=0.5999  Loss=1.1339  TrainL=0.1739  K=228042  round=4.4s  total=469s
#
#   Round 108/200  (lr=0.00341)    Acc=0.5779  Loss=1.2149  TrainL=0.1725  K=228042  round=4.4s  total=474s
#
#   Round 109/200  (lr=0.00338)    Acc=0.6096  Loss=1.1217  TrainL=0.1719  K=228042  round=4.4s  total=478s
#
#   Round 110/200  (lr=0.00334)    Acc=0.5733  Loss=1.2353  TrainL=0.1719  K=228042  round=4.4s  total=483s
#
#   Round 111/200  (lr=0.00331)    Acc=0.6227  Loss=1.0963  TrainL=0.1698  K=228042  round=4.4s  total=487s
#
#   Round 112/200  (lr=0.00328)    Acc=0.5776  Loss=1.2124  TrainL=0.1703  K=228042  round=4.4s  total=491s
#
#   Round 113/200  (lr=0.00324)    Acc=0.6238  Loss=1.0932  TrainL=0.1671  K=228042  round=4.4s  total=496s
#
#   Round 114/200  (lr=0.00321)    Acc=0.5989  Loss=1.1553  TrainL=0.1672  K=228042  round=4.4s  total=500s
#
#   Round 115/200  (lr=0.00318)    Acc=0.6197  Loss=1.0974  TrainL=0.1651  K=228042  round=4.4s  total=505s
#
#   Round 116/200  (lr=0.00315)    Acc=0.5972  Loss=1.1684  TrainL=0.1652  K=228042  round=4.4s  total=509s
#
#   Round 117/200  (lr=0.00312)    Acc=0.6348  Loss=1.0752  TrainL=0.1621  K=228042  round=4.4s  total=513s
#
#   Round 118/200  (lr=0.00309)    Acc=0.6022  Loss=1.1556  TrainL=0.1636  K=228042  round=4.4s  total=518s
#
#   Round 119/200  (lr=0.00305)    Acc=0.6357  Loss=1.0763  TrainL=0.1621  K=228042  round=4.4s  total=522s
#
#   Round 120/200  (lr=0.00302)    Acc=0.6027  Loss=1.1418  TrainL=0.1612  K=228042  round=4.4s  total=527s
#
#   Round 121/200  (lr=0.00299)    Acc=0.6403  Loss=1.0648  TrainL=0.1603  K=228042  round=4.4s  total=531s
#
#   Round 122/200  (lr=0.00296)    Acc=0.5964  Loss=1.1535  TrainL=0.1597  K=228042  round=4.4s  total=536s
#
#   Round 123/200  (lr=0.00293)    Acc=0.6362  Loss=1.0636  TrainL=0.1586  K=228042  round=4.4s  total=540s
#
#   Round 124/200  (lr=0.00290)    Acc=0.6073  Loss=1.1358  TrainL=0.1581  K=228042  round=4.4s  total=544s
#
#   Round 125/200  (lr=0.00288)    Acc=0.6357  Loss=1.0721  TrainL=0.1567  K=228042  round=4.4s  total=549s
#
#   Round 126/200  (lr=0.00285)    Acc=0.6092  Loss=1.1368  TrainL=0.1606  K=228042  round=4.4s  total=553s
#
#   Round 127/200  (lr=0.00282)    Acc=0.6334  Loss=1.0757  TrainL=0.1585  K=228042  round=4.4s  total=558s
#
#   Round 128/200  (lr=0.00279)    Acc=0.6229  Loss=1.1085  TrainL=0.1573  K=228042  round=4.4s  total=562s
#
#   Round 129/200  (lr=0.00276)    Acc=0.6325  Loss=1.0723  TrainL=0.1553  K=228042  round=4.4s  total=566s
#
#   Round 130/200  (lr=0.00273)    Acc=0.6182  Loss=1.1159  TrainL=0.1575  K=228042  round=4.4s  total=571s
#
#   Round 131/200  (lr=0.00271)    Acc=0.6354  Loss=1.0694  TrainL=0.1543  K=228042  round=4.4s  total=575s
#
#   Round 132/200  (lr=0.00268)    Acc=0.6174  Loss=1.1103  TrainL=0.1546  K=228042  round=4.4s  total=580s
#
#   Round 133/200  (lr=0.00265)    Acc=0.6303  Loss=1.0761  TrainL=0.1517  K=228042  round=4.4s  total=584s
#
#   Round 134/200  (lr=0.00263)    Acc=0.6146  Loss=1.1195  TrainL=0.1546  K=228042  round=4.4s  total=589s
#
#   Round 135/200  (lr=0.00260)    Acc=0.6276  Loss=1.0818  TrainL=0.1536  K=228042  round=4.4s  total=593s
#
#   Round 136/200  (lr=0.00257)    Acc=0.6290  Loss=1.0881  TrainL=0.1522  K=228042  round=4.4s  total=597s
#
#   Round 137/200  (lr=0.00255)    Acc=0.6306  Loss=1.0758  TrainL=0.1519  K=228042  round=4.4s  total=602s
#
#   Round 138/200  (lr=0.00252)    Acc=0.6213  Loss=1.0948  TrainL=0.1523  K=228042  round=4.4s  total=606s
#
#   Round 139/200  (lr=0.00250)    Acc=0.6314  Loss=1.0754  TrainL=0.1510  K=228042  round=4.4s  total=611s
#
#   Round 140/200  (lr=0.00247)    Acc=0.6259  Loss=1.0798  TrainL=0.1508  K=228042  round=4.4s  total=615s
#
#   Round 141/200  (lr=0.00245)    Acc=0.6263  Loss=1.0793  TrainL=0.1521  K=228042  round=4.4s  total=619s
#
#   Round 142/200  (lr=0.00242)    Acc=0.6237  Loss=1.0871  TrainL=0.1509  K=228042  round=4.4s  total=624s
#
#   Round 143/200  (lr=0.00240)    Acc=0.6318  Loss=1.0753  TrainL=0.1478  K=228042  round=4.4s  total=628s
#
#   Round 144/200  (lr=0.00238)    Acc=0.6303  Loss=1.0696  TrainL=0.1487  K=228042  round=4.4s  total=633s
#
#   Round 145/200  (lr=0.00235)    Acc=0.6294  Loss=1.0771  TrainL=0.1493  K=228042  round=4.4s  total=637s
#
#   Round 146/200  (lr=0.00233)    Acc=0.6265  Loss=1.0774  TrainL=0.1489  K=228042  round=4.4s  total=641s
#
#   Round 147/200  (lr=0.00231)    Acc=0.6227  Loss=1.0888  TrainL=0.1484  K=228042  round=4.4s  total=646s
#
#   Round 148/200  (lr=0.00228)    Acc=0.6344  Loss=1.0671  TrainL=0.1487  K=228042  round=4.4s  total=650s
#
#   Round 149/200  (lr=0.00226)    Acc=0.6295  Loss=1.0780  TrainL=0.1468  K=228042  round=4.4s  total=655s
#
#   Round 150/200  (lr=0.00224)    Acc=0.6279  Loss=1.0760  TrainL=0.1479  K=228042  round=4.4s  total=659s
#
#   Round 151/200  (lr=0.00221)    Acc=0.6229  Loss=1.0837  TrainL=0.1454  K=228042  round=4.4s  total=664s
#
#   Round 152/200  (lr=0.00219)    Acc=0.6239  Loss=1.0794  TrainL=0.1467  K=228042  round=4.4s  total=668s
#
#   Round 153/200  (lr=0.00217)    Acc=0.6216  Loss=1.0844  TrainL=0.1462  K=228042  round=4.4s  total=672s
#
#   Round 154/200  (lr=0.00215)    Acc=0.6273  Loss=1.0764  TrainL=0.1444  K=228042  round=4.4s  total=677s
#
#   Round 155/200  (lr=0.00213)    Acc=0.6285  Loss=1.0742  TrainL=0.1453  K=228042  round=4.4s  total=681s
#
#   Round 156/200  (lr=0.00211)    Acc=0.6278  Loss=1.0743  TrainL=0.1459  K=228042  round=4.4s  total=686s
#
#   Round 157/200  (lr=0.00208)    Acc=0.6287  Loss=1.0697  TrainL=0.1470  K=228042  round=4.4s  total=690s
#
#   Round 158/200  (lr=0.00206)    Acc=0.6285  Loss=1.0772  TrainL=0.1456  K=228042  round=4.4s  total=694s
#
#   Round 159/200  (lr=0.00204)    Acc=0.6202  Loss=1.0829  TrainL=0.1446  K=228042  round=4.4s  total=699s
#
#   Round 160/200  (lr=0.00202)    Acc=0.6337  Loss=1.0623  TrainL=0.1450  K=228042  round=4.4s  total=703s
#
#   Round 161/200  (lr=0.00200)    Acc=0.6335  Loss=1.0606  TrainL=0.1437  K=228042  round=4.4s  total=708s
#
#   Round 162/200  (lr=0.00198)    Acc=0.6249  Loss=1.0737  TrainL=0.1436  K=228042  round=4.4s  total=712s
#
#   Round 163/200  (lr=0.00196)    Acc=0.6258  Loss=1.0724  TrainL=0.1448  K=228042  round=4.4s  total=717s
#
#   Round 164/200  (lr=0.00194)    Acc=0.6260  Loss=1.0727  TrainL=0.1438  K=228042  round=4.4s  total=721s
#
#   Round 165/200  (lr=0.00192)    Acc=0.6217  Loss=1.0823  TrainL=0.1433  K=228042  round=4.4s  total=725s
#
#   Round 166/200  (lr=0.00190)    Acc=0.6253  Loss=1.0711  TrainL=0.1439  K=228042  round=4.4s  total=730s
#
#   Round 167/200  (lr=0.00189)    Acc=0.6271  Loss=1.0754  TrainL=0.1420  K=228042  round=4.4s  total=734s
#
#   Round 168/200  (lr=0.00187)    Acc=0.6213  Loss=1.0796  TrainL=0.1425  K=228042  round=4.4s  total=739s
#
#   Round 169/200  (lr=0.00185)    Acc=0.6245  Loss=1.0760  TrainL=0.1433  K=228042  round=4.4s  total=743s
#
#   Round 170/200  (lr=0.00183)    Acc=0.6166  Loss=1.0871  TrainL=0.1417  K=228042  round=4.4s  total=747s
#
#   Round 171/200  (lr=0.00181)    Acc=0.6286  Loss=1.0636  TrainL=0.1427  K=228042  round=4.4s  total=752s
#
#   Round 172/200  (lr=0.00179)    Acc=0.6234  Loss=1.0722  TrainL=0.1414  K=228042  round=4.4s  total=756s
#
#   Round 173/200  (lr=0.00178)    Acc=0.6274  Loss=1.0651  TrainL=0.1410  K=228042  round=4.4s  total=761s
#
#   Round 174/200  (lr=0.00176)    Acc=0.6152  Loss=1.0941  TrainL=0.1414  K=228042  round=4.4s  total=765s
#
#   Round 175/200  (lr=0.00174)    Acc=0.6249  Loss=1.0714  TrainL=0.1427  K=228042  round=4.4s  total=770s
#
#   Round 176/200  (lr=0.00172)    Acc=0.6216  Loss=1.0791  TrainL=0.1425  K=228042  round=4.4s  total=774s
#
#   Round 177/200  (lr=0.00171)    Acc=0.6242  Loss=1.0707  TrainL=0.1418  K=228042  round=4.4s  total=778s
#
#   Round 178/200  (lr=0.00169)    Acc=0.6255  Loss=1.0691  TrainL=0.1396  K=228042  round=4.4s  total=783s
#
#   Round 179/200  (lr=0.00167)    Acc=0.6249  Loss=1.0638  TrainL=0.1406  K=228042  round=4.4s  total=787s
#
#   Round 180/200  (lr=0.00165)    Acc=0.6218  Loss=1.0765  TrainL=0.1422  K=228042  round=4.4s  total=792s
#
#   Round 181/200  (lr=0.00164)    Acc=0.6217  Loss=1.0746  TrainL=0.1403  K=228042  round=4.4s  total=796s
#
#   Round 182/200  (lr=0.00162)    Acc=0.6247  Loss=1.0680  TrainL=0.1397  K=228042  round=4.4s  total=800s
#
#   Round 183/200  (lr=0.00161)    Acc=0.6267  Loss=1.0647  TrainL=0.1401  K=228042  round=4.4s  total=805s
#
#   Round 184/200  (lr=0.00159)    Acc=0.6238  Loss=1.0666  TrainL=0.1397  K=228042  round=4.4s  total=809s
#
#   Round 185/200  (lr=0.00157)    Acc=0.6262  Loss=1.0686  TrainL=0.1392  K=228042  round=4.4s  total=814s
#
#   Round 186/200  (lr=0.00156)    Acc=0.6257  Loss=1.0665  TrainL=0.1395  K=228042  round=4.4s  total=818s
#
#   Round 187/200  (lr=0.00154)    Acc=0.6231  Loss=1.0714  TrainL=0.1385  K=228042  round=4.4s  total=823s
#
#   Round 188/200  (lr=0.00153)    Acc=0.6196  Loss=1.0773  TrainL=0.1393  K=228042  round=4.4s  total=827s
#
#   Round 189/200  (lr=0.00151)    Acc=0.6220  Loss=1.0675  TrainL=0.1400  K=228042  round=4.4s  total=831s
#
#   Round 190/200  (lr=0.00150)    Acc=0.6143  Loss=1.0888  TrainL=0.1403  K=228042  round=4.4s  total=836s
#
#   Round 191/200  (lr=0.00148)    Acc=0.6296  Loss=1.0541  TrainL=0.1395  K=228042  round=4.4s  total=840s
#
#   Round 192/200  (lr=0.00147)    Acc=0.6191  Loss=1.0747  TrainL=0.1388  K=228042  round=4.4s  total=845s
#
#   Round 193/200  (lr=0.00145)    Acc=0.6188  Loss=1.0774  TrainL=0.1395  K=228042  round=4.4s  total=849s
#
#   Round 194/200  (lr=0.00144)    Acc=0.6174  Loss=1.0857  TrainL=0.1377  K=228042  round=4.4s  total=853s
#
#   Round 195/200  (lr=0.00142)    Acc=0.6213  Loss=1.0674  TrainL=0.1370  K=228042  round=4.4s  total=858s
#
#   Round 196/200  (lr=0.00141)    Acc=0.6260  Loss=1.0667  TrainL=0.1389  K=228042  round=4.4s  total=862s
#
#   Round 197/200  (lr=0.00139)    Acc=0.6184  Loss=1.0814  TrainL=0.1384  K=228042  round=4.4s  total=867s
#
#   Round 198/200  (lr=0.00138)    Acc=0.6223  Loss=1.0678  TrainL=0.1387  K=228042  round=4.4s  total=871s
#
#   Round 199/200  (lr=0.00137)    Acc=0.6157  Loss=1.0894  TrainL=0.1382  K=228042  round=4.4s  total=875s
#
#   Round 200/200  (lr=0.00135)    Acc=0.6209  Loss=1.0738  TrainL=0.1412  K=228042  round=4.4s  total=880s
#
#   ✅ FEDAVG done — 14.7 min  | Final acc: 0.6209
#
# ==============================================================
#   FIXED_TOPK   | CIFAR10 | 200 rounds | cuda
# ==============================================================
#   d=228,042  k_min=2,280
#   Fixed K=6542 (2.9%)
#
#   Round   1/200  (lr=0.01000)    Acc=0.1084  Loss=2.2965  TrainL=0.7344  K=6542  round=4.5s  total=4s
#
#   Round   2/200  (lr=0.00990)    Acc=0.1575  Loss=2.2494  TrainL=0.6174  K=6542  round=4.4s  total=9s
#
#   Round   3/200  (lr=0.00980)    Acc=0.1667  Loss=2.2063  TrainL=0.5637  K=6542  round=4.4s  total=13s
#
#   Round   4/200  (lr=0.00970)    Acc=0.2550  Loss=2.1855  TrainL=0.5243  K=6542  round=4.4s  total=18s
#
#   Round   5/200  (lr=0.00961)    Acc=0.1634  Loss=2.3668  TrainL=0.5000  K=6542  round=4.4s  total=22s
#
#   Round   6/200  (lr=0.00951)    Acc=0.2158  Loss=2.7838  TrainL=0.5012  K=6542  round=4.4s  total=27s
#
#   Round   7/200  (lr=0.00941)    Acc=0.1837  Loss=2.6201  TrainL=0.5554  K=6542  round=4.4s  total=31s
#
#   Round   8/200  (lr=0.00932)    Acc=0.3206  Loss=2.5989  TrainL=0.5181  K=6542  round=4.4s  total=35s
#
#   Round   9/200  (lr=0.00923)    Acc=0.2150  Loss=2.1298  TrainL=0.5291  K=6542  round=4.4s  total=40s
#
#   Round  10/200  (lr=0.00914)    Acc=0.2569  Loss=2.2830  TrainL=0.4505  K=6542  round=4.4s  total=44s
#
#   Round  11/200  (lr=0.00904)    Acc=0.3016  Loss=2.0489  TrainL=0.4542  K=6542  round=4.4s  total=49s
#
#   Round  12/200  (lr=0.00895)    Acc=0.2994  Loss=2.1033  TrainL=0.4319  K=6542  round=4.4s  total=53s
#
#   Round  13/200  (lr=0.00886)    Acc=0.3395  Loss=1.8614  TrainL=0.4293  K=6542  round=4.4s  total=58s
#
#   Round  14/200  (lr=0.00878)    Acc=0.3292  Loss=2.1440  TrainL=0.3995  K=6542  round=4.4s  total=62s
#
#   Round  15/200  (lr=0.00869)    Acc=0.3282  Loss=1.9765  TrainL=0.4179  K=6542  round=4.4s  total=67s
#
#   Round  16/200  (lr=0.00860)    Acc=0.3461  Loss=1.9875  TrainL=0.3983  K=6542  round=4.4s  total=71s
#
#   Round  17/200  (lr=0.00851)    Acc=0.2738  Loss=1.9690  TrainL=0.3844  K=6542  round=4.4s  total=75s
#
#   Round  18/200  (lr=0.00843)    Acc=0.2797  Loss=2.0871  TrainL=0.3825  K=6542  round=4.4s  total=80s
#
#   Round  19/200  (lr=0.00835)    Acc=0.3009  Loss=2.0593  TrainL=0.3764  K=6542  round=4.4s  total=84s
#
#   Round  20/200  (lr=0.00826)    Acc=0.3711  Loss=1.8683  TrainL=0.3893  K=6542  round=4.4s  total=89s
#
#   Round  21/200  (lr=0.00818)    Acc=0.3542  Loss=1.7668  TrainL=0.3681  K=6542  round=4.4s  total=93s
#
#   Round  22/200  (lr=0.00810)    Acc=0.3774  Loss=1.8276  TrainL=0.3524  K=6542  round=4.4s  total=98s
#
#   Round  23/200  (lr=0.00802)    Acc=0.3647  Loss=1.7814  TrainL=0.3515  K=6542  round=4.4s  total=102s
#
#   Round  24/200  (lr=0.00794)    Acc=0.3696  Loss=1.9694  TrainL=0.3393  K=6542  round=4.4s  total=106s
#
#   Round  25/200  (lr=0.00786)    Acc=0.4176  Loss=1.6724  TrainL=0.3650  K=6542  round=4.4s  total=111s
#
#   Round  26/200  (lr=0.00778)    Acc=0.3904  Loss=1.7395  TrainL=0.3226  K=6542  round=4.4s  total=115s
#
#   Round  27/200  (lr=0.00770)    Acc=0.3828  Loss=1.7341  TrainL=0.3263  K=6542  round=4.4s  total=120s
#
#   Round  28/200  (lr=0.00762)    Acc=0.3584  Loss=1.9163  TrainL=0.3224  K=6542  round=4.4s  total=124s
#
#   Round  29/200  (lr=0.00755)    Acc=0.3475  Loss=1.9051  TrainL=0.3387  K=6542  round=4.4s  total=129s
#
#   Round  30/200  (lr=0.00747)    Acc=0.3454  Loss=1.8232  TrainL=0.3312  K=6542  round=4.4s  total=133s
#
#   Round  31/200  (lr=0.00740)    Acc=0.3986  Loss=1.7633  TrainL=0.3253  K=6542  round=4.4s  total=138s
#
#   Round  32/200  (lr=0.00732)    Acc=0.3822  Loss=1.7700  TrainL=0.3193  K=6542  round=4.4s  total=142s
#
#   Round  33/200  (lr=0.00725)    Acc=0.4298  Loss=1.7175  TrainL=0.3179  K=6542  round=4.4s  total=146s
#
#   Round  34/200  (lr=0.00718)    Acc=0.3928  Loss=1.7703  TrainL=0.3145  K=6542  round=4.4s  total=151s
#
#   Round  35/200  (lr=0.00711)    Acc=0.4434  Loss=1.6295  TrainL=0.3212  K=6542  round=4.4s  total=155s
#
#   Round  36/200  (lr=0.00703)    Acc=0.3727  Loss=1.7396  TrainL=0.2942  K=6542  round=4.4s  total=160s
#
#   Round  37/200  (lr=0.00696)    Acc=0.4208  Loss=1.7613  TrainL=0.3002  K=6542  round=4.4s  total=164s
#
#   Round  38/200  (lr=0.00689)    Acc=0.3775  Loss=1.7090  TrainL=0.3090  K=6542  round=4.4s  total=169s
#
#   Round  39/200  (lr=0.00683)    Acc=0.4487  Loss=1.6928  TrainL=0.3065  K=6542  round=4.4s  total=173s
#
#   Round  40/200  (lr=0.00676)    Acc=0.3880  Loss=1.6717  TrainL=0.3019  K=6542  round=4.4s  total=177s
#
#   Round  41/200  (lr=0.00669)    Acc=0.4677  Loss=1.6601  TrainL=0.2977  K=6542  round=4.4s  total=182s
#
#   Round  42/200  (lr=0.00662)    Acc=0.4132  Loss=1.5384  TrainL=0.2963  K=6542  round=4.4s  total=186s
#
#   Round  43/200  (lr=0.00656)    Acc=0.4765  Loss=1.5711  TrainL=0.2859  K=6542  round=4.4s  total=191s
#
#   Round  44/200  (lr=0.00649)    Acc=0.4239  Loss=1.5070  TrainL=0.2867  K=6542  round=4.4s  total=195s
#
#   Round  45/200  (lr=0.00643)    Acc=0.4298  Loss=1.6218  TrainL=0.2730  K=6542  round=4.4s  total=200s
#
#   Round  46/200  (lr=0.00636)    Acc=0.4080  Loss=1.5848  TrainL=0.2863  K=6542  round=4.4s  total=204s
#
#   Round  47/200  (lr=0.00630)    Acc=0.4713  Loss=1.6058  TrainL=0.2801  K=6542  round=4.4s  total=209s
#
#   Round  48/200  (lr=0.00624)    Acc=0.4342  Loss=1.5778  TrainL=0.2830  K=6542  round=4.4s  total=213s
#
#   Round  49/200  (lr=0.00617)    Acc=0.4936  Loss=1.5903  TrainL=0.2835  K=6542  round=4.4s  total=217s
#
#   Round  50/200  (lr=0.00611)    Acc=0.4419  Loss=1.4781  TrainL=0.2812  K=6542  round=4.4s  total=222s
#
#   Round  51/200  (lr=0.00605)    Acc=0.4978  Loss=1.4884  TrainL=0.2678  K=6542  round=4.4s  total=226s
#
#   Round  52/200  (lr=0.00599)    Acc=0.4432  Loss=1.4607  TrainL=0.2702  K=6542  round=4.4s  total=231s
#
#   Round  53/200  (lr=0.00593)    Acc=0.4869  Loss=1.4687  TrainL=0.2625  K=6542  round=4.4s  total=235s
#
#   Round  54/200  (lr=0.00587)    Acc=0.4338  Loss=1.5107  TrainL=0.2609  K=6542  round=4.4s  total=240s
#
#   Round  55/200  (lr=0.00581)    Acc=0.4857  Loss=1.5859  TrainL=0.2632  K=6542  round=4.4s  total=244s
#
#   Round  56/200  (lr=0.00575)    Acc=0.3928  Loss=1.5899  TrainL=0.2768  K=6542  round=4.4s  total=248s
#
#   Round  57/200  (lr=0.00570)    Acc=0.4810  Loss=1.5715  TrainL=0.2607  K=6542  round=4.4s  total=253s
#
#   Round  58/200  (lr=0.00564)    Acc=0.4506  Loss=1.4365  TrainL=0.2660  K=6542  round=4.4s  total=257s
#
#   Round  59/200  (lr=0.00558)    Acc=0.4991  Loss=1.4793  TrainL=0.2575  K=6542  round=4.4s  total=262s
#
#   Round  60/200  (lr=0.00553)    Acc=0.4644  Loss=1.4309  TrainL=0.2629  K=6542  round=4.4s  total=266s
#
#   Round  61/200  (lr=0.00547)    Acc=0.5111  Loss=1.4379  TrainL=0.2503  K=6542  round=4.4s  total=271s
#
#   Round  62/200  (lr=0.00542)    Acc=0.4352  Loss=1.4653  TrainL=0.2503  K=6542  round=4.4s  total=275s
#
#   Round  63/200  (lr=0.00536)    Acc=0.4891  Loss=1.4853  TrainL=0.2507  K=6542  round=4.4s  total=280s
#
#   Round  64/200  (lr=0.00531)    Acc=0.4581  Loss=1.4423  TrainL=0.2537  K=6542  round=4.4s  total=284s
#
#   Round  65/200  (lr=0.00526)    Acc=0.5137  Loss=1.4559  TrainL=0.2479  K=6542  round=4.4s  total=288s
#
#   Round  66/200  (lr=0.00520)    Acc=0.4351  Loss=1.4513  TrainL=0.2505  K=6542  round=4.4s  total=293s
#
#   Round  67/200  (lr=0.00515)    Acc=0.5175  Loss=1.4165  TrainL=0.2419  K=6542  round=4.4s  total=297s
#
#   Round  68/200  (lr=0.00510)    Acc=0.4453  Loss=1.4439  TrainL=0.2445  K=6542  round=4.4s  total=302s
#
#   Round  69/200  (lr=0.00505)    Acc=0.5117  Loss=1.3878  TrainL=0.2415  K=6542  round=4.4s  total=306s
#
#   Round  70/200  (lr=0.00500)    Acc=0.4800  Loss=1.3771  TrainL=0.2402  K=6542  round=4.4s  total=311s
#
#   Round  71/200  (lr=0.00495)    Acc=0.5286  Loss=1.3957  TrainL=0.2374  K=6542  round=4.4s  total=315s
#
#   Round  72/200  (lr=0.00490)    Acc=0.4794  Loss=1.3866  TrainL=0.2406  K=6542  round=4.4s  total=319s
#
#   Round  73/200  (lr=0.00485)    Acc=0.5503  Loss=1.3712  TrainL=0.2344  K=6542  round=4.4s  total=324s
#
#   Round  74/200  (lr=0.00480)    Acc=0.4803  Loss=1.3525  TrainL=0.2372  K=6542  round=4.4s  total=328s
#
#   Round  75/200  (lr=0.00475)    Acc=0.5347  Loss=1.3382  TrainL=0.2264  K=6542  round=4.4s  total=333s
#
#   Round  76/200  (lr=0.00471)    Acc=0.5052  Loss=1.3074  TrainL=0.2304  K=6542  round=4.4s  total=337s
#
#   Round  77/200  (lr=0.00466)    Acc=0.5111  Loss=1.3515  TrainL=0.2268  K=6542  round=4.4s  total=342s
#
#   Round  78/200  (lr=0.00461)    Acc=0.4884  Loss=1.3412  TrainL=0.2262  K=6542  round=4.4s  total=346s
#
#   Round  79/200  (lr=0.00457)    Acc=0.5512  Loss=1.3301  TrainL=0.2211  K=6542  round=4.4s  total=351s
#
#   Round  80/200  (lr=0.00452)    Acc=0.4644  Loss=1.4065  TrainL=0.2263  K=6542  round=4.4s  total=355s
#
#   Round  81/200  (lr=0.00448)    Acc=0.5402  Loss=1.3264  TrainL=0.2220  K=6542  round=4.4s  total=359s
#
#   Round  82/200  (lr=0.00443)    Acc=0.4919  Loss=1.3519  TrainL=0.2261  K=6542  round=4.4s  total=364s
#
#   Round  83/200  (lr=0.00439)    Acc=0.5387  Loss=1.3334  TrainL=0.2246  K=6542  round=4.4s  total=368s
#
#   Round  84/200  (lr=0.00434)    Acc=0.4964  Loss=1.3340  TrainL=0.2194  K=6542  round=4.4s  total=373s
#
#   Round  85/200  (lr=0.00430)    Acc=0.5500  Loss=1.3061  TrainL=0.2167  K=6542  round=4.4s  total=377s
#
#   Round  86/200  (lr=0.00426)    Acc=0.4641  Loss=1.3784  TrainL=0.2190  K=6542  round=4.4s  total=382s
#
#   Round  87/200  (lr=0.00421)    Acc=0.5420  Loss=1.3162  TrainL=0.2133  K=6542  round=4.4s  total=386s
#
#   Round  88/200  (lr=0.00417)    Acc=0.4800  Loss=1.3578  TrainL=0.2182  K=6542  round=4.4s  total=390s
#
#   Round  89/200  (lr=0.00413)    Acc=0.5327  Loss=1.3192  TrainL=0.2126  K=6542  round=4.4s  total=395s
#
#   Round  90/200  (lr=0.00409)    Acc=0.5211  Loss=1.2709  TrainL=0.2173  K=6542  round=4.4s  total=399s
#
#   Round  91/200  (lr=0.00405)    Acc=0.5563  Loss=1.2767  TrainL=0.2110  K=6542  round=4.4s  total=404s
#
#   Round  92/200  (lr=0.00401)    Acc=0.4760  Loss=1.3604  TrainL=0.2134  K=6542  round=4.4s  total=408s
#
#   Round  93/200  (lr=0.00397)    Acc=0.5407  Loss=1.3004  TrainL=0.2073  K=6542  round=4.4s  total=413s
#
#   Round  94/200  (lr=0.00393)    Acc=0.4967  Loss=1.3127  TrainL=0.2114  K=6542  round=4.4s  total=417s
#
#   Round  95/200  (lr=0.00389)    Acc=0.5581  Loss=1.2811  TrainL=0.2058  K=6542  round=4.4s  total=422s
#
#   Round  96/200  (lr=0.00385)    Acc=0.5189  Loss=1.2797  TrainL=0.2075  K=6542  round=4.4s  total=426s
#
#   Round  97/200  (lr=0.00381)    Acc=0.5596  Loss=1.2629  TrainL=0.2025  K=6542  round=4.4s  total=430s
#
#   Round  98/200  (lr=0.00377)    Acc=0.4967  Loss=1.3081  TrainL=0.2112  K=6542  round=4.4s  total=435s
#
#   Round  99/200  (lr=0.00373)    Acc=0.5509  Loss=1.2887  TrainL=0.2031  K=6542  round=4.4s  total=439s
#
#   Round 100/200  (lr=0.00370)    Acc=0.4910  Loss=1.3300  TrainL=0.2042  K=6542  round=4.4s  total=444s
#
#   Round 101/200  (lr=0.00366)    Acc=0.5599  Loss=1.2572  TrainL=0.2039  K=6542  round=4.4s  total=448s
#
#   Round 102/200  (lr=0.00362)    Acc=0.4819  Loss=1.3376  TrainL=0.2038  K=6542  round=4.4s  total=453s
#
#   Round 103/200  (lr=0.00359)    Acc=0.5647  Loss=1.2410  TrainL=0.2002  K=6542  round=4.4s  total=457s
#
#   Round 104/200  (lr=0.00355)    Acc=0.4613  Loss=1.3989  TrainL=0.2018  K=6542  round=4.4s  total=461s
#
#   Round 105/200  (lr=0.00352)    Acc=0.5584  Loss=1.2745  TrainL=0.1976  K=6542  round=4.4s  total=466s
#
#   Round 106/200  (lr=0.00348)    Acc=0.5114  Loss=1.2720  TrainL=0.2034  K=6542  round=4.4s  total=470s
#
#   Round 107/200  (lr=0.00345)    Acc=0.5652  Loss=1.2659  TrainL=0.1985  K=6542  round=4.4s  total=475s
#
#   Round 108/200  (lr=0.00341)    Acc=0.5354  Loss=1.2465  TrainL=0.1988  K=6542  round=4.4s  total=479s
#
#   Round 109/200  (lr=0.00338)    Acc=0.5654  Loss=1.2364  TrainL=0.1924  K=6542  round=4.4s  total=484s
#
#   Round 110/200  (lr=0.00334)    Acc=0.5123  Loss=1.2785  TrainL=0.1985  K=6542  round=4.4s  total=488s
#
#   Round 111/200  (lr=0.00331)    Acc=0.5745  Loss=1.2270  TrainL=0.1935  K=6542  round=4.4s  total=493s
#
#   Round 112/200  (lr=0.00328)    Acc=0.5070  Loss=1.2830  TrainL=0.1945  K=6542  round=4.4s  total=497s
#
#   Round 113/200  (lr=0.00324)    Acc=0.5676  Loss=1.2343  TrainL=0.1914  K=6542  round=4.4s  total=501s
#
#   Round 114/200  (lr=0.00321)    Acc=0.5006  Loss=1.3155  TrainL=0.1959  K=6542  round=4.4s  total=506s
#
#   Round 115/200  (lr=0.00318)    Acc=0.5811  Loss=1.1938  TrainL=0.1902  K=6542  round=4.4s  total=510s
#
#   Round 116/200  (lr=0.00315)    Acc=0.4933  Loss=1.3244  TrainL=0.1912  K=6542  round=4.4s  total=515s
#
#   Round 117/200  (lr=0.00312)    Acc=0.5731  Loss=1.2190  TrainL=0.1890  K=6542  round=4.4s  total=519s
#
#   Round 118/200  (lr=0.00309)    Acc=0.5132  Loss=1.2721  TrainL=0.1897  K=6542  round=4.4s  total=524s
#
#   Round 119/200  (lr=0.00305)    Acc=0.5728  Loss=1.2140  TrainL=0.1872  K=6542  round=4.4s  total=528s
#
#   Round 120/200  (lr=0.00302)    Acc=0.5246  Loss=1.2523  TrainL=0.1921  K=6542  round=4.4s  total=533s
#
#   Round 121/200  (lr=0.00299)    Acc=0.5652  Loss=1.2214  TrainL=0.1884  K=6542  round=4.4s  total=537s
#
#   Round 122/200  (lr=0.00296)    Acc=0.5045  Loss=1.2985  TrainL=0.1910  K=6542  round=4.4s  total=541s
#
#   Round 123/200  (lr=0.00293)    Acc=0.5693  Loss=1.2068  TrainL=0.1849  K=6542  round=4.4s  total=546s
#
#   Round 124/200  (lr=0.00290)    Acc=0.5355  Loss=1.2282  TrainL=0.1869  K=6542  round=4.4s  total=550s
#
#   Round 125/200  (lr=0.00288)    Acc=0.5812  Loss=1.1864  TrainL=0.1839  K=6542  round=4.4s  total=555s
#
#   Round 126/200  (lr=0.00285)    Acc=0.5290  Loss=1.2484  TrainL=0.1835  K=6542  round=4.4s  total=559s
#
#   Round 127/200  (lr=0.00282)    Acc=0.5874  Loss=1.1681  TrainL=0.1810  K=6542  round=4.4s  total=564s
#
#   Round 128/200  (lr=0.00279)    Acc=0.5105  Loss=1.3073  TrainL=0.1840  K=6542  round=4.4s  total=568s
#
#   Round 129/200  (lr=0.00276)    Acc=0.5752  Loss=1.2045  TrainL=0.1811  K=6542  round=4.4s  total=572s
#
#   Round 130/200  (lr=0.00273)    Acc=0.5219  Loss=1.2617  TrainL=0.1871  K=6542  round=4.4s  total=577s
#
#   Round 131/200  (lr=0.00271)    Acc=0.5752  Loss=1.2067  TrainL=0.1809  K=6542  round=4.4s  total=581s
#
#   Round 132/200  (lr=0.00268)    Acc=0.5166  Loss=1.2716  TrainL=0.1823  K=6542  round=4.4s  total=586s
#
#   Round 133/200  (lr=0.00265)    Acc=0.5776  Loss=1.1877  TrainL=0.1790  K=6542  round=4.4s  total=590s
#
#   Round 134/200  (lr=0.00263)    Acc=0.4959  Loss=1.3292  TrainL=0.1809  K=6542  round=4.4s  total=595s
#
#   Round 135/200  (lr=0.00260)    Acc=0.5862  Loss=1.1778  TrainL=0.1800  K=6542  round=4.5s  total=599s
#
#   Round 136/200  (lr=0.00257)    Acc=0.5099  Loss=1.3041  TrainL=0.1792  K=6542  round=4.5s  total=604s
#
#   Round 137/200  (lr=0.00255)    Acc=0.5756  Loss=1.1968  TrainL=0.1783  K=6542  round=4.5s  total=608s
#
#   Round 138/200  (lr=0.00252)    Acc=0.5195  Loss=1.2604  TrainL=0.1799  K=6542  round=4.5s  total=613s
#
#   Round 139/200  (lr=0.00250)    Acc=0.5842  Loss=1.1784  TrainL=0.1767  K=6542  round=4.5s  total=617s
#
#   Round 140/200  (lr=0.00247)    Acc=0.5285  Loss=1.2584  TrainL=0.1761  K=6542  round=4.5s  total=621s
#
#   Round 141/200  (lr=0.00245)    Acc=0.5876  Loss=1.1663  TrainL=0.1737  K=6542  round=4.5s  total=626s
#
#   Round 142/200  (lr=0.00242)    Acc=0.5491  Loss=1.2073  TrainL=0.1802  K=6542  round=4.4s  total=630s
#
#   Round 143/200  (lr=0.00240)    Acc=0.5838  Loss=1.1796  TrainL=0.1745  K=6542  round=4.4s  total=635s
#
#   Round 144/200  (lr=0.00238)    Acc=0.5390  Loss=1.2274  TrainL=0.1767  K=6542  round=4.4s  total=639s
#
#   Round 145/200  (lr=0.00235)    Acc=0.5824  Loss=1.1786  TrainL=0.1726  K=6542  round=4.4s  total=644s
#
#   Round 146/200  (lr=0.00233)    Acc=0.4924  Loss=1.3490  TrainL=0.1754  K=6542  round=4.4s  total=648s
#
#   Round 147/200  (lr=0.00231)    Acc=0.5964  Loss=1.1489  TrainL=0.1726  K=6542  round=4.4s  total=653s
#
#   Round 148/200  (lr=0.00228)    Acc=0.5421  Loss=1.2163  TrainL=0.1746  K=6542  round=4.4s  total=657s
#
#   Round 149/200  (lr=0.00226)    Acc=0.5721  Loss=1.1899  TrainL=0.1723  K=6542  round=4.4s  total=661s
#
#   Round 150/200  (lr=0.00224)    Acc=0.5321  Loss=1.2358  TrainL=0.1757  K=6542  round=4.4s  total=666s
#
#   Round 151/200  (lr=0.00221)    Acc=0.5975  Loss=1.1485  TrainL=0.1708  K=6542  round=4.4s  total=670s
#
#   Round 152/200  (lr=0.00219)    Acc=0.5315  Loss=1.2475  TrainL=0.1702  K=6542  round=4.4s  total=675s
#
#   Round 153/200  (lr=0.00217)    Acc=0.5780  Loss=1.1809  TrainL=0.1692  K=6542  round=4.4s  total=679s
#
#   Round 154/200  (lr=0.00215)    Acc=0.5382  Loss=1.2354  TrainL=0.1726  K=6542  round=4.4s  total=684s
#
#   Round 155/200  (lr=0.00213)    Acc=0.5868  Loss=1.1784  TrainL=0.1704  K=6542  round=4.4s  total=688s
#
#   Round 156/200  (lr=0.00211)    Acc=0.5444  Loss=1.2165  TrainL=0.1714  K=6542  round=4.4s  total=693s
#
#   Round 157/200  (lr=0.00208)    Acc=0.5899  Loss=1.1664  TrainL=0.1699  K=6542  round=4.4s  total=697s
#
#   Round 158/200  (lr=0.00206)    Acc=0.5327  Loss=1.2463  TrainL=0.1733  K=6542  round=4.4s  total=701s
#
#   Round 159/200  (lr=0.00204)    Acc=0.5966  Loss=1.1421  TrainL=0.1677  K=6542  round=4.4s  total=706s
#
#   Round 160/200  (lr=0.00202)    Acc=0.5476  Loss=1.2122  TrainL=0.1700  K=6542  round=4.4s  total=710s
#
#   Round 161/200  (lr=0.00200)    Acc=0.5860  Loss=1.1492  TrainL=0.1669  K=6542  round=4.4s  total=715s
#
#   Round 162/200  (lr=0.00198)    Acc=0.5405  Loss=1.2199  TrainL=0.1709  K=6542  round=4.4s  total=719s
#
#   Round 163/200  (lr=0.00196)    Acc=0.5887  Loss=1.1691  TrainL=0.1669  K=6542  round=4.4s  total=724s
#
#   Round 164/200  (lr=0.00194)    Acc=0.5348  Loss=1.2513  TrainL=0.1685  K=6542  round=4.4s  total=728s
#
#   Round 165/200  (lr=0.00192)    Acc=0.5801  Loss=1.1852  TrainL=0.1662  K=6542  round=4.4s  total=732s
#
#   Round 166/200  (lr=0.00190)    Acc=0.5230  Loss=1.2680  TrainL=0.1696  K=6542  round=4.4s  total=737s
#
#   Round 167/200  (lr=0.00189)    Acc=0.5948  Loss=1.1486  TrainL=0.1654  K=6542  round=4.4s  total=741s
#
#   Round 168/200  (lr=0.00187)    Acc=0.5204  Loss=1.2890  TrainL=0.1651  K=6542  round=4.4s  total=746s
#
#   Round 169/200  (lr=0.00185)    Acc=0.5844  Loss=1.1688  TrainL=0.1669  K=6542  round=4.4s  total=750s
#
#   Round 170/200  (lr=0.00183)    Acc=0.5463  Loss=1.2002  TrainL=0.1677  K=6542  round=4.4s  total=755s
#
#   Round 171/200  (lr=0.00181)    Acc=0.6029  Loss=1.1312  TrainL=0.1644  K=6542  round=4.4s  total=759s
#
#   Round 172/200  (lr=0.00179)    Acc=0.5375  Loss=1.2448  TrainL=0.1669  K=6542  round=4.4s  total=764s
#
#   Round 173/200  (lr=0.00178)    Acc=0.5947  Loss=1.1324  TrainL=0.1642  K=6542  round=4.4s  total=768s
#
#   Round 174/200  (lr=0.00176)    Acc=0.5422  Loss=1.2275  TrainL=0.1685  K=6542  round=4.4s  total=772s
#
#   Round 175/200  (lr=0.00174)    Acc=0.5899  Loss=1.1526  TrainL=0.1638  K=6542  round=4.4s  total=777s
#
#   Round 176/200  (lr=0.00172)    Acc=0.5268  Loss=1.2733  TrainL=0.1658  K=6542  round=4.4s  total=781s
#
#   Round 177/200  (lr=0.00171)    Acc=0.6014  Loss=1.1201  TrainL=0.1636  K=6542  round=4.4s  total=786s
#
#   Round 178/200  (lr=0.00169)    Acc=0.5325  Loss=1.2513  TrainL=0.1646  K=6542  round=4.4s  total=790s
#
#   Round 179/200  (lr=0.00167)    Acc=0.6008  Loss=1.1317  TrainL=0.1635  K=6542  round=4.4s  total=795s
#
#   Round 180/200  (lr=0.00165)    Acc=0.5306  Loss=1.2683  TrainL=0.1647  K=6542  round=4.4s  total=799s
#
#   Round 181/200  (lr=0.00164)    Acc=0.5962  Loss=1.1300  TrainL=0.1633  K=6542  round=4.4s  total=804s
#
#   Round 182/200  (lr=0.00162)    Acc=0.5562  Loss=1.1897  TrainL=0.1656  K=6542  round=4.4s  total=808s
#
#   Round 183/200  (lr=0.00161)    Acc=0.5906  Loss=1.1545  TrainL=0.1612  K=6542  round=4.4s  total=812s
#
#   Round 184/200  (lr=0.00159)    Acc=0.5323  Loss=1.2637  TrainL=0.1645  K=6542  round=4.4s  total=817s
#
#   Round 185/200  (lr=0.00157)    Acc=0.5852  Loss=1.1714  TrainL=0.1630  K=6542  round=4.4s  total=821s
#
#   Round 186/200  (lr=0.00156)    Acc=0.5075  Loss=1.3266  TrainL=0.1646  K=6542  round=4.4s  total=826s
#
#   Round 187/200  (lr=0.00154)    Acc=0.5928  Loss=1.1505  TrainL=0.1625  K=6542  round=4.4s  total=830s
#
#   Round 188/200  (lr=0.00153)    Acc=0.5371  Loss=1.2420  TrainL=0.1624  K=6542  round=4.4s  total=835s
#
#   Round 189/200  (lr=0.00151)    Acc=0.5906  Loss=1.1468  TrainL=0.1612  K=6542  round=4.4s  total=839s
#
#   Round 190/200  (lr=0.00150)    Acc=0.5312  Loss=1.2537  TrainL=0.1631  K=6542  round=4.4s  total=843s
#
#   Round 191/200  (lr=0.00148)    Acc=0.6063  Loss=1.1203  TrainL=0.1609  K=6542  round=4.4s  total=848s
#
#   Round 192/200  (lr=0.00147)    Acc=0.5292  Loss=1.2700  TrainL=0.1630  K=6542  round=4.4s  total=852s
#
#   Round 193/200  (lr=0.00145)    Acc=0.5873  Loss=1.1598  TrainL=0.1606  K=6542  round=4.4s  total=857s
#
#   Round 194/200  (lr=0.00144)    Acc=0.5544  Loss=1.2035  TrainL=0.1637  K=6542  round=4.4s  total=861s
#
#   Round 195/200  (lr=0.00142)    Acc=0.5946  Loss=1.1476  TrainL=0.1592  K=6542  round=4.4s  total=866s
#
#   Round 196/200  (lr=0.00141)    Acc=0.5232  Loss=1.2834  TrainL=0.1605  K=6542  round=4.4s  total=870s
#
#   Round 197/200  (lr=0.00139)    Acc=0.6016  Loss=1.1194  TrainL=0.1603  K=6542  round=4.4s  total=875s
#
#   Round 198/200  (lr=0.00138)    Acc=0.5497  Loss=1.2199  TrainL=0.1637  K=6542  round=4.4s  total=879s
#
#   Round 199/200  (lr=0.00137)    Acc=0.5933  Loss=1.1452  TrainL=0.1605  K=6542  round=4.4s  total=883s
#
#   Round 200/200  (lr=0.00135)    Acc=0.5420  Loss=1.2295  TrainL=0.1603  K=6542  round=4.4s  total=888s
#
#   ✅ FIXED_TOPK done — 14.8 min  | Final acc: 0.5420
#
# ==============================================================
#   DSFL         | CIFAR10 | 200 rounds | cuda
# ==============================================================
#   d=228,042  k_min=2,280
#   Initial K: mean=34986 (15.3%)  min=6542  max=69400
#
#   Round   1/200  (lr=0.01000)  [DSFL] eff_K=114021  compress=50.0%  Acc=0.1234  Loss=2.2934  TrainL=0.7350  K=114021  round=37.0s  total=37s
#
#   Round   2/200  (lr=0.00990)  [DSFL] eff_K=109831  compress=51.8%  Acc=0.1910  Loss=2.2347  TrainL=0.6380  K=109831  round=37.1s  total=74s
#
#   Round   3/200  (lr=0.00980)  [DSFL] eff_K=105746  compress=53.6%  Acc=0.2488  Loss=2.1806  TrainL=0.5715  K=105746  round=37.1s  total=111s
#
#   Round   4/200  (lr=0.00970)  [DSFL] eff_K=100203  compress=56.1%  Acc=0.1758  Loss=2.2398  TrainL=0.5378  K=100203  round=37.0s  total=148s
#
#   Round   5/200  (lr=0.00961)  [DSFL] eff_K=97597  compress=57.2%  Acc=0.2639  Loss=2.1214  TrainL=0.5169  K=97597  round=37.0s  total=185s
#
#   Round   6/200  (lr=0.00951)  [DSFL] eff_K=93920  compress=58.8%  Acc=0.2458  Loss=2.0593  TrainL=0.4842  K=93920  round=37.0s  total=222s
#
#   Round   7/200  (lr=0.00941)  [DSFL] eff_K=85446  compress=62.5%  Acc=0.2857  Loss=2.0495  TrainL=0.4667  K=85446  round=37.1s  total=259s
#
#   Round   8/200  (lr=0.00932)  [DSFL] eff_K=84499  compress=62.9%  Acc=0.2115  Loss=2.0248  TrainL=0.4513  K=84499  round=37.1s  total=296s
#
#   Round   9/200  (lr=0.00923)  [DSFL] eff_K=81563  compress=64.2%  Acc=0.2742  Loss=1.9742  TrainL=0.4444  K=81563  round=37.1s  total=333s
#
#   Round  10/200  (lr=0.00914)  [DSFL] eff_K=77856  compress=65.9%  Acc=0.2852  Loss=1.9805  TrainL=0.4346  K=77856  round=37.1s  total=371s
#
#   Round  11/200  (lr=0.00904)  [DSFL] eff_K=69362  compress=69.6%  Acc=0.2430  Loss=2.0345  TrainL=0.4216  K=69362  round=37.0s  total=408s
#
#   Round  12/200  (lr=0.00895)  [DSFL] eff_K=63593  compress=72.1%  Acc=0.1984  Loss=2.2163  TrainL=0.4156  K=63593  round=36.9s  total=444s
#
#   Round  13/200  (lr=0.00886)  [DSFL] eff_K=64445  compress=71.7%  Acc=0.2331  Loss=2.0429  TrainL=0.4177  K=64445  round=37.0s  total=481s
#
#   Round  14/200  (lr=0.00878)  [DSFL] eff_K=51624  compress=77.4%  Acc=0.2767  Loss=2.0401  TrainL=0.3994  K=51624  round=37.1s  total=519s
#
#   Round  15/200  (lr=0.00869)  [DSFL] eff_K=59164  compress=74.1%  Acc=0.2748  Loss=2.0342  TrainL=0.4016  K=59164  round=37.1s  total=556s
#
#   Round  16/200  (lr=0.00860)  [DSFL] eff_K=45875  compress=79.9%  Acc=0.3477  Loss=1.8181  TrainL=0.3963  K=45875  round=37.1s  total=593s
#
#   Round  17/200  (lr=0.00851)  [DSFL] eff_K=50464  compress=77.9%  Acc=0.2780  Loss=2.0450  TrainL=0.3758  K=50464  round=37.1s  total=630s
#
#   Round  18/200  (lr=0.00843)  [DSFL] eff_K=41302  compress=81.9%  Acc=0.1611  Loss=2.1524  TrainL=0.3865  K=41302  round=37.0s  total=667s
#
#   Round  19/200  (lr=0.00835)  [DSFL] eff_K=41271  compress=81.9%  Acc=0.2346  Loss=1.9475  TrainL=0.3787  K=41271  round=37.0s  total=704s
#
#   Round  20/200  (lr=0.00826)  [DSFL] eff_K=37653  compress=83.5%  Acc=0.2755  Loss=2.0327  TrainL=0.3633  K=37653  round=37.0s  total=741s
#
#   Round  21/200  (lr=0.00818)  [DSFL] eff_K=30154  compress=86.8%  Acc=0.3072  Loss=1.9028  TrainL=0.3724  K=30154  round=37.0s  total=778s
#
#   Round  22/200  (lr=0.00810)  [DSFL] eff_K=20514  compress=91.0%  Acc=0.1772  Loss=2.1373  TrainL=0.3568  K=20514  round=37.1s  total=815s
#
#   Round  23/200  (lr=0.00802)  [DSFL] eff_K=21270  compress=90.7%  Acc=0.1909  Loss=2.5390  TrainL=0.3663  K=21270  round=37.1s  total=852s
#
#   Round  24/200  (lr=0.00794)  [DSFL] eff_K=32020  compress=86.0%  Acc=0.2459  Loss=2.1034  TrainL=0.3861  K=32020  round=37.1s  total=889s
#
#   Round  25/200  (lr=0.00786)  [DSFL] eff_K=36126  compress=84.2%  Acc=0.3329  Loss=1.8866  TrainL=0.3486  K=36126  round=37.0s  total=926s
#
#   Round  26/200  (lr=0.00778)  [DSFL] eff_K=34225  compress=85.0%  Acc=0.3049  Loss=1.9112  TrainL=0.3405  K=34225  round=37.1s  total=963s
#
#   Round  27/200  (lr=0.00770)  [DSFL] eff_K=23472  compress=89.7%  Acc=0.2675  Loss=2.0669  TrainL=0.3421  K=23472  round=37.0s  total=1000s
#
#   Round  28/200  (lr=0.00762)  [DSFL] eff_K=38230  compress=83.2%  Acc=0.2953  Loss=1.9531  TrainL=0.3410  K=38230  round=37.1s  total=1037s
#
#   Round  29/200  (lr=0.00755)  [DSFL] eff_K=32447  compress=85.8%  Acc=0.4049  Loss=1.6453  TrainL=0.3474  K=32447  round=37.1s  total=1074s
#
#   Round  30/200  (lr=0.00747)  [DSFL] eff_K=42899  compress=81.2%  Acc=0.3724  Loss=1.7753  TrainL=0.3217  K=42899  round=37.1s  total=1111s
#
#   Round  31/200  (lr=0.00740)  [DSFL] eff_K=29354  compress=87.1%  Acc=0.4148  Loss=1.6249  TrainL=0.3253  K=29354  round=37.0s  total=1148s
#
#   Round  32/200  (lr=0.00732)  [DSFL] eff_K=37082  compress=83.7%  Acc=0.4527  Loss=1.5843  TrainL=0.3134  K=37082  round=37.0s  total=1185s
#
#   Round  33/200  (lr=0.00725)  [DSFL] eff_K=25335  compress=88.9%  Acc=0.3974  Loss=1.6534  TrainL=0.3087  K=25335  round=37.0s  total=1222s
#
#   Round  34/200  (lr=0.00718)  [DSFL] eff_K=34362  compress=84.9%  Acc=0.4057  Loss=1.5966  TrainL=0.3135  K=34362  round=37.0s  total=1259s
#
# ...
#
#   Round  98/200  (lr=0.00377)    [FEDS] K=34328  compress=84.9%  p_mean=0.500  Acc=0.4899  Loss=1.4192  TrainL=0.1829  K=34328  round=4.5s  total=437s
#
#   Round  99/200  (lr=0.00373)    [FEDS] K=34626  compress=84.8%  p_mean=0.500  Acc=0.5630  Loss=1.2350  TrainL=0.1925  K=34626  round=4.5s  total=442s
#
#   Round 100/200  (lr=0.00370)    [FEDS] K=24568  compress=89.2%  p_mean=0.500  Acc=0.4655  Loss=1.4467  TrainL=0.1784  K=24568  round=4.5s  total=446s
#
#   Round 101/200  (lr=0.00366)    [FEDS] K=30063  compress=86.8%  p_mean=0.500  Acc=0.5063  Loss=1.3790  TrainL=0.1909  K=30063  round=4.5s  total=451s
#
#   Round 102/200  (lr=0.00362)    [FEDS] K=40150  compress=82.4%  p_mean=0.500  Acc=0.5914  Loss=1.1846  TrainL=0.1830  K=40150  round=4.5s  total=455s
#
#   Round 103/200  (lr=0.00359)    [FEDS] K=28660  compress=87.4%  p_mean=0.500  Acc=0.5912  Loss=1.1598  TrainL=0.1749  K=28660  round=4.5s  total=460s
#
#   Round 104/200  (lr=0.00355)    [FEDS] K=25477  compress=88.8%  p_mean=0.500  Acc=0.5633  Loss=1.2284  TrainL=0.1732  K=25477  round=4.5s  total=464s
#
#   Round 105/200  (lr=0.00352)    [FEDS] K=25964  compress=88.6%  p_mean=0.500  Acc=0.6007  Loss=1.1565  TrainL=0.1756  K=25964  round=4.5s  total=469s
#
#   Round 106/200  (lr=0.00348)    [FEDS] K=31725  compress=86.1%  p_mean=0.500  Acc=0.5775  Loss=1.2052  TrainL=0.1745  K=31725  round=4.5s  total=473s
#
#   Round 107/200  (lr=0.00345)    [FEDS] K=34645  compress=84.8%  p_mean=0.500  Acc=0.6274  Loss=1.1047  TrainL=0.1706  K=34645  round=4.5s  total=478s
#
#   Round 108/200  (lr=0.00341)    [FEDS] K=42369  compress=81.4%  p_mean=0.500  Acc=0.5793  Loss=1.1892  TrainL=0.1663  K=42369  round=4.5s  total=482s
#
#   Round 109/200  (lr=0.00338)    [FEDS] K=25722  compress=88.7%  p_mean=0.500  Acc=0.5986  Loss=1.1618  TrainL=0.1693  K=25722  round=4.5s  total=487s
#
#   Round 110/200  (lr=0.00334)    [FEDS] K=29879  compress=86.9%  p_mean=0.500  Acc=0.5914  Loss=1.1461  TrainL=0.1702  K=29879  round=4.5s  total=491s
#
#   Round 111/200  (lr=0.00331)    [FEDS] K=32456  compress=85.8%  p_mean=0.500  Acc=0.5744  Loss=1.1957  TrainL=0.1733  K=32456  round=4.5s  total=496s
#
#   Round 112/200  (lr=0.00328)    [FEDS] K=33485  compress=85.3%  p_mean=0.500  Acc=0.5903  Loss=1.1630  TrainL=0.1767  K=33485  round=4.5s  total=500s
#
#   Round 113/200  (lr=0.00324)    [FEDS] K=35027  compress=84.6%  p_mean=0.500  Acc=0.5054  Loss=1.3870  TrainL=0.1702  K=35027  round=4.5s  total=504s
#
#   Round 114/200  (lr=0.00321)    [FEDS] K=36607  compress=83.9%  p_mean=0.500  Acc=0.5774  Loss=1.1797  TrainL=0.1808  K=36607  round=4.5s  total=509s
#
#   Round 115/200  (lr=0.00318)    [FEDS] K=18292  compress=92.0%  p_mean=0.500  Acc=0.5977  Loss=1.1565  TrainL=0.1680  K=18292  round=4.5s  total=513s
#
#   Round 116/200  (lr=0.00315)    [FEDS] K=28340  compress=87.6%  p_mean=0.500  Acc=0.5084  Loss=1.3738  TrainL=0.1692  K=28340  round=4.5s  total=518s
#
#   Round 117/200  (lr=0.00312)    [FEDS] K=26150  compress=88.5%  p_mean=0.500  Acc=0.5490  Loss=1.2395  TrainL=0.1856  K=26150  round=4.5s  total=522s
#
#   Round 118/200  (lr=0.00309)    [FEDS] K=26898  compress=88.2%  p_mean=0.500  Acc=0.5595  Loss=1.2518  TrainL=0.1692  K=26898  round=4.5s  total=527s
#
#   Round 119/200  (lr=0.00305)    [FEDS] K=33759  compress=85.2%  p_mean=0.500  Acc=0.5264  Loss=1.3082  TrainL=0.1728  K=33759  round=4.5s  total=531s
#
#   Round 120/200  (lr=0.00302)    [FEDS] K=25021  compress=89.0%  p_mean=0.500  Acc=0.5609  Loss=1.2448  TrainL=0.1751  K=25021  round=4.5s  total=536s
#
#   Round 121/200  (lr=0.00299)    [FEDS] K=27582  compress=87.9%  p_mean=0.500  Acc=0.5902  Loss=1.1647  TrainL=0.1690  K=27582  round=4.5s  total=540s
#
#   Round 122/200  (lr=0.00296)    [FEDS] K=28173  compress=87.6%  p_mean=0.500  Acc=0.5857  Loss=1.1776  TrainL=0.1625  K=28173  round=4.5s  total=545s
#
#   Round 123/200  (lr=0.00293)    [FEDS] K=17120  compress=92.5%  p_mean=0.500  Acc=0.5463  Loss=1.2480  TrainL=0.1713  K=17120  round=4.5s  total=549s
#
#   Round 124/200  (lr=0.00290)    [FEDS] K=28672  compress=87.4%  p_mean=0.500  Acc=0.5731  Loss=1.2538  TrainL=0.1687  K=28672  round=4.5s  total=554s
#
#   Round 125/200  (lr=0.00288)    [FEDS] K=31526  compress=86.2%  p_mean=0.500  Acc=0.6137  Loss=1.1301  TrainL=0.1724  K=31526  round=4.5s  total=558s
#
#   Round 126/200  (lr=0.00285)    [FEDS] K=31900  compress=86.0%  p_mean=0.500  Acc=0.5756  Loss=1.1860  TrainL=0.1610  K=31900  round=4.5s  total=562s
#
#   Round 127/200  (lr=0.00282)    [FEDS] K=27227  compress=88.1%  p_mean=0.500  Acc=0.5738  Loss=1.1868  TrainL=0.1607  K=27227  round=4.5s  total=567s
#
#   Round 128/200  (lr=0.00279)    [FEDS] K=31560  compress=86.2%  p_mean=0.500  Acc=0.5894  Loss=1.1863  TrainL=0.1612  K=31560  round=4.5s  total=571s
#
#   Round 129/200  (lr=0.00276)    [FEDS] K=23005  compress=89.9%  p_mean=0.500  Acc=0.5816  Loss=1.1687  TrainL=0.1624  K=23005  round=4.5s  total=576s
#
#   Round 130/200  (lr=0.00273)    [FEDS] K=33946  compress=85.1%  p_mean=0.500  Acc=0.5969  Loss=1.1722  TrainL=0.1588  K=33946  round=4.5s  total=580s
#
#   Round 131/200  (lr=0.00271)    [FEDS] K=27345  compress=88.0%  p_mean=0.500  Acc=0.5710  Loss=1.2424  TrainL=0.1597  K=27345  round=4.5s  total=585s
#
#   Round 132/200  (lr=0.00268)    [FEDS] K=24648  compress=89.2%  p_mean=0.500  Acc=0.5224  Loss=1.2949  TrainL=0.1657  K=24648  round=4.5s  total=589s
#
#   Round 133/200  (lr=0.00265)    [FEDS] K=39721  compress=82.6%  p_mean=0.500  Acc=0.5514  Loss=1.2097  TrainL=0.1705  K=39721  round=4.5s  total=594s
#
#   Round 134/200  (lr=0.00263)    [FEDS] K=29088  compress=87.2%  p_mean=0.500  Acc=0.5951  Loss=1.1497  TrainL=0.1581  K=29088  round=4.5s  total=598s
#
#   Round 135/200  (lr=0.00260)    [FEDS] K=28200  compress=87.6%  p_mean=0.500  Acc=0.5752  Loss=1.1832  TrainL=0.1563  K=28200  round=4.5s  total=603s
#
#   Round 136/200  (lr=0.00257)    [FEDS] K=20232  compress=91.1%  p_mean=0.500  Acc=0.6212  Loss=1.0928  TrainL=0.1588  K=20232  round=4.5s  total=607s
#
#   Round 137/200  (lr=0.00255)    [FEDS] K=35555  compress=84.4%  p_mean=0.500  Acc=0.5844  Loss=1.1758  TrainL=0.1547  K=35555  round=4.5s  total=612s
#
#   Round 138/200  (lr=0.00252)    [FEDS] K=31794  compress=86.1%  p_mean=0.500  Acc=0.6017  Loss=1.1272  TrainL=0.1538  K=31794  round=4.5s  total=616s
#
#   Round 139/200  (lr=0.00250)    [FEDS] K=31577  compress=86.2%  p_mean=0.500  Acc=0.5502  Loss=1.2690  TrainL=0.1549  K=31577  round=4.5s  total=620s
#
#   Round 140/200  (lr=0.00247)    [FEDS] K=30476  compress=86.6%  p_mean=0.500  Acc=0.6007  Loss=1.1291  TrainL=0.1602  K=30476  round=4.5s  total=625s
#
#   Round 141/200  (lr=0.00245)    [FEDS] K=45985  compress=79.8%  p_mean=0.500  Acc=0.6032  Loss=1.1233  TrainL=0.1577  K=45985  round=4.5s  total=629s
#
#   Round 142/200  (lr=0.00242)    [FEDS] K=23448  compress=89.7%  p_mean=0.500  Acc=0.6311  Loss=1.0731  TrainL=0.1513  K=23448  round=4.5s  total=634s
#
#   Round 143/200  (lr=0.00240)    [FEDS] K=35814  compress=84.3%  p_mean=0.500  Acc=0.6040  Loss=1.1385  TrainL=0.1508  K=35814  round=4.4s  total=638s
#
#   Round 144/200  (lr=0.00238)    [FEDS] K=20736  compress=90.9%  p_mean=0.500  Acc=0.5904  Loss=1.1674  TrainL=0.1530  K=20736  round=4.5s  total=643s
#
#   Round 145/200  (lr=0.00235)    [FEDS] K=33775  compress=85.2%  p_mean=0.500  Acc=0.5433  Loss=1.2420  TrainL=0.1534  K=33775  round=4.5s  total=647s
#
#   Round 146/200  (lr=0.00233)    [FEDS] K=26256  compress=88.5%  p_mean=0.500  Acc=0.5913  Loss=1.1519  TrainL=0.1579  K=26256  round=4.5s  total=652s
#
#   Round 147/200  (lr=0.00231)    [FEDS] K=32213  compress=85.9%  p_mean=0.500  Acc=0.5877  Loss=1.1558  TrainL=0.1544  K=32213  round=4.5s  total=656s
#
#   Round 148/200  (lr=0.00228)    [FEDS] K=29040  compress=87.3%  p_mean=0.500  Acc=0.6154  Loss=1.1138  TrainL=0.1514  K=29040  round=4.5s  total=661s
#
#   Round 149/200  (lr=0.00226)    [FEDS] K=32699  compress=85.7%  p_mean=0.500  Acc=0.6136  Loss=1.0938  TrainL=0.1484  K=32699  round=4.4s  total=665s
#
#   Round 150/200  (lr=0.00224)    [FEDS] K=33916  compress=85.1%  p_mean=0.500  Acc=0.5978  Loss=1.1275  TrainL=0.1489  K=33916  round=4.5s  total=669s
#
#   Round 151/200  (lr=0.00221)    [FEDS] K=25964  compress=88.6%  p_mean=0.500  Acc=0.5942  Loss=1.1485  TrainL=0.1484  K=25964  round=4.5s  total=674s
#
#   Round 152/200  (lr=0.00219)    [FEDS] K=26276  compress=88.5%  p_mean=0.500  Acc=0.5963  Loss=1.1299  TrainL=0.1508  K=26276  round=4.5s  total=678s
#
#   Round 153/200  (lr=0.00217)    [FEDS] K=28143  compress=87.7%  p_mean=0.500  Acc=0.6080  Loss=1.1228  TrainL=0.1481  K=28143  round=4.5s  total=683s
#
#   Round 154/200  (lr=0.00215)    [FEDS] K=23160  compress=89.8%  p_mean=0.500  Acc=0.5872  Loss=1.1777  TrainL=0.1556  K=23160  round=4.5s  total=687s
#
#   Round 155/200  (lr=0.00213)    [FEDS] K=29957  compress=86.9%  p_mean=0.500  Acc=0.6163  Loss=1.1068  TrainL=0.1482  K=29957  round=4.5s  total=692s
#
#   Round 156/200  (lr=0.00211)    [FEDS] K=36468  compress=84.0%  p_mean=0.500  Acc=0.5640  Loss=1.2116  TrainL=0.1504  K=36468  round=4.5s  total=696s
#
#   Round 157/200  (lr=0.00208)    [FEDS] K=37932  compress=83.4%  p_mean=0.500  Acc=0.5584  Loss=1.2503  TrainL=0.1542  K=37932  round=4.5s  total=701s
#
#   Round 158/200  (lr=0.00206)    [FEDS] K=28134  compress=87.7%  p_mean=0.500  Acc=0.5869  Loss=1.1621  TrainL=0.1549  K=28134  round=4.5s  total=705s
#
#   Round 159/200  (lr=0.00204)    [FEDS] K=27060  compress=88.1%  p_mean=0.500  Acc=0.6181  Loss=1.0935  TrainL=0.1513  K=27060  round=4.5s  total=710s
#
#   Round 160/200  (lr=0.00202)    [FEDS] K=30842  compress=86.5%  p_mean=0.500  Acc=0.5929  Loss=1.1496  TrainL=0.1468  K=30842  round=4.5s  total=714s
#
#   Round 161/200  (lr=0.00200)    [FEDS] K=29897  compress=86.9%  p_mean=0.500  Acc=0.5572  Loss=1.2108  TrainL=0.1485  K=29897  round=4.5s  total=718s
#
#   Round 162/200  (lr=0.00198)    [FEDS] K=22478  compress=90.1%  p_mean=0.500  Acc=0.6135  Loss=1.1053  TrainL=0.1508  K=22478  round=4.5s  total=723s
#
#   Round 163/200  (lr=0.00196)    [FEDS] K=37928  compress=83.4%  p_mean=0.500  Acc=0.5930  Loss=1.1518  TrainL=0.1474  K=37928  round=4.5s  total=727s
#
#   Round 164/200  (lr=0.00194)    [FEDS] K=28576  compress=87.5%  p_mean=0.500  Acc=0.6161  Loss=1.1140  TrainL=0.1456  K=28576  round=4.5s  total=732s
#
#   Round 165/200  (lr=0.00192)    [FEDS] K=22793  compress=90.0%  p_mean=0.500  Acc=0.5912  Loss=1.1435  TrainL=0.1483  K=22793  round=4.5s  total=736s
#
#   Round 166/200  (lr=0.00190)    [FEDS] K=32426  compress=85.8%  p_mean=0.500  Acc=0.6022  Loss=1.1226  TrainL=0.1473  K=32426  round=4.5s  total=741s
#
#   Round 167/200  (lr=0.00189)    [FEDS] K=34960  compress=84.7%  p_mean=0.500  Acc=0.6150  Loss=1.0961  TrainL=0.1475  K=34960  round=4.5s  total=745s
#
#   Round 168/200  (lr=0.00187)    [FEDS] K=27687  compress=87.9%  p_mean=0.500  Acc=0.5840  Loss=1.1618  TrainL=0.1459  K=27687  round=4.5s  total=750s
#
#   Round 169/200  (lr=0.00185)    [FEDS] K=38056  compress=83.3%  p_mean=0.500  Acc=0.6153  Loss=1.0952  TrainL=0.1445  K=38056  round=4.5s  total=754s
#
#   Round 170/200  (lr=0.00183)    [FEDS] K=38356  compress=83.2%  p_mean=0.500  Acc=0.6047  Loss=1.1141  TrainL=0.1441  K=38356  round=4.5s  total=759s
#
#   Round 171/200  (lr=0.00181)    [FEDS] K=38426  compress=83.1%  p_mean=0.500  Acc=0.6007  Loss=1.1332  TrainL=0.1442  K=38426  round=4.5s  total=763s
#
#   Round 172/200  (lr=0.00179)    [FEDS] K=21103  compress=90.7%  p_mean=0.500  Acc=0.5766  Loss=1.1924  TrainL=0.1451  K=21103  round=4.5s  total=768s
#
#   Round 173/200  (lr=0.00178)    [FEDS] K=35110  compress=84.6%  p_mean=0.500  Acc=0.6131  Loss=1.1137  TrainL=0.1462  K=35110  round=4.5s  total=772s
#
#   Round 174/200  (lr=0.00176)    [FEDS] K=28913  compress=87.3%  p_mean=0.500  Acc=0.6074  Loss=1.1167  TrainL=0.1465  K=28913  round=4.5s  total=776s
#
#   Round 175/200  (lr=0.00174)    [FEDS] K=38642  compress=83.1%  p_mean=0.500  Acc=0.5965  Loss=1.1349  TrainL=0.1453  K=38642  round=4.5s  total=781s
#
#   Round 176/200  (lr=0.00172)    [FEDS] K=20102  compress=91.2%  p_mean=0.500  Acc=0.5940  Loss=1.1666  TrainL=0.1446  K=20102  round=4.5s  total=785s
#
#   Round 177/200  (lr=0.00171)    [FEDS] K=33272  compress=85.4%  p_mean=0.500  Acc=0.5866  Loss=1.1514  TrainL=0.1450  K=33272  round=4.5s  total=790s
#
#   Round 178/200  (lr=0.00169)    [FEDS] K=25568  compress=88.8%  p_mean=0.500  Acc=0.5913  Loss=1.1430  TrainL=0.1447  K=25568  round=4.5s  total=794s
#
#   Round 179/200  (lr=0.00167)    [FEDS] K=29561  compress=87.0%  p_mean=0.500  Acc=0.6183  Loss=1.0916  TrainL=0.1477  K=29561  round=4.5s  total=799s
#
#   Round 180/200  (lr=0.00165)    [FEDS] K=24587  compress=89.2%  p_mean=0.500  Acc=0.5993  Loss=1.1108  TrainL=0.1429  K=24587  round=4.5s  total=803s
#
#   Round 181/200  (lr=0.00164)    [FEDS] K=29892  compress=86.9%  p_mean=0.500  Acc=0.6031  Loss=1.1268  TrainL=0.1425  K=29892  round=4.5s  total=808s
#
#   Round 182/200  (lr=0.00162)    [FEDS] K=33073  compress=85.5%  p_mean=0.500  Acc=0.5940  Loss=1.1353  TrainL=0.1419  K=33073  round=4.5s  total=812s
#
#   Round 183/200  (lr=0.00161)    [FEDS] K=25419  compress=88.9%  p_mean=0.500  Acc=0.5818  Loss=1.1669  TrainL=0.1431  K=25419  round=4.5s  total=817s
#
#   Round 184/200  (lr=0.00159)    [FEDS] K=26699  compress=88.3%  p_mean=0.500  Acc=0.5893  Loss=1.1428  TrainL=0.1462  K=26699  round=4.5s  total=821s
#
#   Round 185/200  (lr=0.00157)    [FEDS] K=34224  compress=85.0%  p_mean=0.500  Acc=0.5850  Loss=1.1454  TrainL=0.1471  K=34224  round=4.5s  total=826s
#
#   Round 186/200  (lr=0.00156)    [FEDS] K=45088  compress=80.2%  p_mean=0.500  Acc=0.5916  Loss=1.1538  TrainL=0.1441  K=45088  round=4.5s  total=830s
#
#   Round 187/200  (lr=0.00154)    [FEDS] K=38490  compress=83.1%  p_mean=0.500  Acc=0.6023  Loss=1.1142  TrainL=0.1445  K=38490  round=4.5s  total=834s
#
#   Round 188/200  (lr=0.00153)    [FEDS] K=25878  compress=88.7%  p_mean=0.500  Acc=0.6061  Loss=1.1183  TrainL=0.1421  K=25878  round=4.5s  total=839s
#
#   Round 189/200  (lr=0.00151)    [FEDS] K=17790  compress=92.2%  p_mean=0.500  Acc=0.5723  Loss=1.1905  TrainL=0.1410  K=17790  round=4.5s  total=843s
#
#   Round 190/200  (lr=0.00150)    [FEDS] K=27755  compress=87.8%  p_mean=0.500  Acc=0.6306  Loss=1.0782  TrainL=0.1425  K=27755  round=4.5s  total=848s
#
#   Round 191/200  (lr=0.00148)    [FEDS] K=28990  compress=87.3%  p_mean=0.500  Acc=0.5745  Loss=1.1916  TrainL=0.1445  K=28990  round=4.5s  total=852s
#
#   Round 192/200  (lr=0.00147)    [FEDS] K=19362  compress=91.5%  p_mean=0.500  Acc=0.5830  Loss=1.1839  TrainL=0.1437  K=19362  round=4.5s  total=857s
#
#   Round 193/200  (lr=0.00145)    [FEDS] K=27896  compress=87.8%  p_mean=0.500  Acc=0.5843  Loss=1.1749  TrainL=0.1437  K=27896  round=4.5s  total=861s
#
#   Round 194/200  (lr=0.00144)    [FEDS] K=30805  compress=86.5%  p_mean=0.500  Acc=0.5986  Loss=1.1258  TrainL=0.1425  K=30805  round=4.5s  total=866s
#
#   Round 195/200  (lr=0.00142)    [FEDS] K=41312  compress=81.9%  p_mean=0.500  Acc=0.6395  Loss=1.0459  TrainL=0.1433  K=41312  round=4.5s  total=870s
#
#   Round 196/200  (lr=0.00141)    [FEDS] K=28593  compress=87.5%  p_mean=0.500  Acc=0.5448  Loss=1.2793  TrainL=0.1475  K=28593  round=4.5s  total=875s
#
#   Round 197/200  (lr=0.00139)    [FEDS] K=31125  compress=86.4%  p_mean=0.500  Acc=0.5848  Loss=1.1568  TrainL=0.1426  K=31125  round=4.5s  total=879s
#
#   Round 198/200  (lr=0.00138)    [FEDS] K=36479  compress=84.0%  p_mean=0.500  Acc=0.6081  Loss=1.0970  TrainL=0.1421  K=36479  round=4.5s  total=884s
#
#   Round 199/200  (lr=0.00137)    [FEDS] K=24817  compress=89.1%  p_mean=0.500  Acc=0.6172  Loss=1.0907  TrainL=0.1408  K=24817  round=4.5s  total=888s
#
#   Round 200/200  (lr=0.00135)    [FEDS] K=31482  compress=86.2%  p_mean=0.500  Acc=0.5979  Loss=1.1258  TrainL=0.1415  K=31482  round=4.5s  total=893s
#
#   ✅ FEDS done — 14.9 min  | Final acc: 0.5979
#
# Summary:
# FedAvg           best=64.03% final=62.09% comm_save=N/A t=14.7m
# Fixed Top-K      best=60.63% final=54.20% comm_save=97.1% t=14.8m
# DSFL             best=58.99% final=51.93% comm_save=85.2% t=123.5m
# FEDS (Ours)      best=63.95% final=59.79% comm_save=85.0% t=14.9m

# %% [markdown]
# ## Cell 7 - Figures

# %%
import matplotlib, matplotlib.pyplot as plt
matplotlib.rcParams.update({
    "font.family":"serif","font.serif":["Times New Roman","DejaVu Serif"],
    "font.size":11,"axes.titlesize":12,"axes.labelsize":11,
    "xtick.labelsize":10,"ytick.labelsize":10,"legend.fontsize":10,
    "figure.dpi":150,"axes.grid":True,"grid.alpha":0.3,
    "grid.linestyle":"--","axes.spines.top":False,"axes.spines.right":False,
})
COLORS={"fedavg":"#2166ac","fixed_topk":"#d6604d","dsfl":"#f4a582","feds":"#1a9641"}
LABELS={"fedavg":"FedAvg","fixed_topk":"Fixed Top-K","dsfl":"DSFL","feds":"FEDS (Ours)"}
LS={"fedavg":":","fixed_topk":"-.","dsfl":"--","feds":"-"}
MK={"fedavg":"s","fixed_topk":"D","dsfl":"^","feds":"o"}
EV=max(1,NUM_ROUNDS//10)
W=EMA_SMOOTH

def ema_smooth(vals, window=10):
    alpha=2.0/(window+1); out=[vals[0]]
    for v in vals[1:]: out.append(alpha*v+(1-alpha)*out[-1])
    return out

def save_fig(name):
    for ext in ["pdf","png"]:
        plt.savefig(f"{RESULTS_DIR}/figures/{name}.{ext}",bbox_inches="tight",dpi=300 if ext=="png" else None)
    print(f"Saved {name}")

# Fig 1: Accuracy + Loss
fig,axes=plt.subplots(1,2,figsize=(10,3.5))
fig.suptitle(f"{DATASET} | Non-IID | {NUM_CLIENTS} clients | a={ALPHA_COMM} g={GAMMA_COMM}",fontsize=12,fontweight="bold")
for m,log in all_logs.items():
    r=log["round"]
    acc_raw=[a*100 for a in log["accuracy"]]
    loss_raw=log["loss"]
    acc_sm=ema_smooth(acc_raw,W); loss_sm=ema_smooth(loss_raw,W)
    axes[0].plot(r,acc_raw,color=COLORS[m],alpha=0.15,lw=0.8,ls=LS[m])
    axes[1].plot(r,loss_raw,color=COLORS[m],alpha=0.15,lw=0.8,ls=LS[m])
    kw=dict(color=COLORS[m],ls=LS[m],lw=2,label=LABELS[m],marker=MK[m],markevery=EV,ms=5)
    axes[0].plot(r,acc_sm,**kw); axes[1].plot(r,loss_sm,**kw)
axes[0].set(xlabel="Round",ylabel="Test Accuracy (%)",title="(a) Test Accuracy")
axes[0].legend(loc="lower right")
axes[1].set(xlabel="Round",ylabel="Test Loss",title="(b) Test Loss")
axes[1].legend(loc="upper right")
plt.tight_layout(); save_fig(f"fig1_acc_loss_{DATASET}"); plt.show()

# Fig 2: K trajectory
if "feds" in all_logs and "dsfl" in all_logs:
    fig,axes=plt.subplots(1,2,figsize=(10,3.5))
    fig.suptitle(f"FEDS vs DSFL K - {DATASET}",fontsize=12,fontweight="bold")
    r=all_logs["feds"]["round"]
    ka_raw=np.array(all_logs["feds"]["k_mean"])
    ks=np.array(all_logs["feds"]["k_std"])
    kd_raw=np.array(all_logs["dsfl"]["k_mean"])
    ka_sm=np.array(ema_smooth(ka_raw.tolist(),W))
    kd_sm=np.array(ema_smooth(kd_raw.tolist(),W))
    axes[0].plot(r,ka_raw,color=COLORS["feds"],alpha=0.15,lw=0.8)
    axes[0].plot(r,ka_sm,color=COLORS["feds"],lw=2,label="FEDS K")
    axes[0].fill_between(r,ka_sm-ks,ka_sm+ks,alpha=0.15,color=COLORS["feds"])
    axes[0].plot(r,kd_sm,color=COLORS["dsfl"],ls="--",lw=1.5,label="DSFL K")
    axes[0].axvline(COMP_WARMUP,color="gray",ls=":",lw=1,label="Warmup end")
    axes[0].set(xlabel="Round",ylabel="K",title="(a) K per round"); axes[0].legend(fontsize=9)
    sv=[(1-a/b)*100 if b>0 else 0 for a,b in zip(ka_raw,kd_raw)]
    sv_sm=ema_smooth(sv,W)
    axes[1].plot(r,sv,color=COLORS["feds"],alpha=0.15,lw=0.8)
    axes[1].plot(r,sv_sm,color=COLORS["feds"],lw=2)
    axes[1].axhline(0,color="gray",ls="--",lw=1)
    axes[1].fill_between(r,0,sv_sm,where=[s>0 for s in sv_sm],alpha=0.2,color=COLORS["feds"])
    axes[1].set(xlabel="Round",ylabel="Comm. Saving vs DSFL (%)",title="(b) Savings over DSFL")
    plt.tight_layout(); save_fig(f"fig2_k_{DATASET}"); plt.show()

# Fig 3: Convergence
fig,ax=plt.subplots(figsize=(5.5,3.5))
fig.suptitle(f"Rounds to Convergence - {DATASET}",fontsize=12,fontweight="bold")
max_acc=max(max(log["accuracy"]) for log in all_logs.values())
targets=[t for t in np.arange(0.1,max_acc,0.1) if t<max_acc]
for m,log in all_logs.items():
    acc_sm=ema_smooth(log["accuracy"],W); pts,seen=[],set()
    for tgt in targets:
        for ri,a in enumerate(acc_sm):
            if a>=tgt and tgt not in seen: pts.append((tgt*100,ri+1)); seen.add(tgt); break
    if pts:
        ts,rs=zip(*pts)
        ax.plot(ts,rs,color=COLORS[m],ls=LS[m],lw=2,marker=MK[m],ms=6,label=LABELS[m])
ax.set(xlabel="Target Accuracy (%)",ylabel="Rounds to reach target")
ax.legend(); plt.tight_layout(); save_fig(f"fig3_conv_{DATASET}"); plt.show()
print("All figures saved")
# Out:
# Saved fig1_acc_loss_CIFAR10
# Saved fig2_k_CIFAR10
# Saved fig3_conv_CIFAR10
# All figures saved

# %% [markdown]
# ## Cell 8 — 📋 Table (LaTeX + CSV)

# %%
import pandas as pd

LABELS = {'fedavg':'FedAvg','fixed_topk':'Fixed Top-K',
          'dsfl':'DSFL','feds':'FEDS (Ours)'}
d = next(iter(all_logs.values()))['total_params']
rows = []
for m, log in all_logs.items():
    acc = np.array(log['accuracy'])
    km  = np.array(log['k_mean'])
    rows.append({
        'Method'        : LABELS[m],
        'Best Acc (%)'  : f'{acc.max()*100:.2f}',
        'Best Round'    : int(np.argmax(acc))+1,
        'Final Acc (%)' : f'{acc[-1]*100:.2f}',
        'Final Loss'    : f'{log["loss"][-1]:.4f}',
        'Avg K'         : f'{km.mean():.0f}' if m!='fedavg' else 'N/A',
        'Comm. Saving'  : f'{(1-km.mean()/d)*100:.1f}%' if m!='fedavg' else 'N/A',
        'Time (min)'    : f'{log["total_time"]/60:.1f}',
    })

df = pd.DataFrame(rows)
print(df.to_string(index=False))
df.to_csv(f'{RESULTS_DIR}/tables/results_{DATASET}.csv', index=False)

latex = df.to_latex(
    index=False, escape=False,
    caption=f'{DATASET} (Non-IID, {NUM_CLIENTS} clients, {NUM_ROUNDS} rounds, '
            f'α={ALPHA_COMM}, γ={GAMMA_COMM}).',
    label=f'tab:{DATASET.lower()}',
    column_format='l' + 'c'*(len(df.columns)-1)
).replace('FEDS (Ours)', '\\textbf{FEDS (Ours)}')

with open(f'{RESULTS_DIR}/tables/results_{DATASET}.tex', 'w') as f:
    f.write(latex)
print('\n── LaTeX ─────────────────────────────────────────────────')
print(latex)
# Out:
#      Method Best Acc (%)  Best Round Final Acc (%) Final Loss Avg K Comm. Saving Time (min)
#      FedAvg        64.03         121         62.09     1.0738   N/A          N/A       14.7
# Fixed Top-K        60.63         191         54.20     1.2295  6542        97.1%       14.8
#        DSFL        58.99         188         51.93     1.4167 33655        85.2%      123.5
# FEDS (Ours)        63.95         195         59.79     1.1258 34119        85.0%       14.9
#
# ── LaTeX ─────────────────────────────────────────────────
# \begin{table}
# \caption{CIFAR10 (Non-IID, 10 clients, 200 rounds, α=10, γ=10).}
# \label{tab:cifar10}
# \begin{tabular}{lccccccc}
# \toprule
# Method & Best Acc (%) & Best Round & Final Acc (%) & Final Loss & Avg K & Comm. Saving & Time (min) \\
# \midrule
# FedAvg & 64.03 & 121 & 62.09 & 1.0738 & N/A & N/A & 14.7 \\
# Fixed Top-K & 60.63 & 191 & 54.20 & 1.2295 & 6542 & 97.1% & 14.8 \\
# DSFL & 58.99 & 188 & 51.93 & 1.4167 & 33655 & 85.2% & 123.5 \\
# \textbf{FEDS (Ours)} & 63.95 & 195 & 59.79 & 1.1258 & 34119 & 85.0% & 14.9 \\
# \bottomrule
# \end{tabular}
# \end{table}
