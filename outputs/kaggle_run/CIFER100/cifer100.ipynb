# %% [markdown]
# # FEDS v11 — CIFAR-100 (Dirichlet) replaces Speech
#
# ## Datasets
# - **MNIST**: UnifiedNet(1ch, 10cls) — label-pair non-IID
# - **CIFAR-10**: UnifiedNet(3ch, 10cls) — label-pair non-IID
# - **CIFAR-100**: UnifiedNet(3ch, 100cls) — Dirichlet(alpha=0.5) non-IID
#
# ## Why CIFAR-100 + Dirichlet
# - Standard benchmark in recent FL literature (FedLN, FedFN etc.)
# - Dir(0.5) creates realistic heterogeneity across 100 classes
# - Same UnifiedNet architecture — only output layer changes (10->100)
# - Harder task = variance signal more informative = FEDS advantage clearer
# - No variable-length audio issues, no separate architecture
#
# ## Algorithm (unchanged from v10)
#     CLIENT: phi_j = |delta_j| * p_j[t-1]  -> top-K
#     SERVER: p[t]  = rank_norm(Var_i(delta_i_j))  -> broadcast
#
# **Run:** Cell 1 -> 2 -> 3 -> 4 -> 5 (smoke) -> 6 (full)

# %%
import subprocess, sys, os
IS_COLAB  = 'google.colab' in sys.modules or os.path.exists('/content')
IS_KAGGLE = os.path.exists('/kaggle')
PLATFORM  = 'colab' if IS_COLAB else ('kaggle' if IS_KAGGLE else 'local')
print(f'Platform: {PLATFORM}')
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                'torch', 'torchvision', 'torchaudio',
                'numpy', 'matplotlib', 'scipy', 'pandas'])
import torch, numpy as np
print(f'PyTorch : {torch.__version__}')
if torch.cuda.is_available():
    print(f'GPU     : {torch.cuda.get_device_name(0)}')
    print(f'VRAM    : {torch.cuda.get_device_properties(0).total_memory/1e9:.1f} GB')
    # Warm up CUDA context
    _ = torch.zeros(1).cuda()
    torch.cuda.synchronize()
    print('CUDA context warmed up ✅')
else:
    print('⚠️  No GPU — will run on CPU (slow)')
print('✅ ready')
# Out:
# Platform: colab
# PyTorch : 2.9.0+cu126
# GPU     : Tesla T4
# VRAM    : 15.6 GB
# CUDA context warmed up ✅
# ✅ ready

# %%
# Options: 'MNIST' | 'CIFAR10' | 'CIFAR100'
DATASET      = 'CIFAR100'

NUM_ROUNDS   = 200
NUM_CLIENTS  = 10
LOCAL_EPOCHS = 1
BATCH_SIZE   = 256

LR           = 0.01
LR_DECAY     = 0.99
LR_MIN       = 1e-4
SEED         = 42

ALPHA_COMM      = 10    # communication heterogeneity
GAMMA_COMM      = 10
DIRICHLET_ALPHA = 0.5   # data heterogeneity for CIFAR-100
COMP_WARMUP     = 20
CKA_BATCHES     = 2     # DSFL baseline only
FEDS_EMA        = 0.7
EMA_SMOOTH      = 10    # figure smoothing window

RESULTS_DIR  = f'results_{DATASET}'
import torch, os, numpy as np
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
for sub in ['figures','tables','data']: os.makedirs(f'{RESULTS_DIR}/{sub}',exist_ok=True)
if DEVICE == 'cuda': torch.backends.cudnn.benchmark = True

print(f'Dataset : {DATASET}  Rounds: {NUM_ROUNDS}  Clients: {NUM_CLIENTS}')
print(f'Batch   : {BATCH_SIZE}  LR: {LR}  decay={LR_DECAY}')
print(f'alpha_comm={ALPHA_COMM}  gamma={GAMMA_COMM}  warmup={COMP_WARMUP}')
print(f'Dirichlet alpha={DIRICHLET_ALPHA}  (CIFAR100 only)')
print(f'FEDS_EMA={FEDS_EMA}  CKA_BATCHES={CKA_BATCHES} (DSFL only)')
print(f'Device  : {DEVICE}')
# Out:
# Dataset : CIFAR100  Rounds: 200  Clients: 10
# Batch   : 256  LR: 0.01  decay=0.99
# alpha_comm=10  gamma=10  warmup=20
# Dirichlet alpha=0.5  (CIFAR100 only)
# FEDS_EMA=0.7  CKA_BATCHES=2 (DSFL only)
# Device  : cuda

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision.datasets import MNIST, CIFAR10, CIFAR100
from torch.utils.data import DataLoader, Dataset
import numpy as np
import copy, json, time, random, pickle, os
from collections import OrderedDict
from scipy.stats import truncnorm


# ═══════════════════════════════════════════════════════
# REPRODUCIBILITY
# ═══════════════════════════════════════════════════════
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    # NOTE: benchmark=True (set in config) is faster but slightly non-deterministic
    # Set deterministic=True here only if exact reproducibility is required
    torch.backends.cudnn.deterministic = False


# ═══════════════════════════════════════════════════════
# MODELS — exact architectures from DSFL paper
# ═══════════════════════════════════════════════════════
class UnifiedNet(nn.Module):
    """
    Unified CNN for MNIST and CIFAR-10.
    ~226K parameters regardless of dataset.
    Handles 1-channel (MNIST) and 3-channel (CIFAR-10) input.
    AdaptiveAvgPool ensures same FC input size across spatial dims.

    MNIST : 1x28x28 -> ... -> 512 -> 256 -> 10
    CIFAR : 3x32x32 -> ... -> 512 -> 256 -> 10

    Approx param count:
      conv1: C_in*32*3*3  (288 or 864)
      conv2: 32*64*3*3    = 18,432
      conv3: 64*128*3*3   = 73,728
      BN layers:          ~ 384
      fc1: 512*256        = 131,072
      fc2: 256*num_cls    = 2,560 (CIFAR-10) or 2,560 (MNIST)
      Total               ~ 226K
    """
    def __init__(self, in_channels=3, num_classes=10):
        super().__init__()
        self.features = nn.Sequential(
            # Block 1
            nn.Conv2d(in_channels, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            # Block 2
            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            # Block 3
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d(2),   # -> [B, 128, 2, 2] = 512
        )
        self.classifier = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, num_classes),
        )
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)



def get_model(dataset):
    if dataset == 'MNIST':    return UnifiedNet(in_channels=1, num_classes=10)
    if dataset == 'CIFAR10':  return UnifiedNet(in_channels=3, num_classes=10)
    if dataset == 'CIFAR100': return UnifiedNet(in_channels=3, num_classes=100)
    raise ValueError(dataset)



# ═══════════════════════════════════════════════════════
# DATA — label-pair non-IID (DSFL paper Section V)
# ═══════════════════════════════════════════════════════
class IndexedDataset(Dataset):
    def __init__(self, base, idx):
        self.base = base
        self.idx  = np.asarray(idx)
    def __len__(self):  return len(self.idx)
    def __getitem__(self, i): return self.base[int(self.idx[i])]


def label_pair_partition(dataset, num_clients, num_classes, rng):
    if hasattr(dataset, 'targets'):
        targets = np.array(dataset.targets)
    elif hasattr(dataset, 'labels'):
        targets = np.array(dataset.labels)
    else:
        targets = np.array([dataset[i][1] for i in range(len(dataset))])
    parts = []
    for cid in range(num_clients):
        la  = cid % num_classes
        lb  = (cid + 1) % num_classes
        idx = np.where((targets == la) | (targets == lb))[0].copy()
        rng.shuffle(idx)
        parts.append(idx)
    return parts



# ============================================================
# GPU TENSOR CACHE  —  THE REAL FIX FOR 26s/round
#
# Root cause: MNISTNet is 582K params. Each batch takes ~0.3ms
# GPU compute. But DataLoader transfers take ~100ms/batch.
# 230 batches/round x 100ms = 23s WASTED on CPU->GPU transfers.
#
# Fix: load entire dataset into GPU RAM ONCE before training.
# MNIST:  10 clients x ~6k x (1x28x28) x fp32 = 188MB (of 15GB)
# CIFAR10:10 clients x ~5k x (3x32x32) x fp32 = 565MB (of 15GB)
# Speech: variable-length, falls back to DataLoader
# ============================================================
class GPUTensorLoader:
    """Pre-batched GPU tensors. Zero CPU-GPU transfer during training."""
    def __init__(self, X_gpu, Y_gpu, batch_size, seed=0):
        self.X=X_gpu; self.Y=Y_gpu; self.bs=batch_size
        self.gen=torch.Generator(device=X_gpu.device); self.gen.manual_seed(seed)
        self.n=X_gpu.shape[0]
    def __iter__(self):
        idx=torch.randperm(self.n, device=self.X.device, generator=self.gen)
        for s in range(0, self.n-self.bs+1, self.bs):
            b=idx[s:s+self.bs]; yield self.X[b], self.Y[b]
    def __len__(self): return self.n // self.bs


def build_loaders(dataset_name, num_clients, seed, batch_size,
                  partition_dir='partitions', device='cpu',
                  dirichlet_alpha=0.5):
    os.makedirs(partition_dir, exist_ok=True)
    cache = f'{partition_dir}/{dataset_name}_nc{num_clients}_seed{seed}.pkl'
    rng   = np.random.default_rng(seed)

    if dataset_name == 'MNIST':
        tf = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.1307,),(0.3081,))])
        train_ds=MNIST('/tmp/data',train=True, download=True,transform=tf)
        test_ds =MNIST('/tmp/data',train=False,download=True,transform=tf)
        num_classes=10

    elif dataset_name == 'CIFAR10':
        tf = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.5,)*3,(0.5,)*3)])
        train_ds=CIFAR10('/tmp/data',train=True, download=True,transform=tf)
        test_ds =CIFAR10('/tmp/data',train=False,download=True,transform=tf)
        num_classes=10

    else:  # CIFAR100 with Dirichlet partition
        tf = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5071,0.4867,0.4408),(0.2675,0.2565,0.2761))
        ])
        train_ds=CIFAR100('/tmp/data',train=True, download=True,transform=tf)
        test_ds =CIFAR100('/tmp/data',train=False,download=True,transform=tf)
        num_classes=100

    # Partition — Dirichlet for CIFAR100, label-pair for others
    if os.path.exists(cache):
        print('  Loaded partition cache')
        with open(cache,'rb') as f: tr_parts=pickle.load(f)
    else:
        if dataset_name == 'CIFAR100':
            print(f'  Creating Dirichlet(alpha={dirichlet_alpha}) partition...')
            tr_parts=dirichlet_partition(train_ds,num_clients,num_classes,
                                         dirichlet_alpha,rng)
        else:
            print('  Creating label-pair partition...')
            tr_parts=label_pair_partition(train_ds,num_clients,num_classes,rng)
        tgts=np.array(train_ds.targets)
        for cid,idx in enumerate(tr_parts):
            labs,cnt=np.unique(tgts[idx],return_counts=True)
            print(f'  Client {cid}: {len(labs)} classes  n={len(idx)}')
        with open(cache,'wb') as f: pickle.dump(tr_parts,f)

    # Preload FULL dataset to GPU once
    print('  Preloading dataset to GPU...')
    loader_tmp=DataLoader(train_ds,batch_size=4096,shuffle=False,
                           num_workers=2,pin_memory=(device=='cuda'))
    Xs,Ys=[],[]
    for xb,yb in loader_tmp: Xs.append(xb); Ys.append(yb)
    all_X=torch.cat(Xs).to(device)
    all_Y=torch.cat(Ys).to(device)

    train_loaders=[
        GPUTensorLoader(all_X[idx], all_Y[idx], batch_size, seed=seed+cid)
        for cid,idx in enumerate(tr_parts)
    ]

    te_tmp=DataLoader(test_ds,batch_size=4096,shuffle=False,
                       num_workers=2,pin_memory=(device=='cuda'))
    teX,teY=[],[]
    for xb,yb in te_tmp: teX.append(xb); teY.append(yb)
    te_X=torch.cat(teX).to(device); te_Y=torch.cat(teY).to(device)
    test_loader=GPUTensorLoader(te_X, te_Y, batch_size*2, seed=0)

    if device=='cuda':
        print(f'  GPU memory used: {torch.cuda.memory_allocated()/1e6:.0f} MB')
    print(f'  Train: {num_clients} clients  batch={batch_size}  '
          f'~{sum(len(idx) for idx in tr_parts)//num_clients} samples/client')
    print(f'  Test : {len(te_Y)} samples on {device}')
    return train_loaders, test_loader


# ═══════════════════════════════════════════════════════
# LOCAL TRAIN / EVAL
# ═══════════════════════════════════════════════════════
def local_train(model, loader, epochs, lr, device):
    model.train()
    opt  = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=1e-4)
    crit = nn.CrossEntropyLoss()
    total, n = 0.0, 0
    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            opt.zero_grad(set_to_none=True)   # v5: set_to_none=True saves a memset
            loss = crit(model(x), y)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            opt.step()
            total += loss.item(); n += 1
    return total / max(n, 1)


def evaluate(model, loader, device):
    model.eval()
    crit = nn.CrossEntropyLoss()
    tl, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            out      = model(x)
            tl      += crit(out, y).item() * y.size(0)
            correct += (out.argmax(1) == y).sum().item()
            total   += y.size(0)
    return tl / max(total, 1), correct / max(total, 1)


# ═══════════════════════════════════════════════════════
# PARAMETER UTILITIES — v5: stay on GPU, avoid CPU round-trips
# ═══════════════════════════════════════════════════════
def split_state_dict(model):
    fp, ob = OrderedDict(), OrderedDict()
    for k, v in model.state_dict().items():
        (fp if v.is_floating_point() else ob)[k] = v
    return fp, ob

def get_float_shapes(model):
    fp, _ = split_state_dict(model)
    return [tuple(v.shape) for v in fp.values()]

def get_float_param_names(model):
    fp, _ = split_state_dict(model)
    return list(fp.keys())

def get_layer_map(model):
    fp, _ = split_state_dict(model)
    layer_map = []
    for layer_idx, (_, v) in enumerate(fp.items()):
        layer_map.extend([layer_idx] * v.numel())
    return np.array(layer_map, dtype=np.int32)

# v5: return GPU tensors directly — no .cpu().numpy()
def get_float_params_gpu(model, device):
    fp, _ = split_state_dict(model)
    return torch.cat([v.detach().to(device, non_blocking=True).float().flatten()
                      for v in fp.values()])  # → 1D tensor on device

def set_float_params_gpu(model, flat_gpu, shapes):
    """Set model float params from a 1D GPU tensor — no CPU round-trip."""
    fp, ob = split_state_dict(model)
    sd = OrderedDict()
    offset = 0
    for (k, _), s in zip(fp.items(), shapes):
        n = int(np.prod(s))
        sd[k] = flat_gpu[offset:offset+n].reshape(s)
        offset += n
    for k, v in ob.items():
        sd[k] = v.clone()
    model.load_state_dict(sd, strict=True)

# Keep numpy helpers for methods that still need numpy (topk, lss masks)
def params_to_flat(pl):
    return np.concatenate([p.flatten().astype(np.float32) for p in pl])

def flat_to_params(flat, shapes):
    out, i = [], 0
    for s in shapes:
        n = int(np.prod(s))
        out.append(flat[i:i+n].reshape(s).astype(np.float32))
        i += n
    return out

def get_float_params(model):
    fp, _ = split_state_dict(model)
    return [v.detach().cpu().float().numpy().copy() for v in fp.values()]

def set_float_params(model, params_list):
    fp, ob = split_state_dict(model)
    sd = OrderedDict()
    for (k, _), arr in zip(fp.items(), params_list):
        sd[k] = torch.tensor(arr, dtype=torch.float32)
    for k, v in ob.items():
        sd[k] = v.clone()
    model.load_state_dict(sd, strict=True)


# ═══════════════════════════════════════════════════════
# CKA SIMILARITY — v5: fully on GPU with PyTorch
# Linear CKA: HSIC(X,X)^{1/2} * HSIC(Y,Y)^{1/2} denominator
# ═══════════════════════════════════════════════════════
def linear_cka_gpu(X, Y):
    """X, Y: [n_samples, n_features] tensors on GPU. Returns scalar float."""
    X = X - X.mean(0, keepdim=True)
    Y = Y - Y.mean(0, keepdim=True)
    # Using Frobenius norm of X^T Y
    XtY = X.T @ Y
    XtX = X.T @ X
    YtY = Y.T @ Y
    top = torch.norm(XtY, 'fro') ** 2
    bot = torch.norm(XtX, 'fro') * torch.norm(YtY, 'fro')
    return (top / bot).item() if bot.item() > 1e-12 else 0.0


def compute_per_layer_cka(client_model, global_model, probe_loader,
                           device, max_batches=2):
    """v5: activations collected on GPU, CKA computed on GPU."""
    client_model.eval(); global_model.eval()
    fp_names    = get_float_param_names(client_model)
    mod_to_pidx = {}
    for pidx, pname in enumerate(fp_names):
        mname = pname.rsplit('.', 1)[0]
        if mname not in mod_to_pidx:
            mod_to_pidx[mname] = pidx

    c_acts, g_acts = {}, {}

    def hook_fn(store, key):
        def h(mod, inp, out):
            # Stay on GPU — reshape but don't move to CPU
            a = out.detach().float().reshape(out.size(0), -1)
            store[key] = torch.cat([store[key], a], dim=0) if key in store else a
        return h

    hooks  = []
    c_mods = dict(client_model.named_modules())
    g_mods = dict(global_model.named_modules())
    for mname, pidx in mod_to_pidx.items():
        if mname in c_mods and mname in g_mods:
            hooks.append(c_mods[mname].register_forward_hook(hook_fn(c_acts, pidx)))
            hooks.append(g_mods[mname].register_forward_hook(hook_fn(g_acts, pidx)))

    with torch.no_grad():
        for i, (x, _) in enumerate(probe_loader):
            if i >= max_batches: break
            x = x.to(device, non_blocking=True)
            client_model(x); global_model(x)

    for h in hooks: h.remove()

    result = {}
    for idx in c_acts:
        if idx in g_acts:
            result[idx] = linear_cka_gpu(c_acts[idx], g_acts[idx])
    return result


# ═══════════════════════════════════════════════════════
# K SAMPLING — DSFL eq. 8
# ═══════════════════════════════════════════════════════
def sample_k_list(d, n, alpha, gamma, rng):
    mu, sigma = d/alpha, d/gamma
    a_s, b_s  = (0-mu)/sigma, (d-mu)/sigma
    s = truncnorm.rvs(a_s, b_s, loc=mu, scale=sigma, size=n, random_state=rng)
    return [max(1, min(int(v), d)) for v in s]


# ═══════════════════════════════════════════════════════
# TOP-K SPARSIFICATION
# ═══════════════════════════════════════════════════════
def topk_sparse(delta, k):
    k    = max(1, min(int(k), len(delta)))
    mask = np.zeros_like(delta)
    mask[np.argpartition(np.abs(delta), -k)[-k:]] = 1.0
    return delta * mask, delta * (1.0 - mask)


# ═══════════════════════════════════════════════════════
# METHOD 1: FedAvg
# ═══════════════════════════════════════════════════════
def fedavg_aggregate(c_params):
    avg = [np.zeros_like(p) for p in c_params[0]]
    for ps in c_params:
        for i, p in enumerate(ps): avg[i] += p / len(c_params)
    return avg



# Server-side variance priority  (FEDS v9)
def compute_server_priority(c_deltas, d, ema_alpha=0.7, prev_priority=None):
    """
    Compute per-parameter priority from inter-client variance.
    Called SERVER-SIDE after receiving all client deltas.
    Cost: one pass over N*d floats - FREE during aggregation.

    sigma2_j = Var_i(delta_i_j)
    High variance -> clients disagree -> transmit next round
    Low variance  -> clients agree    -> safe to compress
    """
    stack = np.stack(c_deltas, axis=0)        # [N, d]
    mean  = stack.mean(axis=0)                # [d]
    var   = ((stack - mean)**2).mean(axis=0)  # [d]

    # Rank-based normalisation: maps to [0,1] uniformly
    # Avoids collapse when variance is highly concentrated
    # (e.g. small non-IID models where a few params dominate)
    ranks = np.argsort(np.argsort(var)).astype(np.float32)  # [0..d-1]
    p = ranks / max(d - 1, 1)                               # [0,1]

    # EMA smoothing across rounds for stability
    if prev_priority is not None:
        p = ema_alpha * p + (1.0 - ema_alpha) * prev_priority
    return p.astype(np.float32)


def priority_sparse(delta, priority, k):
    """
    FEDS client-side selection.
    phi_j = |delta_j| * p_j   -> top-K by phi
    Round 1: p=ones -> reduces to standard Top-K.
    """
    k = max(1, min(int(k), len(delta)))
    phi  = np.abs(delta) * priority
    mask = np.zeros_like(delta)
    mask[np.argpartition(phi, -k)[-k:]] = 1.0
    return delta * mask, delta * (1.0 - mask)

# ═══════════════════════════════════════════════════════
# METHOD 2: Fixed Top-K
# ═══════════════════════════════════════════════════════
def fixed_topk_aggregate(c_params, gflat, errors, shapes, k_fixed):
    sds, errs = [], []
    for i, ps in enumerate(c_params):
        delta = (params_to_flat(ps) - gflat) + errors[i]
        sd, lo = topk_sparse(delta, k_fixed)
        sds.append(sd); errs.append(lo)
    return flat_to_params(gflat + np.mean(sds, axis=0), shapes), \
           gflat + np.mean(sds, axis=0), errs


# ═══════════════════════════════════════════════════════
# LSS MASK — DSFL eq. 2-3
# ═══════════════════════════════════════════════════════
def lss_mask(delta, cka_scores, layer_map, rng):
    mask = np.ones(len(delta), dtype=np.float32)
    for lidx, sim in cka_scores.items():
        pos = np.where(layer_map == lidx)[0]
        if len(pos) == 0: continue
        keep_p = float(np.clip(1.0 - sim, 0.05, 1.0))
        mask[pos] = (rng.random(len(pos)) < keep_p).astype(np.float32)
    return delta * mask



# ═══════════════════════════════════════════════════════
# FEDS UNIFIED IMPORTANCE SPARSIFICATION  (v7)
#
# phi_j = |delta_j| * (1 - CKA[layer(j)])
#
# Single-stage deterministic selection. Reduces to:
#   standard Top-K  when all CKA = 0
#   layer-only sel. when all |delta_j| equal
# Provably minimises expected reconstruction error at server.
# ═══════════════════════════════════════════════════════
def layer_norm_sparse(delta, layer_map, k):
    """
    FEDS v8 - Layer-Normalised Importance Sparsification.

    Importance score:
        phi_j = |delta_j| * importance_weight[layer(j)]

    where importance_weight[l] = ||delta_l||_2 / sqrt(n_l)
                                  normalised across layers to [0,1]

    This is the per-parameter RMS change in layer l.
    Layers that changed a lot get high weight - transmit more from them.
    Layers that barely moved get low weight - they are already close to
    global model, fewer parameters needed.

    Key advantages over CKA:
      - Zero extra cost: delta is already computed before sparsification
      - No forward passes, no probe data, no matrix operations
      - Robust to small models and few layers (CKA is noisy there)
      - Self-consistent: uses the update signal to weight the update signal
    """
    k = max(1, min(int(k), len(delta)))

    # Compute per-layer RMS update magnitude
    unique_layers = np.unique(layer_map)
    layer_rms = np.zeros(unique_layers.max() + 1, dtype=np.float32)
    for l in unique_layers:
        pos = np.where(layer_map == l)[0]
        if len(pos) == 0: continue
        layer_rms[l] = np.sqrt(np.mean(delta[pos] ** 2))  # RMS of delta in layer l

    # Normalise to [0, 1] so weights are comparable across layers
    max_rms = layer_rms.max()
    if max_rms > 1e-12:
        layer_rms = layer_rms / max_rms
    # Floor at 0.1 so even stable layers can contribute
    layer_rms = np.clip(layer_rms, 0.1, 1.0)

    # Per-parameter importance weight
    layer_weight = layer_rms[layer_map]

    # Unified score: magnitude * layer importance
    phi = np.abs(delta) * layer_weight

    # Top-K selection by phi
    mask = np.zeros_like(delta)
    mask[np.argpartition(phi, -k)[-k:]] = 1.0
    return delta * mask, delta * (1.0 - mask)

# ═══════════════════════════════════════════════════════
# METHOD 3: DSFL
# ═══════════════════════════════════════════════════════
def dsfl_aggregate(c_params, gflat, errors, shapes, layer_map,
                   k_list, d, client_models, gref,
                   train_loaders, device, rng,
                   round_idx, comp_warmup, cka_batches=2):
    warmup_frac = min(1.0, round_idx / max(comp_warmup, 1))
    eff_k = [int(d//2 + warmup_frac * (ki - d//2)) for ki in k_list]

    sds, errs = [], []
    for i, ps in enumerate(c_params):
        flat  = params_to_flat(ps)
        delta = (flat - gflat) + errors[i]
        cka   = compute_per_layer_cka(client_models[i], gref,
                                       train_loaders[i], device, cka_batches)
        d_lss = lss_mask(delta, cka, layer_map, rng)
        sd, _ = topk_sparse(d_lss, eff_k[i])
        sds.append(sd)
        errs.append(delta - sd)

    new_flat = gflat + np.mean(sds, axis=0)
    return flat_to_params(new_flat, shapes), new_flat, errs, eff_k


# ═══════════════════════════════════════════════════════
# ═══════════════════════════════════════════════════════
# METHOD 4: FEDS v9  server-variance-guided sparsification
#
# CLIENT: phi_j = |delta_j| * p_j[t-1]  ->  top-K selection
# SERVER: p[t]  = normalised Var_i(delta_i_j)  ->  broadcast with w[t+1]
#
# p computed FREE during aggregation. No CKA, no forward passes.
# Provably prioritises parameters where clients disagree most.
def feds_aggregate(c_params, gflat, errors, shapes, d,
                   k_list, priority, round_idx, comp_warmup,
                   prev_priority, ema_alpha=0.7):
    warmup_frac = min(1.0, round_idx / max(comp_warmup, 1))
    eff_k = [int(d//2 + warmup_frac * (ki - d//2)) for ki in k_list]
    sds, errs, raw_deltas = [], [], []
    for i, ps in enumerate(c_params):
        flat  = params_to_flat(ps)
        delta = (flat - gflat) + errors[i]
        raw_deltas.append(delta.copy())
        sd, residual = priority_sparse(delta, priority, eff_k[i])
        sds.append(sd); errs.append(residual)
    new_flat     = gflat + np.mean(sds, axis=0)
    new_priority = compute_server_priority(
        raw_deltas, d, ema_alpha=ema_alpha, prev_priority=prev_priority)
    ka = np.array(eff_k)
    print(f'  [FEDS] K={ka.mean():.0f}  compress={1-ka.mean()/d:.1%}  '
          f'p_mean={new_priority.mean():.3f}', end='')
    return flat_to_params(new_flat, shapes), new_flat, errs, eff_k, new_priority


# ═══════════════════════════════════════════════════════
# MAIN SIMULATION RUNNER — v5
# ═══════════════════════════════════════════════════════
def run_simulation(dataset, method, num_rounds, num_clients,
                   local_epochs, lr, lr_decay, lr_min, device, seed,
                   alpha_comm, gamma_comm,
                   comp_warmup,
                   train_loaders, global_test_loader,
                   cka_batches=2,
                   feds_ema=0.7):

    set_seed(seed)
    rng = np.random.default_rng(seed)
    print(f'\n{"="*62}')
    print(f'  {method.upper():12s} | {dataset} | {num_rounds} rounds | {device}')
    print(f'{"="*62}')

    global_model  = get_model(dataset).to(device)
    shapes        = get_float_shapes(global_model)
    layer_map     = get_layer_map(global_model)
    global_params = get_float_params(global_model)
    global_flat   = params_to_flat(global_params)
    d             = len(global_flat)
    k_max, k_min  = d, max(100, d // 100)
    print(f'  d={d:,}  k_min={k_min:,}')

    # v5: persistent gref model — reuse every round, just update weights
    gref = get_model(dataset).to(device) if method == 'dsfl' else None

    errors      = [np.zeros(d, dtype=np.float32) for _ in range(num_clients)]
    priority    = np.ones(d, dtype=np.float32)  # p[0]=uniform, round 1 = Top-K
    current_lr  = lr

    if method == 'fixed_topk':
        k_sample = sample_k_list(d, num_clients, alpha_comm, gamma_comm, rng)
        k_fixed  = min(k_sample)
        print(f'  Fixed K={k_fixed} ({k_fixed/d:.1%})')
    elif method in ('dsfl', 'feds'):
        k_list = sample_k_list(d, num_clients, alpha_comm, gamma_comm, rng)
        ka = np.array(k_list)
        print(f'  Initial K: mean={ka.mean():.0f} ({ka.mean()/d:.1%})  '
              f'min={ka.min()}  max={ka.max()}')

    client_models = [get_model(dataset).to(device) for _ in range(num_clients)]

    log = dict(
        method=method, dataset=dataset, seed=seed,
        total_params=d, k_max=k_max, k_min=k_min,
        round=[], accuracy=[], loss=[],
        k_mean=[], k_std=[], k_min_r=[], k_max_r=[],
        train_loss=[], lr=[], elapsed=[]
    )

    t0 = time.time()
    for rnd in range(num_rounds):
        t_round = time.time()
        print(f'\n  Round {rnd+1:3d}/{num_rounds}  (lr={current_lr:.5f})', end='  ')

        # v5: distribute global model using GPU tensor copy (no CPU round-trip)
        global_flat_gpu = torch.tensor(global_flat, device=device, dtype=torch.float32)
        for cm in client_models:
            set_float_params_gpu(cm, global_flat_gpu, shapes)

        # Local training — sequential (GPU is busy the whole time per client)
        c_params, c_losses = [], []
        for cid in range(num_clients):
            tl = local_train(client_models[cid], train_loaders[cid],
                             local_epochs, current_lr, device)
            c_params.append(get_float_params(client_models[cid]))
            c_losses.append(tl)

        if any(np.isnan(cl) for cl in c_losses):
            print(f'\n  ⚠️  NaN in losses — STOPPING'); break

        # Aggregation
        if method == 'fedavg':
            global_params = fedavg_aggregate(c_params)
            global_flat   = params_to_flat(global_params)
            k_arr = np.full(num_clients, d, dtype=float)

        elif method == 'fixed_topk':
            global_params, global_flat, errors = fixed_topk_aggregate(
                c_params, global_flat, errors, shapes, k_fixed)
            k_arr = np.full(num_clients, k_fixed, dtype=float)

        elif method == 'dsfl':
            k_list = sample_k_list(d, num_clients, alpha_comm, gamma_comm, rng)
            # v5: reuse persistent gref — just update its weights
            set_float_params_gpu(gref, global_flat_gpu, shapes)
            global_params, global_flat, errors, eff_k = dsfl_aggregate(
                c_params, global_flat, errors, shapes, layer_map,
                k_list, d, client_models, gref, train_loaders,
                device, rng, rnd, comp_warmup, cka_batches)
            k_arr = np.array(eff_k, dtype=float)
            print(f'[DSFL] eff_K={k_arr.mean():.0f}  compress={1-k_arr.mean()/d:.1%}', end='')

        elif method == 'feds':
            k_list = sample_k_list(d, num_clients, alpha_comm, gamma_comm, rng)
            global_params, global_flat, errors, eff_k, priority = feds_aggregate(
                c_params, global_flat, errors, shapes, d,
                k_list, priority, rnd, comp_warmup,
                prev_priority=priority, ema_alpha=feds_ema)
            k_arr = np.array(eff_k, dtype=float)

        current_lr = max(lr_min, current_lr * lr_decay)

        set_float_params(global_model, global_params)
        ev_loss, acc = evaluate(global_model, global_test_loader, device)
        elapsed = time.time() - t0
        rtime   = time.time() - t_round

        log['round'].append(rnd+1)
        log['accuracy'].append(float(acc))
        log['loss'].append(float(ev_loss))
        log['k_mean'].append(float(k_arr.mean()))
        log['k_std'].append(float(k_arr.std()))
        log['k_min_r'].append(int(k_arr.min()))
        log['k_max_r'].append(int(k_arr.max()))
        log['train_loss'].append(float(np.mean(c_losses)))
        log['lr'].append(float(current_lr))
        log['elapsed'].append(elapsed)

        print(f'  Acc={acc:.4f}  Loss={ev_loss:.4f}  '
              f'TrainL={np.mean(c_losses):.4f}  '
              f'K={k_arr.mean():.0f}  round={rtime:.1f}s  total={elapsed:.0f}s')

    log['total_time'] = time.time() - t0
    print(f'\n  ✅ {method.upper()} done — '
          f'{log["total_time"]/60:.1f} min  '
          f'| Final acc: {log["accuracy"][-1]:.4f}')
    return log

print('All functions defined (v11 - CIFAR100 Dirichlet + UnifiedNet)')
print('Model param counts:')
for name, kwargs in [('MNIST',   {'in_channels':1, 'num_classes':10}),
                     ('CIFAR10', {'in_channels':3, 'num_classes':10}),
                     ('CIFAR100',{'in_channels':3, 'num_classes':100})]:
    m = UnifiedNet(**kwargs)
    fp, _ = split_state_dict(m)
    print(f'  {name:8s}: {sum(v.numel() for v in fp.values()):,}')
    
def dirichlet_partition(dataset, num_clients, num_classes, alpha, rng):
    """
    Dirichlet partition for non-IID FL (standard benchmark).
    alpha controls heterogeneity: lower = more non-IID.
    alpha=0.5 is the standard setting in recent FL literature.
    """
    if hasattr(dataset, 'targets'):
        targets = np.array(dataset.targets)
    else:
        targets = np.array([dataset[i][1] for i in range(len(dataset))])

    # Group indices by class
    class_indices = [np.where(targets == c)[0] for c in range(num_classes)]

    # Sample Dirichlet proportions for each class
    client_indices = [[] for _ in range(num_clients)]
    for c in range(num_classes):
        proportions = rng.dirichlet(alpha * np.ones(num_clients))
        # Sort clients by proportion and assign samples
        idx_c = class_indices[c].copy()
        rng.shuffle(idx_c)
        splits = (np.cumsum(proportions[:-1]) * len(idx_c)).astype(int)
        for cid, chunk in enumerate(np.split(idx_c, splits)):
            client_indices[cid].extend(chunk.tolist())

    # Shuffle each client's indices
    parts = []
    for cid in range(num_clients):
        idx = np.array(client_indices[cid])
        rng.shuffle(idx)
        parts.append(idx)

    return parts
# Out:
# All functions defined (v11 - CIFAR100 Dirichlet + UnifiedNet)
# Model param counts:
#   MNIST   : 227,466
#   CIFAR10 : 228,042
#   CIFAR100: 251,172

# %% [markdown]
# ## Cell 4 - Load Data

# %%
import torch, time
t0=time.time()
train_loaders, global_test_loader = build_loaders(
    DATASET, NUM_CLIENTS, SEED, BATCH_SIZE,
    device=DEVICE, dirichlet_alpha=DIRICHLET_ALPHA
)
print(f'Load time: {time.time()-t0:.1f}s')
x, y = next(iter(train_loaders[0]))
print(f'x: {x.shape}  dtype={x.dtype}  device={x.device}')
assert str(x.device).startswith(DEVICE), f'Expected {DEVICE}, got {x.device}'
m = get_model(DATASET).to(DEVICE)
with torch.no_grad(): out = m(x.to(DEVICE))
loss_init = torch.nn.CrossEntropyLoss()(out, y.to(DEVICE)).item()
print(f'Init loss={loss_init:.4f}')
fp,_ = split_state_dict(m)
n_params = sum(v.numel() for v in fp.values())
print(f'UnifiedNet params: {n_params:,}')
if DEVICE=='cuda':
    import time as _t; torch.cuda.synchronize(); t0=_t.time()
    for cid in range(NUM_CLIENTS): local_train(m,train_loaders[cid],1,LR,DEVICE)
    torch.cuda.synchronize(); tt=_t.time()-t0
    print(f'Benchmark: 10-client={tt:.2f}s  GPU={torch.cuda.memory_allocated()/1e6:.0f}MB')
print('Data ready')
# Out:
# 100%|██████████| 169M/169M [00:04<00:00, 35.1MB/s]
#   Creating Dirichlet(alpha=0.5) partition...
#   Client 0: 85 classes  n=5131
#   Client 1: 95 classes  n=5173
#   Client 2: 93 classes  n=3780
#   Client 3: 94 classes  n=4378
#   Client 4: 92 classes  n=4654
#   Client 5: 91 classes  n=6253
#   Client 6: 94 classes  n=4678
#   Client 7: 96 classes  n=5630
#   Client 8: 93 classes  n=4962
#   Client 9: 100 classes  n=5361
#   Preloading dataset to GPU...
#   GPU memory used: 1355 MB
#   Train: 10 clients  batch=256  ~5000 samples/client
#   Test : 10000 samples on cuda
# Load time: 17.2s
# x: torch.Size([256, 3, 32, 32])  dtype=torch.float32  device=cuda:0
# Init loss=4.6322
# UnifiedNet params: 251,172
# Benchmark: 10-client=2.63s  GPU=763MB
# Data ready

# %% [markdown]
# ## Cell 5 - Smoke Test (30 rounds)
#
# CIFAR-100: expect ~5-15% accuracy at R30 (100 classes, hard task).
# Watch that FEDS loss decreases smoothly — that was the key fix in v10.

# %%
# SMOKE_ROUNDS = 30
# LABELS = {'fedavg':'FedAvg','fixed_topk':'Fixed Top-K','dsfl':'DSFL','feds':'FEDS (Ours)'}

# # Fast CKA proxy for DSFL only
# _real_cka = compute_per_layer_cka
# def _fast_cka(cm,gm,loader,device,max_batches=1):
#     names=get_float_param_names(cm)
#     mods=list(dict.fromkeys(n.rsplit('.',1)[0] for n in names)); nl=max(len(mods),1)
#     return {next(i for i,pn in enumerate(names) if pn.rsplit('.',1)[0]==mname):
#             float(np.clip(0.6*(1-rank/nl)+0.1,0,0.99))
#             for rank,mname in enumerate(mods)}
# compute_per_layer_cka = _fast_cka

# smoke_logs={}
# for method in ['fedavg','fixed_topk','dsfl','feds']:
#     smoke_logs[method]=run_simulation(
#         dataset=DATASET,method=method,num_rounds=SMOKE_ROUNDS,
#         num_clients=NUM_CLIENTS,local_epochs=LOCAL_EPOCHS,
#         lr=LR,lr_decay=LR_DECAY,lr_min=LR_MIN,device=DEVICE,seed=SEED,
#         alpha_comm=ALPHA_COMM,gamma_comm=GAMMA_COMM,
#         comp_warmup=min(10,SMOKE_ROUNDS//3),
#         train_loaders=train_loaders,global_test_loader=global_test_loader,
#         cka_batches=CKA_BATCHES, feds_ema=FEDS_EMA,
#     )
# compute_per_layer_cka = _real_cka

# print('\n-- Smoke Results --')
# print(f'{"Method":<16} {"R10":>7} {"R20":>7} {"R30":>7}')
# for m,log in smoke_logs.items():
#     acc=log['accuracy']
#     print(f'{LABELS.get(m,m):<16} {acc[9]*100:>6.1f}% {acc[19]*100:>6.1f}% {acc[-1]*100:>6.1f}%')
# finals=[round(log['accuracy'][-1],4) for log in smoke_logs.values()]
# print('BUG: all identical' if len(set(finals))==1 else 'Smoke OK - run Cell 6')

# %% [markdown]
# ## Cell 6 - Full Experiment (200 rounds)

# %%
import json
METHODS = ['fedavg','fixed_topk','dsfl','feds']
LABELS  = {'fedavg':'FedAvg','fixed_topk':'Fixed Top-K','dsfl':'DSFL','feds':'FEDS (Ours)'}

all_logs={}
for method in METHODS:
    log=run_simulation(
        dataset=DATASET,method=method,num_rounds=NUM_ROUNDS,
        num_clients=NUM_CLIENTS,local_epochs=LOCAL_EPOCHS,
        lr=LR,lr_decay=LR_DECAY,lr_min=LR_MIN,device=DEVICE,seed=SEED,
        alpha_comm=ALPHA_COMM,gamma_comm=GAMMA_COMM,
        comp_warmup=COMP_WARMUP,
        train_loaders=train_loaders,global_test_loader=global_test_loader,
        cka_batches=CKA_BATCHES, feds_ema=FEDS_EMA,
    )
    all_logs[method]=log
    with open(f'{RESULTS_DIR}/data/{method}_{DATASET}.json','w') as f: json.dump(log,f,indent=2)

d=next(iter(all_logs.values()))['total_params']
print('\nSummary:')
for m,log in all_logs.items():
    km=np.mean(log['k_mean'])
    cs=f'{(1-km/d)*100:.1f}%' if m!='fedavg' else 'N/A'
    print(f'{LABELS.get(m,m):<16} '
          f'best={max(log["accuracy"])*100:.2f}% '
          f'final={log["accuracy"][-1]*100:.2f}% '
          f'comm_save={cs} '
          f't={log["total_time"]/60:.1f}m')
# Out:
# ==============================================================
#   FEDAVG       | CIFAR100 | 200 rounds | cuda
# ==============================================================
#   d=251,172  k_min=2,511
#
#   Round   1/200  (lr=0.01000)    Acc=0.0218  Loss=4.5917  TrainL=4.4628  K=251172  round=2.3s  total=2s
#
#   Round   2/200  (lr=0.00990)    Acc=0.0356  Loss=4.5260  TrainL=4.3706  K=251172  round=2.2s  total=4s
#
#   Round   3/200  (lr=0.00980)    Acc=0.0425  Loss=4.4444  TrainL=4.2617  K=251172  round=2.2s  total=7s
#
#   Round   4/200  (lr=0.00970)    Acc=0.0495  Loss=4.3791  TrainL=4.1519  K=251172  round=2.2s  total=9s
#
#   Round   5/200  (lr=0.00961)    Acc=0.0632  Loss=4.3200  TrainL=4.0532  K=251172  round=2.2s  total=11s
#
#   Round   6/200  (lr=0.00951)    Acc=0.0746  Loss=4.2672  TrainL=3.9626  K=251172  round=2.2s  total=13s
#
#   Round   7/200  (lr=0.00941)    Acc=0.0859  Loss=4.2083  TrainL=3.8764  K=251172  round=2.2s  total=15s
#
#   Round   8/200  (lr=0.00932)    Acc=0.0929  Loss=4.1477  TrainL=3.7996  K=251172  round=2.2s  total=17s
#
#   Round   9/200  (lr=0.00923)    Acc=0.0968  Loss=4.0929  TrainL=3.7301  K=251172  round=2.2s  total=20s
#
#   Round  10/200  (lr=0.00914)    Acc=0.1059  Loss=4.0360  TrainL=3.6679  K=251172  round=2.2s  total=22s
#
#   Round  11/200  (lr=0.00904)    Acc=0.1087  Loss=3.9938  TrainL=3.6122  K=251172  round=2.2s  total=24s
#
#   Round  12/200  (lr=0.00895)    Acc=0.1154  Loss=3.9392  TrainL=3.5625  K=251172  round=2.2s  total=26s
#
#   Round  13/200  (lr=0.00886)    Acc=0.1192  Loss=3.9009  TrainL=3.5153  K=251172  round=2.2s  total=28s
#
#   Round  14/200  (lr=0.00878)    Acc=0.1251  Loss=3.8584  TrainL=3.4622  K=251172  round=2.2s  total=30s
#
#   Round  15/200  (lr=0.00869)    Acc=0.1285  Loss=3.8168  TrainL=3.4286  K=251172  round=2.2s  total=33s
#
#   Round  16/200  (lr=0.00860)    Acc=0.1325  Loss=3.7834  TrainL=3.3913  K=251172  round=2.2s  total=35s
#
#   Round  17/200  (lr=0.00851)    Acc=0.1359  Loss=3.7467  TrainL=3.3564  K=251172  round=2.2s  total=37s
#
#   Round  18/200  (lr=0.00843)    Acc=0.1395  Loss=3.7209  TrainL=3.3272  K=251172  round=2.2s  total=39s
#
#   Round  19/200  (lr=0.00835)    Acc=0.1444  Loss=3.6896  TrainL=3.2935  K=251172  round=2.2s  total=41s
#
#   Round  20/200  (lr=0.00826)    Acc=0.1482  Loss=3.6579  TrainL=3.2665  K=251172  round=2.2s  total=44s
#
#   Round  21/200  (lr=0.00818)    Acc=0.1509  Loss=3.6321  TrainL=3.2402  K=251172  round=2.2s  total=46s
#
#   Round  22/200  (lr=0.00810)    Acc=0.1571  Loss=3.6108  TrainL=3.2151  K=251172  round=2.2s  total=48s
#
#   Round  23/200  (lr=0.00802)    Acc=0.1586  Loss=3.5848  TrainL=3.1977  K=251172  round=2.2s  total=50s
#
#   Round  24/200  (lr=0.00794)    Acc=0.1640  Loss=3.5592  TrainL=3.1720  K=251172  round=2.2s  total=53s
#
#   Round  25/200  (lr=0.00786)    Acc=0.1669  Loss=3.5415  TrainL=3.1449  K=251172  round=2.2s  total=55s
#
#   Round  26/200  (lr=0.00778)    Acc=0.1729  Loss=3.5099  TrainL=3.1271  K=251172  round=2.2s  total=57s
#
#   Round  27/200  (lr=0.00770)    Acc=0.1748  Loss=3.4950  TrainL=3.1043  K=251172  round=2.2s  total=59s
#
#   Round  28/200  (lr=0.00762)    Acc=0.1770  Loss=3.4745  TrainL=3.0809  K=251172  round=2.2s  total=61s
#
#   Round  29/200  (lr=0.00755)    Acc=0.1813  Loss=3.4608  TrainL=3.0635  K=251172  round=2.2s  total=64s
#
#   Round  30/200  (lr=0.00747)    Acc=0.1838  Loss=3.4336  TrainL=3.0414  K=251172  round=2.2s  total=66s
#
#   Round  31/200  (lr=0.00740)    Acc=0.1909  Loss=3.4072  TrainL=3.0235  K=251172  round=2.3s  total=68s
#
#   Round  32/200  (lr=0.00732)    Acc=0.1910  Loss=3.3946  TrainL=2.9939  K=251172  round=2.3s  total=70s
#
#   Round  33/200  (lr=0.00725)    Acc=0.1972  Loss=3.3669  TrainL=2.9821  K=251172  round=2.3s  total=73s
#
#   Round  34/200  (lr=0.00718)    Acc=0.2013  Loss=3.3514  TrainL=2.9570  K=251172  round=2.3s  total=75s
#
#   Round  35/200  (lr=0.00711)    Acc=0.2007  Loss=3.3324  TrainL=2.9378  K=251172  round=2.3s  total=77s
#
#   Round  36/200  (lr=0.00703)    Acc=0.2044  Loss=3.3095  TrainL=2.9204  K=251172  round=2.3s  total=80s
#
#   Round  37/200  (lr=0.00696)    Acc=0.2096  Loss=3.2896  TrainL=2.9044  K=251172  round=2.3s  total=82s
#
#   Round  38/200  (lr=0.00689)    Acc=0.2134  Loss=3.2751  TrainL=2.8849  K=251172  round=2.3s  total=84s
#
#   Round  39/200  (lr=0.00683)    Acc=0.2134  Loss=3.2542  TrainL=2.8688  K=251172  round=2.3s  total=86s
#
#   Round  40/200  (lr=0.00676)    Acc=0.2219  Loss=3.2346  TrainL=2.8503  K=251172  round=2.3s  total=89s
#
#   Round  41/200  (lr=0.00669)    Acc=0.2245  Loss=3.2117  TrainL=2.8344  K=251172  round=2.3s  total=91s
#
#   Round  42/200  (lr=0.00662)    Acc=0.2282  Loss=3.1962  TrainL=2.8150  K=251172  round=2.3s  total=93s
#
#   Round  43/200  (lr=0.00656)    Acc=0.2304  Loss=3.1764  TrainL=2.7979  K=251172  round=2.3s  total=96s
#
#   Round  44/200  (lr=0.00649)    Acc=0.2326  Loss=3.1597  TrainL=2.7765  K=251172  round=2.3s  total=98s
#
#   Round  45/200  (lr=0.00643)    Acc=0.2347  Loss=3.1428  TrainL=2.7666  K=251172  round=2.3s  total=100s
#
#   Round  46/200  (lr=0.00636)    Acc=0.2389  Loss=3.1194  TrainL=2.7530  K=251172  round=2.4s  total=103s
#
#   Round  47/200  (lr=0.00630)    Acc=0.2396  Loss=3.1174  TrainL=2.7407  K=251172  round=2.4s  total=105s
#
#   Round  48/200  (lr=0.00624)    Acc=0.2419  Loss=3.0985  TrainL=2.7274  K=251172  round=2.4s  total=107s
#
#   Round  49/200  (lr=0.00617)    Acc=0.2488  Loss=3.0763  TrainL=2.7063  K=251172  round=2.4s  total=110s
#
#   Round  50/200  (lr=0.00611)    Acc=0.2489  Loss=3.0668  TrainL=2.6994  K=251172  round=2.4s  total=112s
#
#   Round  51/200  (lr=0.00605)    Acc=0.2523  Loss=3.0481  TrainL=2.6799  K=251172  round=2.4s  total=115s
#
#   Round  52/200  (lr=0.00599)    Acc=0.2528  Loss=3.0366  TrainL=2.6647  K=251172  round=2.4s  total=117s
#
#   Round  53/200  (lr=0.00593)    Acc=0.2542  Loss=3.0184  TrainL=2.6569  K=251172  round=2.4s  total=119s
#
#   Round  54/200  (lr=0.00587)    Acc=0.2587  Loss=3.0060  TrainL=2.6432  K=251172  round=2.3s  total=122s
#
#   Round  55/200  (lr=0.00581)    Acc=0.2578  Loss=3.0108  TrainL=2.6261  K=251172  round=2.3s  total=124s
#
#   Round  56/200  (lr=0.00575)    Acc=0.2621  Loss=2.9874  TrainL=2.6230  K=251172  round=2.3s  total=126s
#
#   Round  57/200  (lr=0.00570)    Acc=0.2653  Loss=2.9749  TrainL=2.6051  K=251172  round=2.3s  total=129s
#
#   Round  58/200  (lr=0.00564)    Acc=0.2667  Loss=2.9551  TrainL=2.5901  K=251172  round=2.3s  total=131s
#
#   Round  59/200  (lr=0.00558)    Acc=0.2669  Loss=2.9548  TrainL=2.5923  K=251172  round=2.3s  total=133s
#
#   Round  60/200  (lr=0.00553)    Acc=0.2717  Loss=2.9349  TrainL=2.5748  K=251172  round=2.3s  total=136s
#
#   Round  61/200  (lr=0.00547)    Acc=0.2693  Loss=2.9358  TrainL=2.5624  K=251172  round=2.3s  total=138s
#
#   Round  62/200  (lr=0.00542)    Acc=0.2714  Loss=2.9180  TrainL=2.5521  K=251172  round=2.3s  total=140s
#
#   Round  63/200  (lr=0.00536)    Acc=0.2752  Loss=2.9090  TrainL=2.5465  K=251172  round=2.3s  total=142s
#
#   Round  64/200  (lr=0.00531)    Acc=0.2767  Loss=2.8962  TrainL=2.5340  K=251172  round=2.3s  total=145s
#
#   Round  65/200  (lr=0.00526)    Acc=0.2822  Loss=2.8903  TrainL=2.5301  K=251172  round=2.3s  total=147s
#
#   Round  66/200  (lr=0.00520)    Acc=0.2802  Loss=2.8807  TrainL=2.5124  K=251172  round=2.3s  total=149s
#
#   Round  67/200  (lr=0.00515)    Acc=0.2808  Loss=2.8724  TrainL=2.5000  K=251172  round=2.3s  total=152s
#
#   Round  68/200  (lr=0.00510)    Acc=0.2833  Loss=2.8579  TrainL=2.4944  K=251172  round=2.3s  total=154s
#
#   Round  69/200  (lr=0.00505)    Acc=0.2872  Loss=2.8428  TrainL=2.4809  K=251172  round=2.3s  total=156s
#
#   Round  70/200  (lr=0.00500)    Acc=0.2835  Loss=2.8570  TrainL=2.4749  K=251172  round=2.3s  total=158s
#
#   Round  71/200  (lr=0.00495)    Acc=0.2915  Loss=2.8177  TrainL=2.4689  K=251172  round=2.3s  total=161s
#
#   Round  72/200  (lr=0.00490)    Acc=0.2943  Loss=2.8191  TrainL=2.4622  K=251172  round=2.3s  total=163s
#
#   Round  73/200  (lr=0.00485)    Acc=0.2969  Loss=2.8138  TrainL=2.4553  K=251172  round=2.3s  total=165s
#
#   Round  74/200  (lr=0.00480)    Acc=0.2962  Loss=2.8082  TrainL=2.4404  K=251172  round=2.3s  total=168s
#
#   Round  75/200  (lr=0.00475)    Acc=0.3015  Loss=2.7997  TrainL=2.4327  K=251172  round=2.3s  total=170s
#
#   Round  76/200  (lr=0.00471)    Acc=0.2993  Loss=2.7833  TrainL=2.4261  K=251172  round=2.3s  total=172s
#
#   Round  77/200  (lr=0.00466)    Acc=0.3009  Loss=2.7796  TrainL=2.4161  K=251172  round=2.3s  total=175s
#
#   Round  78/200  (lr=0.00461)    Acc=0.3014  Loss=2.7722  TrainL=2.4112  K=251172  round=2.3s  total=177s
#
#   Round  79/200  (lr=0.00457)    Acc=0.3026  Loss=2.7661  TrainL=2.4080  K=251172  round=2.3s  total=179s
#
#   Round  80/200  (lr=0.00452)    Acc=0.3064  Loss=2.7530  TrainL=2.3937  K=251172  round=2.3s  total=182s
#
#   Round  81/200  (lr=0.00448)    Acc=0.3102  Loss=2.7433  TrainL=2.3864  K=251172  round=2.3s  total=184s
#
#   Round  82/200  (lr=0.00443)    Acc=0.3079  Loss=2.7559  TrainL=2.3839  K=251172  round=2.3s  total=186s
#
#   Round  83/200  (lr=0.00439)    Acc=0.3103  Loss=2.7437  TrainL=2.3739  K=251172  round=2.3s  total=189s
#
#   Round  84/200  (lr=0.00434)    Acc=0.3074  Loss=2.7277  TrainL=2.3674  K=251172  round=2.3s  total=191s
#
#   Round  85/200  (lr=0.00430)    Acc=0.3154  Loss=2.7144  TrainL=2.3703  K=251172  round=2.3s  total=193s
#
#   Round  86/200  (lr=0.00426)    Acc=0.3123  Loss=2.7145  TrainL=2.3565  K=251172  round=2.3s  total=196s
#
#   Round  87/200  (lr=0.00421)    Acc=0.3179  Loss=2.7032  TrainL=2.3529  K=251172  round=2.3s  total=198s
#
#   Round  88/200  (lr=0.00417)    Acc=0.3190  Loss=2.6931  TrainL=2.3415  K=251172  round=2.3s  total=200s
#
#   Round  89/200  (lr=0.00413)    Acc=0.3202  Loss=2.6895  TrainL=2.3272  K=251172  round=2.3s  total=203s
#
#   Round  90/200  (lr=0.00409)    Acc=0.3232  Loss=2.6826  TrainL=2.3294  K=251172  round=2.3s  total=205s
#
#   Round  91/200  (lr=0.00405)    Acc=0.3170  Loss=2.6873  TrainL=2.3233  K=251172  round=2.3s  total=207s
#
#   Round  92/200  (lr=0.00401)    Acc=0.3196  Loss=2.6812  TrainL=2.3228  K=251172  round=2.3s  total=210s
#
#   Round  93/200  (lr=0.00397)    Acc=0.3251  Loss=2.6598  TrainL=2.3091  K=251172  round=2.3s  total=212s
#
#   Round  94/200  (lr=0.00393)    Acc=0.3232  Loss=2.6654  TrainL=2.3020  K=251172  round=2.3s  total=214s
#
#   Round  95/200  (lr=0.00389)    Acc=0.3278  Loss=2.6486  TrainL=2.2991  K=251172  round=2.3s  total=217s
#
#   Round  96/200  (lr=0.00385)    Acc=0.3268  Loss=2.6553  TrainL=2.2943  K=251172  round=2.3s  total=219s
#
#   Round  97/200  (lr=0.00381)    Acc=0.3272  Loss=2.6378  TrainL=2.2868  K=251172  round=2.3s  total=221s
#
#   Round  98/200  (lr=0.00377)    Acc=0.3280  Loss=2.6396  TrainL=2.2810  K=251172  round=2.3s  total=224s
#
#   Round  99/200  (lr=0.00373)    Acc=0.3287  Loss=2.6378  TrainL=2.2822  K=251172  round=2.3s  total=226s
#
#   Round 100/200  (lr=0.00370)    Acc=0.3332  Loss=2.6232  TrainL=2.2739  K=251172  round=2.3s  total=228s
#
#   Round 101/200  (lr=0.00366)    Acc=0.3324  Loss=2.6186  TrainL=2.2705  K=251172  round=2.3s  total=230s
#
#   Round 102/200  (lr=0.00362)    Acc=0.3357  Loss=2.6204  TrainL=2.2625  K=251172  round=2.3s  total=233s
#
#   Round 103/200  (lr=0.00359)    Acc=0.3325  Loss=2.6125  TrainL=2.2582  K=251172  round=2.3s  total=235s
#
#   Round 104/200  (lr=0.00355)    Acc=0.3386  Loss=2.6026  TrainL=2.2572  K=251172  round=2.3s  total=237s
#
#   Round 105/200  (lr=0.00352)    Acc=0.3362  Loss=2.6004  TrainL=2.2461  K=251172  round=2.3s  total=240s
#
#   Round 106/200  (lr=0.00348)    Acc=0.3349  Loss=2.6063  TrainL=2.2432  K=251172  round=2.3s  total=242s
#
#   Round 107/200  (lr=0.00345)    Acc=0.3410  Loss=2.5884  TrainL=2.2332  K=251172  round=2.3s  total=244s
#
#   Round 108/200  (lr=0.00341)    Acc=0.3397  Loss=2.5924  TrainL=2.2410  K=251172  round=2.3s  total=247s
#
#   Round 109/200  (lr=0.00338)    Acc=0.3420  Loss=2.5782  TrainL=2.2310  K=251172  round=2.3s  total=249s
#
#   Round 110/200  (lr=0.00334)    Acc=0.3389  Loss=2.5799  TrainL=2.2246  K=251172  round=2.3s  total=251s
#
#   Round 111/200  (lr=0.00331)    Acc=0.3433  Loss=2.5659  TrainL=2.2176  K=251172  round=2.3s  total=254s
#
#   Round 112/200  (lr=0.00328)    Acc=0.3414  Loss=2.5770  TrainL=2.2098  K=251172  round=2.3s  total=256s
#
#   Round 113/200  (lr=0.00324)    Acc=0.3487  Loss=2.5578  TrainL=2.2131  K=251172  round=2.3s  total=258s
#
#   Round 114/200  (lr=0.00321)    Acc=0.3423  Loss=2.5652  TrainL=2.1994  K=251172  round=2.3s  total=261s
#
#   Round 115/200  (lr=0.00318)    Acc=0.3489  Loss=2.5503  TrainL=2.2025  K=251172  round=2.3s  total=263s
#
#   Round 116/200  (lr=0.00315)    Acc=0.3464  Loss=2.5539  TrainL=2.1980  K=251172  round=2.3s  total=265s
#
#   Round 117/200  (lr=0.00312)    Acc=0.3514  Loss=2.5388  TrainL=2.1983  K=251172  round=2.3s  total=268s
#
#   Round 118/200  (lr=0.00309)    Acc=0.3480  Loss=2.5416  TrainL=2.1900  K=251172  round=2.3s  total=270s
#
#   Round 119/200  (lr=0.00305)    Acc=0.3481  Loss=2.5468  TrainL=2.1903  K=251172  round=2.3s  total=272s
#
#   Round 120/200  (lr=0.00302)    Acc=0.3508  Loss=2.5406  TrainL=2.1882  K=251172  round=2.3s  total=275s
#
#   Round 121/200  (lr=0.00299)    Acc=0.3536  Loss=2.5324  TrainL=2.1788  K=251172  round=2.3s  total=277s
#
#   Round 122/200  (lr=0.00296)    Acc=0.3552  Loss=2.5256  TrainL=2.1791  K=251172  round=2.3s  total=279s
#
#   Round 123/200  (lr=0.00293)    Acc=0.3541  Loss=2.5170  TrainL=2.1769  K=251172  round=2.3s  total=282s
#
#   Round 124/200  (lr=0.00290)    Acc=0.3509  Loss=2.5350  TrainL=2.1708  K=251172  round=2.3s  total=284s
#
#   Round 125/200  (lr=0.00288)    Acc=0.3602  Loss=2.5118  TrainL=2.1707  K=251172  round=2.3s  total=286s
#
#   Round 126/200  (lr=0.00285)    Acc=0.3561  Loss=2.5119  TrainL=2.1675  K=251172  round=2.3s  total=289s
#
#   Round 127/200  (lr=0.00282)    Acc=0.3566  Loss=2.5090  TrainL=2.1578  K=251172  round=2.3s  total=291s
#
#   Round 128/200  (lr=0.00279)    Acc=0.3571  Loss=2.5089  TrainL=2.1545  K=251172  round=2.3s  total=293s
#
#   Round 129/200  (lr=0.00276)    Acc=0.3593  Loss=2.4978  TrainL=2.1487  K=251172  round=2.3s  total=296s
#
#   Round 130/200  (lr=0.00273)    Acc=0.3608  Loss=2.4963  TrainL=2.1526  K=251172  round=2.3s  total=298s
#
#   Round 131/200  (lr=0.00271)    Acc=0.3620  Loss=2.4994  TrainL=2.1428  K=251172  round=2.3s  total=300s
#
#   Round 132/200  (lr=0.00268)    Acc=0.3608  Loss=2.4899  TrainL=2.1416  K=251172  round=2.3s  total=302s
#
#   Round 133/200  (lr=0.00265)    Acc=0.3632  Loss=2.4851  TrainL=2.1371  K=251172  round=2.3s  total=305s
#
#   Round 134/200  (lr=0.00263)    Acc=0.3614  Loss=2.4814  TrainL=2.1428  K=251172  round=2.3s  total=307s
#
#   Round 135/200  (lr=0.00260)    Acc=0.3638  Loss=2.4830  TrainL=2.1358  K=251172  round=2.3s  total=309s
#
#   Round 136/200  (lr=0.00257)    Acc=0.3655  Loss=2.4809  TrainL=2.1331  K=251172  round=2.3s  total=312s
#
#   Round 137/200  (lr=0.00255)    Acc=0.3673  Loss=2.4789  TrainL=2.1328  K=251172  round=2.3s  total=314s
#
#   Round 138/200  (lr=0.00252)    Acc=0.3615  Loss=2.4823  TrainL=2.1259  K=251172  round=2.3s  total=316s
#
#   Round 139/200  (lr=0.00250)    Acc=0.3671  Loss=2.4654  TrainL=2.1260  K=251172  round=2.3s  total=319s
#
#   Round 140/200  (lr=0.00247)    Acc=0.3671  Loss=2.4669  TrainL=2.1212  K=251172  round=2.3s  total=321s
#
#   Round 141/200  (lr=0.00245)    Acc=0.3696  Loss=2.4595  TrainL=2.1173  K=251172  round=2.3s  total=323s
#
#   Round 142/200  (lr=0.00242)    Acc=0.3708  Loss=2.4593  TrainL=2.1121  K=251172  round=2.3s  total=326s
#
#   Round 143/200  (lr=0.00240)    Acc=0.3696  Loss=2.4575  TrainL=2.1118  K=251172  round=2.3s  total=328s
#
#   Round 144/200  (lr=0.00238)    Acc=0.3686  Loss=2.4566  TrainL=2.1048  K=251172  round=2.3s  total=330s
#
#   Round 145/200  (lr=0.00235)    Acc=0.3733  Loss=2.4554  TrainL=2.1081  K=251172  round=2.3s  total=333s
#
#   Round 146/200  (lr=0.00233)    Acc=0.3736  Loss=2.4495  TrainL=2.1051  K=251172  round=2.3s  total=335s
#
#   Round 147/200  (lr=0.00231)    Acc=0.3705  Loss=2.4541  TrainL=2.1037  K=251172  round=2.3s  total=337s
#
#   Round 148/200  (lr=0.00228)    Acc=0.3725  Loss=2.4433  TrainL=2.1023  K=251172  round=2.3s  total=340s
#
#   Round 149/200  (lr=0.00226)    Acc=0.3746  Loss=2.4380  TrainL=2.0999  K=251172  round=2.3s  total=342s
#
#   Round 150/200  (lr=0.00224)    Acc=0.3750  Loss=2.4373  TrainL=2.0995  K=251172  round=2.3s  total=344s
#
#   Round 151/200  (lr=0.00221)    Acc=0.3742  Loss=2.4353  TrainL=2.0942  K=251172  round=2.3s  total=347s
#
#   Round 152/200  (lr=0.00219)    Acc=0.3754  Loss=2.4314  TrainL=2.0919  K=251172  round=2.3s  total=349s
#
#   Round 153/200  (lr=0.00217)    Acc=0.3767  Loss=2.4275  TrainL=2.0905  K=251172  round=2.3s  total=351s
#
#   Round 154/200  (lr=0.00215)    Acc=0.3766  Loss=2.4244  TrainL=2.0849  K=251172  round=2.3s  total=354s
#
#   Round 155/200  (lr=0.00213)    Acc=0.3771  Loss=2.4204  TrainL=2.0815  K=251172  round=2.3s  total=356s
#
#   Round 156/200  (lr=0.00211)    Acc=0.3772  Loss=2.4221  TrainL=2.0881  K=251172  round=2.3s  total=358s
#
#   Round 157/200  (lr=0.00208)    Acc=0.3742  Loss=2.4215  TrainL=2.0811  K=251172  round=2.3s  total=361s
#
#   Round 158/200  (lr=0.00206)    Acc=0.3740  Loss=2.4211  TrainL=2.0798  K=251172  round=2.3s  total=363s
#
#   Round 159/200  (lr=0.00204)    Acc=0.3752  Loss=2.4250  TrainL=2.0776  K=251172  round=2.3s  total=365s
#
#   Round 160/200  (lr=0.00202)    Acc=0.3796  Loss=2.4159  TrainL=2.0761  K=251172  round=2.3s  total=368s
#
#   Round 161/200  (lr=0.00200)    Acc=0.3813  Loss=2.4089  TrainL=2.0687  K=251172  round=2.3s  total=370s
#
#   Round 162/200  (lr=0.00198)    Acc=0.3783  Loss=2.4070  TrainL=2.0739  K=251172  round=2.3s  total=372s
#
#   Round 163/200  (lr=0.00196)    Acc=0.3804  Loss=2.4133  TrainL=2.0665  K=251172  round=2.3s  total=375s
#
#   Round 164/200  (lr=0.00194)    Acc=0.3801  Loss=2.4071  TrainL=2.0658  K=251172  round=2.3s  total=377s
#
#   Round 165/200  (lr=0.00192)    Acc=0.3802  Loss=2.4037  TrainL=2.0657  K=251172  round=2.3s  total=379s
#
#   Round 166/200  (lr=0.00190)    Acc=0.3814  Loss=2.4050  TrainL=2.0596  K=251172  round=2.3s  total=382s
#
#   Round 167/200  (lr=0.00189)    Acc=0.3782  Loss=2.4084  TrainL=2.0608  K=251172  round=2.3s  total=384s
#
#   Round 168/200  (lr=0.00187)    Acc=0.3822  Loss=2.4002  TrainL=2.0620  K=251172  round=2.3s  total=386s
#
#   Round 169/200  (lr=0.00185)    Acc=0.3828  Loss=2.3905  TrainL=2.0599  K=251172  round=2.3s  total=388s
#
#   Round 170/200  (lr=0.00183)    Acc=0.3856  Loss=2.3916  TrainL=2.0547  K=251172  round=2.3s  total=391s
#
#   Round 171/200  (lr=0.00181)    Acc=0.3840  Loss=2.3872  TrainL=2.0470  K=251172  round=2.3s  total=393s
#
#   Round 172/200  (lr=0.00179)    Acc=0.3821  Loss=2.3896  TrainL=2.0542  K=251172  round=2.3s  total=395s
#
#   Round 173/200  (lr=0.00178)    Acc=0.3825  Loss=2.3913  TrainL=2.0525  K=251172  round=2.3s  total=398s
#
#   Round 174/200  (lr=0.00176)    Acc=0.3848  Loss=2.3858  TrainL=2.0487  K=251172  round=2.3s  total=400s
#
#   Round 175/200  (lr=0.00174)    Acc=0.3854  Loss=2.3807  TrainL=2.0475  K=251172  round=2.3s  total=402s
#
#   Round 176/200  (lr=0.00172)    Acc=0.3823  Loss=2.3845  TrainL=2.0448  K=251172  round=2.3s  total=405s
#
#   Round 177/200  (lr=0.00171)    Acc=0.3853  Loss=2.3841  TrainL=2.0434  K=251172  round=2.3s  total=407s
#
#   Round 178/200  (lr=0.00169)    Acc=0.3873  Loss=2.3771  TrainL=2.0440  K=251172  round=2.3s  total=409s
#
#   Round 179/200  (lr=0.00167)    Acc=0.3871  Loss=2.3754  TrainL=2.0416  K=251172  round=2.3s  total=412s
#
#   Round 180/200  (lr=0.00165)    Acc=0.3855  Loss=2.3779  TrainL=2.0420  K=251172  round=2.3s  total=414s
#
#   Round 181/200  (lr=0.00164)    Acc=0.3865  Loss=2.3731  TrainL=2.0410  K=251172  round=2.3s  total=416s
#
#   Round 182/200  (lr=0.00162)    Acc=0.3886  Loss=2.3684  TrainL=2.0405  K=251172  round=2.3s  total=419s
#
#   Round 183/200  (lr=0.00161)    Acc=0.3875  Loss=2.3674  TrainL=2.0340  K=251172  round=2.3s  total=421s
#
#   Round 184/200  (lr=0.00159)    Acc=0.3884  Loss=2.3692  TrainL=2.0353  K=251172  round=2.3s  total=423s
#
#   Round 185/200  (lr=0.00157)    Acc=0.3906  Loss=2.3638  TrainL=2.0272  K=251172  round=2.3s  total=426s
#
#   Round 186/200  (lr=0.00156)    Acc=0.3886  Loss=2.3621  TrainL=2.0370  K=251172  round=2.3s  total=428s
#
#   Round 187/200  (lr=0.00154)    Acc=0.3900  Loss=2.3598  TrainL=2.0327  K=251172  round=2.3s  total=430s
#
#   Round 188/200  (lr=0.00153)    Acc=0.3919  Loss=2.3615  TrainL=2.0280  K=251172  round=2.3s  total=433s
#
#   Round 189/200  (lr=0.00151)    Acc=0.3887  Loss=2.3669  TrainL=2.0303  K=251172  round=2.3s  total=435s
#
#   Round 190/200  (lr=0.00150)    Acc=0.3909  Loss=2.3602  TrainL=2.0275  K=251172  round=2.3s  total=437s
#
#   Round 191/200  (lr=0.00148)    Acc=0.3900  Loss=2.3607  TrainL=2.0239  K=251172  round=2.3s  total=440s
#
#   Round 192/200  (lr=0.00147)    Acc=0.3917  Loss=2.3520  TrainL=2.0263  K=251172  round=2.3s  total=442s
#
#   Round 193/200  (lr=0.00145)    Acc=0.3916  Loss=2.3535  TrainL=2.0277  K=251172  round=2.3s  total=444s
#
#   Round 194/200  (lr=0.00144)    Acc=0.3938  Loss=2.3515  TrainL=2.0227  K=251172  round=2.3s  total=447s
#
#   Round 195/200  (lr=0.00142)    Acc=0.3934  Loss=2.3503  TrainL=2.0181  K=251172  round=2.3s  total=449s
#
#   Round 196/200  (lr=0.00141)    Acc=0.3934  Loss=2.3484  TrainL=2.0204  K=251172  round=2.3s  total=451s
#
#   Round 197/200  (lr=0.00139)    Acc=0.3967  Loss=2.3479  TrainL=2.0226  K=251172  round=2.3s  total=454s
#
#   Round 198/200  (lr=0.00138)    Acc=0.3937  Loss=2.3496  TrainL=2.0184  K=251172  round=2.3s  total=456s
#
#   Round 199/200  (lr=0.00137)    Acc=0.3938  Loss=2.3404  TrainL=2.0168  K=251172  round=2.3s  total=458s
#
#   Round 200/200  (lr=0.00135)    Acc=0.3948  Loss=2.3401  TrainL=2.0173  K=251172  round=2.3s  total=461s
#
#   ✅ FEDAVG done — 7.7 min  | Final acc: 0.3948
#
# ==============================================================
#   FIXED_TOPK   | CIFAR100 | 200 rounds | cuda
# ==============================================================
#   d=251,172  k_min=2,511
#   Fixed K=7206 (2.9%)
#
#   Round   1/200  (lr=0.01000)    Acc=0.0124  Loss=4.6021  TrainL=4.4636  K=7206  round=2.4s  total=2s
#
#   Round   2/200  (lr=0.00990)    Acc=0.0197  Loss=4.5880  TrainL=4.4261  K=7206  round=2.3s  total=5s
#
#   Round   3/200  (lr=0.00980)    Acc=0.0264  Loss=4.5647  TrainL=4.3856  K=7206  round=2.4s  total=7s
#
#   Round   4/200  (lr=0.00970)    Acc=0.0298  Loss=4.5354  TrainL=4.3239  K=7206  round=2.4s  total=9s
#
#   Round   5/200  (lr=0.00961)    Acc=0.0355  Loss=4.4983  TrainL=4.2638  K=7206  round=2.3s  total=12s
#
#   Round   6/200  (lr=0.00951)    Acc=0.0387  Loss=4.4544  TrainL=4.2113  K=7206  round=2.3s  total=14s
#
#   Round   7/200  (lr=0.00941)    Acc=0.0462  Loss=4.4118  TrainL=4.1369  K=7206  round=2.3s  total=16s
#
#   Round   8/200  (lr=0.00932)    Acc=0.0536  Loss=4.3639  TrainL=4.0749  K=7206  round=2.3s  total=19s
#
#   Round   9/200  (lr=0.00923)    Acc=0.0604  Loss=4.3191  TrainL=4.0159  K=7206  round=2.3s  total=21s
#
#   Round  10/200  (lr=0.00914)    Acc=0.0659  Loss=4.2767  TrainL=3.9599  K=7206  round=2.3s  total=24s
#
#   Round  11/200  (lr=0.00904)    Acc=0.0727  Loss=4.2378  TrainL=3.9062  K=7206  round=2.3s  total=26s
#
#   Round  12/200  (lr=0.00895)    Acc=0.0773  Loss=4.1982  TrainL=3.8507  K=7206  round=2.3s  total=28s
#
#   Round  13/200  (lr=0.00886)    Acc=0.0893  Loss=4.1543  TrainL=3.8015  K=7206  round=2.3s  total=31s
#
#   Round  14/200  (lr=0.00878)    Acc=0.0843  Loss=4.1186  TrainL=3.7578  K=7206  round=2.3s  total=33s
#
#   Round  15/200  (lr=0.00869)    Acc=0.0915  Loss=4.0806  TrainL=3.7103  K=7206  round=2.3s  total=35s
#
#   Round  16/200  (lr=0.00860)    Acc=0.0926  Loss=4.0482  TrainL=3.6680  K=7206  round=2.3s  total=38s
#
#   Round  17/200  (lr=0.00851)    Acc=0.0971  Loss=4.0144  TrainL=3.6309  K=7206  round=2.4s  total=40s
#
#   Round  18/200  (lr=0.00843)    Acc=0.0972  Loss=3.9881  TrainL=3.5997  K=7206  round=2.3s  total=42s
#
#   Round  19/200  (lr=0.00835)    Acc=0.1070  Loss=3.9480  TrainL=3.5661  K=7206  round=2.3s  total=45s
#
#   Round  20/200  (lr=0.00826)    Acc=0.1038  Loss=3.9253  TrainL=3.5277  K=7206  round=2.3s  total=47s
#
#   Round  21/200  (lr=0.00818)    Acc=0.1150  Loss=3.8850  TrainL=3.5011  K=7206  round=2.3s  total=49s
#
#   Round  22/200  (lr=0.00810)    Acc=0.1104  Loss=3.8658  TrainL=3.4705  K=7206  round=2.3s  total=52s
#
#   Round  23/200  (lr=0.00802)    Acc=0.1191  Loss=3.8337  TrainL=3.4470  K=7206  round=2.3s  total=54s
#
#   Round  24/200  (lr=0.00794)    Acc=0.1196  Loss=3.8168  TrainL=3.4199  K=7206  round=2.3s  total=56s
#
#   Round  25/200  (lr=0.00786)    Acc=0.1217  Loss=3.7842  TrainL=3.3953  K=7206  round=2.3s  total=59s
#
#   Round  26/200  (lr=0.00778)    Acc=0.1229  Loss=3.7754  TrainL=3.3715  K=7206  round=2.3s  total=61s
#
#   Round  27/200  (lr=0.00770)    Acc=0.1273  Loss=3.7426  TrainL=3.3482  K=7206  round=2.4s  total=63s
#
#   Round  28/200  (lr=0.00762)    Acc=0.1261  Loss=3.7297  TrainL=3.3285  K=7206  round=2.3s  total=66s
#
#   Round  29/200  (lr=0.00755)    Acc=0.1334  Loss=3.7054  TrainL=3.3069  K=7206  round=2.3s  total=68s
#
#   Round  30/200  (lr=0.00747)    Acc=0.1386  Loss=3.6857  TrainL=3.2899  K=7206  round=2.3s  total=70s
#
#   Round  31/200  (lr=0.00740)    Acc=0.1386  Loss=3.6619  TrainL=3.2701  K=7206  round=2.3s  total=73s
#
#   Round  32/200  (lr=0.00732)    Acc=0.1373  Loss=3.6575  TrainL=3.2555  K=7206  round=2.3s  total=75s
#
#   Round  33/200  (lr=0.00725)    Acc=0.1440  Loss=3.6345  TrainL=3.2410  K=7206  round=2.3s  total=77s
#
#   Round  34/200  (lr=0.00718)    Acc=0.1439  Loss=3.6171  TrainL=3.2211  K=7206  round=2.3s  total=80s
#
#   Round  35/200  (lr=0.00711)    Acc=0.1481  Loss=3.5932  TrainL=3.2037  K=7206  round=2.3s  total=82s
#
#   Round  36/200  (lr=0.00703)    Acc=0.1523  Loss=3.5878  TrainL=3.1911  K=7206  round=2.3s  total=85s
#
#   Round  37/200  (lr=0.00696)    Acc=0.1523  Loss=3.5668  TrainL=3.1724  K=7206  round=2.3s  total=87s
#
#   Round  38/200  (lr=0.00689)    Acc=0.1542  Loss=3.5547  TrainL=3.1518  K=7206  round=2.3s  total=89s
#
#   Round  39/200  (lr=0.00683)    Acc=0.1602  Loss=3.5274  TrainL=3.1436  K=7206  round=2.3s  total=92s
#
#   Round  40/200  (lr=0.00676)    Acc=0.1591  Loss=3.5242  TrainL=3.1281  K=7206  round=2.3s  total=94s
#
#   Round  41/200  (lr=0.00669)    Acc=0.1640  Loss=3.5031  TrainL=3.1116  K=7206  round=2.3s  total=96s
#
#   Round  42/200  (lr=0.00662)    Acc=0.1674  Loss=3.4881  TrainL=3.0927  K=7206  round=2.3s  total=99s
#
#   Round  43/200  (lr=0.00656)    Acc=0.1677  Loss=3.4724  TrainL=3.0819  K=7206  round=2.3s  total=101s
#
#   Round  44/200  (lr=0.00649)    Acc=0.1681  Loss=3.4702  TrainL=3.0717  K=7206  round=2.3s  total=103s
#
#   Round  45/200  (lr=0.00643)    Acc=0.1716  Loss=3.4529  TrainL=3.0595  K=7206  round=2.3s  total=106s
#
#   Round  46/200  (lr=0.00636)    Acc=0.1729  Loss=3.4321  TrainL=3.0349  K=7206  round=2.3s  total=108s
#
#   Round  47/200  (lr=0.00630)    Acc=0.1835  Loss=3.4100  TrainL=3.0254  K=7206  round=2.3s  total=110s
#
#   Round  48/200  (lr=0.00624)    Acc=0.1812  Loss=3.4017  TrainL=3.0087  K=7206  round=2.3s  total=113s
#
#   Round  49/200  (lr=0.00617)    Acc=0.1864  Loss=3.3799  TrainL=2.9967  K=7206  round=2.3s  total=115s
#
#   Round  50/200  (lr=0.00611)    Acc=0.1864  Loss=3.3770  TrainL=2.9799  K=7206  round=2.3s  total=117s
#
#   Round  51/200  (lr=0.00605)    Acc=0.1874  Loss=3.3553  TrainL=2.9676  K=7206  round=2.3s  total=120s
#
#   Round  52/200  (lr=0.00599)    Acc=0.1924  Loss=3.3476  TrainL=2.9528  K=7206  round=2.3s  total=122s
#
#   Round  53/200  (lr=0.00593)    Acc=0.1922  Loss=3.3382  TrainL=2.9472  K=7206  round=2.3s  total=124s
#
#   Round  54/200  (lr=0.00587)    Acc=0.1949  Loss=3.3115  TrainL=2.9296  K=7206  round=2.3s  total=127s
#
#   Round  55/200  (lr=0.00581)    Acc=0.1985  Loss=3.3006  TrainL=2.9149  K=7206  round=2.3s  total=129s
#
#   Round  56/200  (lr=0.00575)    Acc=0.2000  Loss=3.2912  TrainL=2.9021  K=7206  round=2.3s  total=131s
#
#   Round  57/200  (lr=0.00570)    Acc=0.2056  Loss=3.2690  TrainL=2.8933  K=7206  round=2.3s  total=134s
#
#   Round  58/200  (lr=0.00564)    Acc=0.2068  Loss=3.2630  TrainL=2.8768  K=7206  round=2.3s  total=136s
#
#   Round  59/200  (lr=0.00558)    Acc=0.2157  Loss=3.2353  TrainL=2.8627  K=7206  round=2.3s  total=138s
#
#   Round  60/200  (lr=0.00553)    Acc=0.2146  Loss=3.2246  TrainL=2.8470  K=7206  round=2.3s  total=141s
#
#   Round  61/200  (lr=0.00547)    Acc=0.2171  Loss=3.2140  TrainL=2.8363  K=7206  round=2.3s  total=143s
#
#   Round  62/200  (lr=0.00542)    Acc=0.2180  Loss=3.2046  TrainL=2.8257  K=7206  round=2.3s  total=145s
#
#   Round  63/200  (lr=0.00536)    Acc=0.2182  Loss=3.2045  TrainL=2.8183  K=7206  round=2.3s  total=148s
#
#   Round  64/200  (lr=0.00531)    Acc=0.2232  Loss=3.1820  TrainL=2.8049  K=7206  round=2.3s  total=150s
#
#   Round  65/200  (lr=0.00526)    Acc=0.2283  Loss=3.1639  TrainL=2.7878  K=7206  round=2.3s  total=153s
#
#   Round  66/200  (lr=0.00520)    Acc=0.2257  Loss=3.1552  TrainL=2.7767  K=7206  round=2.3s  total=155s
#
#   Round  67/200  (lr=0.00515)    Acc=0.2312  Loss=3.1370  TrainL=2.7725  K=7206  round=2.3s  total=157s
#
#   Round  68/200  (lr=0.00510)    Acc=0.2276  Loss=3.1452  TrainL=2.7568  K=7206  round=2.3s  total=160s
#
#   Round  69/200  (lr=0.00505)    Acc=0.2332  Loss=3.1224  TrainL=2.7507  K=7206  round=2.3s  total=162s
#
#   Round  70/200  (lr=0.00500)    Acc=0.2353  Loss=3.1156  TrainL=2.7370  K=7206  round=2.3s  total=164s
#
#   Round  71/200  (lr=0.00495)    Acc=0.2376  Loss=3.1022  TrainL=2.7312  K=7206  round=2.3s  total=167s
#
#   Round  72/200  (lr=0.00490)    Acc=0.2387  Loss=3.0899  TrainL=2.7101  K=7206  round=2.3s  total=169s
#
#   Round  73/200  (lr=0.00485)    Acc=0.2433  Loss=3.0725  TrainL=2.7063  K=7206  round=2.3s  total=171s
#
#   Round  74/200  (lr=0.00480)    Acc=0.2377  Loss=3.0767  TrainL=2.6935  K=7206  round=2.3s  total=174s
#
#   Round  75/200  (lr=0.00475)    Acc=0.2448  Loss=3.0581  TrainL=2.6885  K=7206  round=2.3s  total=176s
#
#   Round  76/200  (lr=0.00471)    Acc=0.2443  Loss=3.0587  TrainL=2.6825  K=7206  round=2.3s  total=178s
#
#   Round  77/200  (lr=0.00466)    Acc=0.2509  Loss=3.0435  TrainL=2.6719  K=7206  round=2.3s  total=181s
#
#   Round  78/200  (lr=0.00461)    Acc=0.2462  Loss=3.0329  TrainL=2.6624  K=7206  round=2.3s  total=183s
#
#   Round  79/200  (lr=0.00457)    Acc=0.2513  Loss=3.0247  TrainL=2.6533  K=7206  round=2.3s  total=185s
#
#   Round  80/200  (lr=0.00452)    Acc=0.2528  Loss=3.0169  TrainL=2.6415  K=7206  round=2.3s  total=188s
#
#   Round  81/200  (lr=0.00448)    Acc=0.2551  Loss=3.0054  TrainL=2.6398  K=7206  round=2.3s  total=190s
#
#   Round  82/200  (lr=0.00443)    Acc=0.2564  Loss=2.9995  TrainL=2.6290  K=7206  round=2.3s  total=192s
#
#   Round  83/200  (lr=0.00439)    Acc=0.2585  Loss=2.9905  TrainL=2.6191  K=7206  round=2.3s  total=195s
#
#   Round  84/200  (lr=0.00434)    Acc=0.2549  Loss=2.9881  TrainL=2.6214  K=7206  round=2.3s  total=197s
#
#   Round  85/200  (lr=0.00430)    Acc=0.2609  Loss=2.9671  TrainL=2.6101  K=7206  round=2.3s  total=199s
#
#   Round  86/200  (lr=0.00426)    Acc=0.2582  Loss=2.9688  TrainL=2.5938  K=7206  round=2.3s  total=202s
#
#   Round  87/200  (lr=0.00421)    Acc=0.2610  Loss=2.9580  TrainL=2.5857  K=7206  round=2.3s  total=204s
#
#   Round  88/200  (lr=0.00417)    Acc=0.2579  Loss=2.9699  TrainL=2.5889  K=7206  round=2.3s  total=206s
#
#   Round  89/200  (lr=0.00413)    Acc=0.2651  Loss=2.9422  TrainL=2.5799  K=7206  round=2.3s  total=209s
#
#   Round  90/200  (lr=0.00409)    Acc=0.2678  Loss=2.9299  TrainL=2.5612  K=7206  round=2.3s  total=211s
#
#   Round  91/200  (lr=0.00405)    Acc=0.2695  Loss=2.9264  TrainL=2.5592  K=7206  round=2.3s  total=213s
#
#   Round  92/200  (lr=0.00401)    Acc=0.2696  Loss=2.9269  TrainL=2.5583  K=7206  round=2.3s  total=216s
#
#   Round  93/200  (lr=0.00397)    Acc=0.2734  Loss=2.9118  TrainL=2.5485  K=7206  round=2.3s  total=218s
#
#   Round  94/200  (lr=0.00393)    Acc=0.2703  Loss=2.9101  TrainL=2.5387  K=7206  round=2.3s  total=221s
#
#   Round  95/200  (lr=0.00389)    Acc=0.2762  Loss=2.8905  TrainL=2.5375  K=7206  round=2.3s  total=223s
#
#   Round  96/200  (lr=0.00385)    Acc=0.2725  Loss=2.8819  TrainL=2.5215  K=7206  round=2.3s  total=225s
#
#   Round  97/200  (lr=0.00381)    Acc=0.2762  Loss=2.8821  TrainL=2.5200  K=7206  round=2.3s  total=228s
#
#   Round  98/200  (lr=0.00377)    Acc=0.2754  Loss=2.8823  TrainL=2.5144  K=7206  round=2.3s  total=230s
#
#   Round  99/200  (lr=0.00373)    Acc=0.2795  Loss=2.8754  TrainL=2.5057  K=7206  round=2.3s  total=232s
#
#   Round 100/200  (lr=0.00370)    Acc=0.2829  Loss=2.8620  TrainL=2.5020  K=7206  round=2.3s  total=235s
#
#   Round 101/200  (lr=0.00366)    Acc=0.2833  Loss=2.8591  TrainL=2.4998  K=7206  round=2.3s  total=237s
#
#   Round 102/200  (lr=0.00362)    Acc=0.2826  Loss=2.8561  TrainL=2.4913  K=7206  round=2.3s  total=239s
#
#   Round 103/200  (lr=0.00359)    Acc=0.2883  Loss=2.8348  TrainL=2.4872  K=7206  round=2.3s  total=242s
#
#   Round 104/200  (lr=0.00355)    Acc=0.2885  Loss=2.8301  TrainL=2.4714  K=7206  round=2.3s  total=244s
#
#   Round 105/200  (lr=0.00352)    Acc=0.2890  Loss=2.8342  TrainL=2.4728  K=7206  round=2.3s  total=246s
#
#   Round 106/200  (lr=0.00348)    Acc=0.2841  Loss=2.8396  TrainL=2.4707  K=7206  round=2.3s  total=249s
#
#   Round 107/200  (lr=0.00345)    Acc=0.2859  Loss=2.8331  TrainL=2.4676  K=7206  round=2.3s  total=251s
#
#   Round 108/200  (lr=0.00341)    Acc=0.2846  Loss=2.8246  TrainL=2.4563  K=7206  round=2.3s  total=253s
#
#   Round 109/200  (lr=0.00338)    Acc=0.2927  Loss=2.8061  TrainL=2.4509  K=7206  round=2.3s  total=256s
#
#   Round 110/200  (lr=0.00334)    Acc=0.2969  Loss=2.7924  TrainL=2.4468  K=7206  round=2.3s  total=258s
#
#   Round 111/200  (lr=0.00331)    Acc=0.2930  Loss=2.8011  TrainL=2.4430  K=7206  round=2.3s  total=260s
#
#   Round 112/200  (lr=0.00328)    Acc=0.2912  Loss=2.7990  TrainL=2.4405  K=7206  round=2.4s  total=263s
#
#   Round 113/200  (lr=0.00324)    Acc=0.2977  Loss=2.7837  TrainL=2.4378  K=7206  round=2.3s  total=265s
#
#   Round 114/200  (lr=0.00321)    Acc=0.2987  Loss=2.7786  TrainL=2.4216  K=7206  round=2.3s  total=267s
#
#   Round 115/200  (lr=0.00318)    Acc=0.3040  Loss=2.7680  TrainL=2.4228  K=7206  round=2.3s  total=270s
#
#   Round 116/200  (lr=0.00315)    Acc=0.2980  Loss=2.7725  TrainL=2.4133  K=7206  round=2.3s  total=272s
#
#   Round 117/200  (lr=0.00312)    Acc=0.3032  Loss=2.7694  TrainL=2.4147  K=7206  round=2.3s  total=274s
#
#   Round 118/200  (lr=0.00309)    Acc=0.2988  Loss=2.7705  TrainL=2.4054  K=7206  round=2.3s  total=277s
#
#   Round 119/200  (lr=0.00305)    Acc=0.3061  Loss=2.7523  TrainL=2.4066  K=7206  round=2.3s  total=279s
#
#   Round 120/200  (lr=0.00302)    Acc=0.3039  Loss=2.7459  TrainL=2.3956  K=7206  round=2.3s  total=282s
#
#   Round 121/200  (lr=0.00299)    Acc=0.3065  Loss=2.7496  TrainL=2.3961  K=7206  round=2.3s  total=284s
#
#   Round 122/200  (lr=0.00296)    Acc=0.3079  Loss=2.7428  TrainL=2.3914  K=7206  round=2.3s  total=286s
#
#   Round 123/200  (lr=0.00293)    Acc=0.3050  Loss=2.7492  TrainL=2.3911  K=7206  round=2.3s  total=289s
#
#   Round 124/200  (lr=0.00290)    Acc=0.3041  Loss=2.7474  TrainL=2.3814  K=7206  round=2.3s  total=291s
#
#   Round 125/200  (lr=0.00288)    Acc=0.3091  Loss=2.7231  TrainL=2.3786  K=7206  round=2.4s  total=293s
#
#   Round 126/200  (lr=0.00285)    Acc=0.3076  Loss=2.7269  TrainL=2.3639  K=7206  round=2.3s  total=296s
#
#   Round 127/200  (lr=0.00282)    Acc=0.3113  Loss=2.7161  TrainL=2.3654  K=7206  round=2.4s  total=298s
#
#   Round 128/200  (lr=0.00279)    Acc=0.3091  Loss=2.7166  TrainL=2.3624  K=7206  round=2.4s  total=300s
#
#   Round 129/200  (lr=0.00276)    Acc=0.3118  Loss=2.7121  TrainL=2.3561  K=7206  round=2.3s  total=303s
#
#   Round 130/200  (lr=0.00273)    Acc=0.3119  Loss=2.7064  TrainL=2.3538  K=7206  round=2.4s  total=305s
#
#   Round 131/200  (lr=0.00271)    Acc=0.3150  Loss=2.7039  TrainL=2.3605  K=7206  round=2.3s  total=307s
#
#   Round 132/200  (lr=0.00268)    Acc=0.3175  Loss=2.6965  TrainL=2.3452  K=7206  round=2.3s  total=310s
#
#   Round 133/200  (lr=0.00265)    Acc=0.3197  Loss=2.6895  TrainL=2.3460  K=7206  round=2.3s  total=312s
#
#   Round 134/200  (lr=0.00263)    Acc=0.3178  Loss=2.6823  TrainL=2.3440  K=7206  round=2.3s  total=314s
#
#   Round 135/200  (lr=0.00260)    Acc=0.3186  Loss=2.6888  TrainL=2.3395  K=7206  round=2.4s  total=317s
#
#   Round 136/200  (lr=0.00257)    Acc=0.3175  Loss=2.6843  TrainL=2.3291  K=7206  round=2.3s  total=319s
#
#   Round 137/200  (lr=0.00255)    Acc=0.3148  Loss=2.6941  TrainL=2.3331  K=7206  round=2.3s  total=321s
#
#   Round 138/200  (lr=0.00252)    Acc=0.3209  Loss=2.6719  TrainL=2.3294  K=7206  round=2.3s  total=324s
#
#   Round 139/200  (lr=0.00250)    Acc=0.3224  Loss=2.6741  TrainL=2.3240  K=7206  round=2.3s  total=326s
#
#   Round 140/200  (lr=0.00247)    Acc=0.3224  Loss=2.6679  TrainL=2.3162  K=7206  round=2.3s  total=329s
#
#   Round 141/200  (lr=0.00245)    Acc=0.3263  Loss=2.6600  TrainL=2.3136  K=7206  round=2.3s  total=331s
#
#   Round 142/200  (lr=0.00242)    Acc=0.3200  Loss=2.6601  TrainL=2.3124  K=7206  round=2.3s  total=333s
#
#   Round 143/200  (lr=0.00240)    Acc=0.3245  Loss=2.6514  TrainL=2.3134  K=7206  round=2.3s  total=336s
#
#   Round 144/200  (lr=0.00238)    Acc=0.3244  Loss=2.6556  TrainL=2.3114  K=7206  round=2.3s  total=338s
#
#   Round 145/200  (lr=0.00235)    Acc=0.3222  Loss=2.6545  TrainL=2.3058  K=7206  round=2.3s  total=340s
#
#   Round 146/200  (lr=0.00233)    Acc=0.3270  Loss=2.6446  TrainL=2.3050  K=7206  round=2.3s  total=343s
#
#   Round 147/200  (lr=0.00231)    Acc=0.3301  Loss=2.6414  TrainL=2.2979  K=7206  round=2.3s  total=345s
#
#   Round 148/200  (lr=0.00228)    Acc=0.3259  Loss=2.6470  TrainL=2.2937  K=7206  round=2.3s  total=347s
#
#   Round 149/200  (lr=0.00226)    Acc=0.3279  Loss=2.6358  TrainL=2.2930  K=7206  round=2.3s  total=350s
#
#   Round 150/200  (lr=0.00224)    Acc=0.3271  Loss=2.6318  TrainL=2.2879  K=7206  round=2.3s  total=352s
#
#   Round 151/200  (lr=0.00221)    Acc=0.3300  Loss=2.6242  TrainL=2.2864  K=7206  round=2.3s  total=354s
#
#   Round 152/200  (lr=0.00219)    Acc=0.3309  Loss=2.6199  TrainL=2.2825  K=7206  round=2.3s  total=357s
#
#   Round 153/200  (lr=0.00217)    Acc=0.3323  Loss=2.6225  TrainL=2.2806  K=7206  round=2.3s  total=359s
#
#   Round 154/200  (lr=0.00215)    Acc=0.3317  Loss=2.6195  TrainL=2.2753  K=7206  round=2.3s  total=361s
#
#   Round 155/200  (lr=0.00213)    Acc=0.3326  Loss=2.6144  TrainL=2.2777  K=7206  round=2.3s  total=364s
#
#   Round 156/200  (lr=0.00211)    Acc=0.3332  Loss=2.6165  TrainL=2.2737  K=7206  round=2.3s  total=366s
#
#   Round 157/200  (lr=0.00208)    Acc=0.3312  Loss=2.6013  TrainL=2.2729  K=7206  round=2.3s  total=368s
#
#   Round 158/200  (lr=0.00206)    Acc=0.3336  Loss=2.6042  TrainL=2.2682  K=7206  round=2.3s  total=371s
#
#   Round 159/200  (lr=0.00204)    Acc=0.3362  Loss=2.5970  TrainL=2.2661  K=7206  round=2.3s  total=373s
#
#   Round 160/200  (lr=0.00202)    Acc=0.3361  Loss=2.5968  TrainL=2.2616  K=7206  round=2.3s  total=375s
#
#   Round 161/200  (lr=0.00200)    Acc=0.3339  Loss=2.6005  TrainL=2.2593  K=7206  round=2.3s  total=378s
#
#   Round 162/200  (lr=0.00198)    Acc=0.3344  Loss=2.5942  TrainL=2.2593  K=7206  round=2.3s  total=380s
#
#   Round 163/200  (lr=0.00196)    Acc=0.3365  Loss=2.5959  TrainL=2.2547  K=7206  round=2.3s  total=382s
#
#   Round 164/200  (lr=0.00194)    Acc=0.3396  Loss=2.5869  TrainL=2.2530  K=7206  round=2.3s  total=385s
#
#   Round 165/200  (lr=0.00192)    Acc=0.3408  Loss=2.5864  TrainL=2.2505  K=7206  round=2.3s  total=387s
#
#   Round 166/200  (lr=0.00190)    Acc=0.3373  Loss=2.5887  TrainL=2.2538  K=7206  round=2.3s  total=389s
#
#   Round 167/200  (lr=0.00189)    Acc=0.3385  Loss=2.5797  TrainL=2.2449  K=7206  round=2.3s  total=392s
#
#   Round 168/200  (lr=0.00187)    Acc=0.3370  Loss=2.5838  TrainL=2.2475  K=7206  round=2.3s  total=394s
#
#   Round 169/200  (lr=0.00185)    Acc=0.3394  Loss=2.5761  TrainL=2.2454  K=7206  round=2.3s  total=397s
#
#   Round 170/200  (lr=0.00183)    Acc=0.3389  Loss=2.5741  TrainL=2.2435  K=7206  round=2.3s  total=399s
#
#   Round 171/200  (lr=0.00181)    Acc=0.3425  Loss=2.5622  TrainL=2.2377  K=7206  round=2.3s  total=401s
#
#   Round 172/200  (lr=0.00179)    Acc=0.3381  Loss=2.5681  TrainL=2.2351  K=7206  round=2.3s  total=404s
#
#   Round 173/200  (lr=0.00178)    Acc=0.3412  Loss=2.5658  TrainL=2.2317  K=7206  round=2.3s  total=406s
#
#   Round 174/200  (lr=0.00176)    Acc=0.3439  Loss=2.5641  TrainL=2.2352  K=7206  round=2.3s  total=408s
#
#   Round 175/200  (lr=0.00174)    Acc=0.3445  Loss=2.5614  TrainL=2.2369  K=7206  round=2.3s  total=411s
#
#   Round 176/200  (lr=0.00172)    Acc=0.3435  Loss=2.5593  TrainL=2.2318  K=7206  round=2.3s  total=413s
#
#   Round 177/200  (lr=0.00171)    Acc=0.3452  Loss=2.5614  TrainL=2.2268  K=7206  round=2.3s  total=415s
#
#   Round 178/200  (lr=0.00169)    Acc=0.3413  Loss=2.5615  TrainL=2.2259  K=7206  round=2.3s  total=418s
#
#   Round 179/200  (lr=0.00167)    Acc=0.3493  Loss=2.5436  TrainL=2.2265  K=7206  round=2.4s  total=420s
#
#   Round 180/200  (lr=0.00165)    Acc=0.3468  Loss=2.5451  TrainL=2.2244  K=7206  round=2.3s  total=422s
#
#   Round 181/200  (lr=0.00164)    Acc=0.3451  Loss=2.5493  TrainL=2.2184  K=7206  round=2.3s  total=425s
#
#   Round 182/200  (lr=0.00162)    Acc=0.3452  Loss=2.5458  TrainL=2.2168  K=7206  round=2.3s  total=427s
#
#   Round 183/200  (lr=0.00161)    Acc=0.3491  Loss=2.5407  TrainL=2.2184  K=7206  round=2.3s  total=429s
#
#   Round 184/200  (lr=0.00159)    Acc=0.3467  Loss=2.5439  TrainL=2.2120  K=7206  round=2.3s  total=432s
#
#   Round 185/200  (lr=0.00157)    Acc=0.3509  Loss=2.5347  TrainL=2.2108  K=7206  round=2.3s  total=434s
#
#   Round 186/200  (lr=0.00156)    Acc=0.3502  Loss=2.5347  TrainL=2.2098  K=7206  round=2.3s  total=436s
#
#   Round 187/200  (lr=0.00154)    Acc=0.3490  Loss=2.5340  TrainL=2.2116  K=7206  round=2.3s  total=439s
#
#   Round 188/200  (lr=0.00153)    Acc=0.3486  Loss=2.5311  TrainL=2.2050  K=7206  round=2.3s  total=441s
#
#   Round 189/200  (lr=0.00151)    Acc=0.3502  Loss=2.5235  TrainL=2.2042  K=7206  round=2.3s  total=443s
#
#   Round 190/200  (lr=0.00150)    Acc=0.3445  Loss=2.5367  TrainL=2.2010  K=7206  round=2.3s  total=446s
#
#   Round 191/200  (lr=0.00148)    Acc=0.3491  Loss=2.5302  TrainL=2.2076  K=7206  round=2.3s  total=448s
#
#   Round 192/200  (lr=0.00147)    Acc=0.3493  Loss=2.5263  TrainL=2.1997  K=7206  round=2.3s  total=450s
#
#   Round 193/200  (lr=0.00145)    Acc=0.3513  Loss=2.5205  TrainL=2.1975  K=7206  round=2.3s  total=453s
#
#   Round 194/200  (lr=0.00144)    Acc=0.3501  Loss=2.5216  TrainL=2.1958  K=7206  round=2.3s  total=455s
#
#   Round 195/200  (lr=0.00142)    Acc=0.3544  Loss=2.5140  TrainL=2.2001  K=7206  round=2.3s  total=457s
#
#   Round 196/200  (lr=0.00141)    Acc=0.3512  Loss=2.5168  TrainL=2.1971  K=7206  round=2.3s  total=460s
#
#   Round 197/200  (lr=0.00139)    Acc=0.3544  Loss=2.5175  TrainL=2.1895  K=7206  round=2.3s  total=462s
#
#   Round 198/200  (lr=0.00138)    Acc=0.3522  Loss=2.5206  TrainL=2.1943  K=7206  round=2.3s  total=464s
#
#   Round 199/200  (lr=0.00137)    Acc=0.3521  Loss=2.5177  TrainL=2.1920  K=7206  round=2.3s  total=467s
#
#   Round 200/200  (lr=0.00135)    Acc=0.3559  Loss=2.5066  TrainL=2.1911  K=7206  round=2.3s  total=469s
#
#   ✅ FIXED_TOPK done — 7.8 min  | Final acc: 0.3559
#
# ==============================================================
#   DSFL         | CIFAR100 | 200 rounds | cuda
# ==============================================================
#   d=251,172  k_min=2,511
#   Initial K: mean=38534 (15.3%)  min=7206  max=76439
#
#   Round   1/200  (lr=0.01000)  [DSFL] eff_K=125586  compress=50.0%  Acc=0.0111  Loss=4.6025  TrainL=4.4630  K=125586  round=39.9s  total=40s
#
#   Round   2/200  (lr=0.00990)  [DSFL] eff_K=121217  compress=51.7%  Acc=0.0185  Loss=4.5887  TrainL=4.4376  K=121217  round=39.9s  total=80s
#
#   Round   3/200  (lr=0.00980)  [DSFL] eff_K=115316  compress=54.1%  Acc=0.0217  Loss=4.5726  TrainL=4.3999  K=115316  round=39.9s  total=120s
#
#   Round   4/200  (lr=0.00970)  [DSFL] eff_K=110691  compress=55.9%  Acc=0.0310  Loss=4.5525  TrainL=4.3599  K=110691  round=39.9s  total=160s
#
#   Round   5/200  (lr=0.00961)  [DSFL] eff_K=107648  compress=57.1%  Acc=0.0412  Loss=4.5307  TrainL=4.3128  K=107648  round=39.9s  total=199s
#
#   Round   6/200  (lr=0.00951)  [DSFL] eff_K=101176  compress=59.7%  Acc=0.0415  Loss=4.5055  TrainL=4.2643  K=101176  round=39.8s  total=239s
#
#   Round   7/200  (lr=0.00941)  [DSFL] eff_K=98581  compress=60.8%  Acc=0.0414  Loss=4.4807  TrainL=4.2200  K=98581  round=39.8s  total=279s
#
#   Round   8/200  (lr=0.00932)  [DSFL] eff_K=93411  compress=62.8%  Acc=0.0410  Loss=4.4581  TrainL=4.1811  K=93411  round=39.8s  total=319s
#
#   Round   9/200  (lr=0.00923)  [DSFL] eff_K=85539  compress=65.9%  Acc=0.0420  Loss=4.4280  TrainL=4.1474  K=85539  round=39.8s  total=359s
#
#   Round  10/200  (lr=0.00914)  [DSFL] eff_K=88269  compress=64.9%  Acc=0.0475  Loss=4.4050  TrainL=4.1168  K=88269  round=39.8s  total=399s
#
#   Round  11/200  (lr=0.00904)  [DSFL] eff_K=81245  compress=67.7%  Acc=0.0467  Loss=4.3786  TrainL=4.0842  K=81245  round=39.8s  total=438s
#
#   Round  12/200  (lr=0.00895)  [DSFL] eff_K=74600  compress=70.3%  Acc=0.0477  Loss=4.3521  TrainL=4.0521  K=74600  round=39.8s  total=478s
#
#   Round  13/200  (lr=0.00886)  [DSFL] eff_K=72634  compress=71.1%  Acc=0.0481  Loss=4.3263  TrainL=4.0201  K=72634  round=39.8s  total=518s
#
#   Round  14/200  (lr=0.00878)  [DSFL] eff_K=60673  compress=75.8%  Acc=0.0516  Loss=4.3033  TrainL=3.9849  K=60673  round=39.8s  total=558s
#
#   Round  15/200  (lr=0.00869)  [DSFL] eff_K=55714  compress=77.8%  Acc=0.0548  Loss=4.2824  TrainL=3.9566  K=55714  round=39.8s  total=598s
#
#   Round  16/200  (lr=0.00860)  [DSFL] eff_K=55223  compress=78.0%  Acc=0.0624  Loss=4.2581  TrainL=3.9230  K=55223  round=39.8s  total=637s
#
#   Round  17/200  (lr=0.00851)  [DSFL] eff_K=51592  compress=79.5%  Acc=0.0676  Loss=4.2417  TrainL=3.8939  K=51592  round=39.8s  total=677s
#
#   Round  18/200  (lr=0.00843)  [DSFL] eff_K=47571  compress=81.1%  Acc=0.0670  Loss=4.2153  TrainL=3.8590  K=47571  round=39.8s  total=717s
#
#   Round  19/200  (lr=0.00835)  [DSFL] eff_K=43340  compress=82.7%  Acc=0.0629  Loss=4.1972  TrainL=3.8301  K=43340  round=39.8s  total=757s
#
#   Round  20/200  (lr=0.00826)  [DSFL] eff_K=41566  compress=83.5%  Acc=0.0739  Loss=4.1799  TrainL=3.8008  K=41566  round=39.8s  total=796s
#
#   Round  21/200  (lr=0.00818)  [DSFL] eff_K=28652  compress=88.6%  Acc=0.0711  Loss=4.1606  TrainL=3.7691  K=28652  round=39.8s  total=836s
#
#   Round  22/200  (lr=0.00810)  [DSFL] eff_K=33467  compress=86.7%  Acc=0.0723  Loss=4.1444  TrainL=3.7374  K=33467  round=39.8s  total=876s
#
#   Round  23/200  (lr=0.00802)  [DSFL] eff_K=41588  compress=83.4%  Acc=0.0750  Loss=4.1227  TrainL=3.7071  K=41588  round=39.7s  total=916s
#
#   Round  24/200  (lr=0.00794)  [DSFL] eff_K=29645  compress=88.2%  Acc=0.0770  Loss=4.1073  TrainL=3.6799  K=29645  round=39.7s  total=955s
#
#   Round  25/200  (lr=0.00786)  [DSFL] eff_K=35784  compress=85.8%  Acc=0.0785  Loss=4.0827  TrainL=3.6610  K=35784  round=39.7s  total=995s
#
#   Round  26/200  (lr=0.00778)  [DSFL] eff_K=24466  compress=90.3%  Acc=0.0886  Loss=4.0628  TrainL=3.6300  K=24466  round=39.8s  total=1035s
#
#   Round  27/200  (lr=0.00770)  [DSFL] eff_K=35403  compress=85.9%  Acc=0.0875  Loss=4.0525  TrainL=3.6073  K=35403  round=39.8s  total=1075s
#
#   Round  28/200  (lr=0.00762)  [DSFL] eff_K=43302  compress=82.8%  Acc=0.0823  Loss=4.0448  TrainL=3.5837  K=43302  round=39.8s  total=1115s
#
#   Round  29/200  (lr=0.00755)  [DSFL] eff_K=24614  compress=90.2%  Acc=0.0828  Loss=4.0358  TrainL=3.5663  K=24614  round=39.8s  total=1154s
#
#   Round  30/200  (lr=0.00747)  [DSFL] eff_K=32261  compress=87.2%  Acc=0.0844  Loss=4.0253  TrainL=3.5512  K=32261  round=39.8s  total=1194s
#
#   Round  31/200  (lr=0.00740)  [DSFL] eff_K=30339  compress=87.9%  Acc=0.0907  Loss=4.0170  TrainL=3.5349  K=30339  round=39.8s  total=1234s
#
#   Round  32/200  (lr=0.00732)  [DSFL] eff_K=27080  compress=89.2%  Acc=0.0872  Loss=4.0170  TrainL=3.5147  K=27080  round=39.9s  total=1274s
#
#   Round  33/200  (lr=0.00725)  [DSFL] eff_K=26910  compress=89.3%  Acc=0.0880  Loss=3.9990  TrainL=3.5044  K=26910  round=39.9s  total=1314s
#
#   Round  34/200  (lr=0.00718)  [DSFL] eff_K=24389  compress=90.3%  Acc=0.0823  Loss=4.0135  TrainL=3.4914  K=24389  round=39.9s  total=1354s
#
# ...
#
#   Round  98/200  (lr=0.00377)    [FEDS] K=37810  compress=84.9%  p_mean=0.500  Acc=0.3073  Loss=2.7216  TrainL=2.3452  K=37810  round=2.4s  total=233s
#
#   Round  99/200  (lr=0.00373)    [FEDS] K=38138  compress=84.8%  p_mean=0.500  Acc=0.3066  Loss=2.7211  TrainL=2.3442  K=38138  round=2.4s  total=235s
#
#   Round 100/200  (lr=0.00370)    [FEDS] K=27060  compress=89.2%  p_mean=0.500  Acc=0.3130  Loss=2.7115  TrainL=2.3365  K=27060  round=2.4s  total=237s
#
#   Round 101/200  (lr=0.00366)    [FEDS] K=33112  compress=86.8%  p_mean=0.500  Acc=0.3166  Loss=2.6885  TrainL=2.3335  K=33112  round=2.4s  total=240s
#
#   Round 102/200  (lr=0.00362)    [FEDS] K=44223  compress=82.4%  p_mean=0.500  Acc=0.3231  Loss=2.6811  TrainL=2.3229  K=44223  round=2.4s  total=242s
#
#   Round 103/200  (lr=0.00359)    [FEDS] K=31568  compress=87.4%  p_mean=0.500  Acc=0.3234  Loss=2.6752  TrainL=2.3230  K=31568  round=2.4s  total=244s
#
#   Round 104/200  (lr=0.00355)    [FEDS] K=28061  compress=88.8%  p_mean=0.500  Acc=0.3247  Loss=2.6688  TrainL=2.3179  K=28061  round=2.4s  total=247s
#
#   Round 105/200  (lr=0.00352)    [FEDS] K=28597  compress=88.6%  p_mean=0.500  Acc=0.3184  Loss=2.6710  TrainL=2.3086  K=28597  round=2.4s  total=249s
#
#   Round 106/200  (lr=0.00348)    [FEDS] K=34943  compress=86.1%  p_mean=0.500  Acc=0.3237  Loss=2.6601  TrainL=2.3076  K=34943  round=2.4s  total=252s
#
#   Round 107/200  (lr=0.00345)    [FEDS] K=38160  compress=84.8%  p_mean=0.500  Acc=0.3203  Loss=2.6679  TrainL=2.3027  K=38160  round=2.4s  total=254s
#
#   Round 108/200  (lr=0.00341)    [FEDS] K=46666  compress=81.4%  p_mean=0.500  Acc=0.3209  Loss=2.6595  TrainL=2.2995  K=46666  round=2.4s  total=256s
#
#   Round 109/200  (lr=0.00338)    [FEDS] K=28331  compress=88.7%  p_mean=0.500  Acc=0.3274  Loss=2.6440  TrainL=2.2923  K=28331  round=2.4s  total=259s
#
#   Round 110/200  (lr=0.00334)    [FEDS] K=32909  compress=86.9%  p_mean=0.500  Acc=0.3306  Loss=2.6463  TrainL=2.2823  K=32909  round=2.4s  total=261s
#
#   Round 111/200  (lr=0.00331)    [FEDS] K=35748  compress=85.8%  p_mean=0.500  Acc=0.3267  Loss=2.6349  TrainL=2.2834  K=35748  round=2.4s  total=263s
#
#   Round 112/200  (lr=0.00328)    [FEDS] K=36882  compress=85.3%  p_mean=0.500  Acc=0.3282  Loss=2.6297  TrainL=2.2729  K=36882  round=2.4s  total=266s
#
#   Round 113/200  (lr=0.00324)    [FEDS] K=38580  compress=84.6%  p_mean=0.500  Acc=0.3258  Loss=2.6385  TrainL=2.2760  K=38580  round=2.4s  total=268s
#
#   Round 114/200  (lr=0.00321)    [FEDS] K=40320  compress=83.9%  p_mean=0.500  Acc=0.3311  Loss=2.6211  TrainL=2.2743  K=40320  round=2.4s  total=271s
#
#   Round 115/200  (lr=0.00318)    [FEDS] K=20147  compress=92.0%  p_mean=0.500  Acc=0.3304  Loss=2.6261  TrainL=2.2704  K=20147  round=2.4s  total=273s
#
#   Round 116/200  (lr=0.00315)    [FEDS] K=31214  compress=87.6%  p_mean=0.500  Acc=0.3258  Loss=2.6401  TrainL=2.2642  K=31214  round=2.4s  total=275s
#
#   Round 117/200  (lr=0.00312)    [FEDS] K=28803  compress=88.5%  p_mean=0.500  Acc=0.3296  Loss=2.6195  TrainL=2.2674  K=28803  round=2.4s  total=278s
#
#   Round 118/200  (lr=0.00309)    [FEDS] K=29626  compress=88.2%  p_mean=0.500  Acc=0.3381  Loss=2.6051  TrainL=2.2529  K=29626  round=2.4s  total=280s
#
#   Round 119/200  (lr=0.00305)    [FEDS] K=37183  compress=85.2%  p_mean=0.500  Acc=0.3319  Loss=2.6026  TrainL=2.2515  K=37183  round=2.4s  total=282s
#
#   Round 120/200  (lr=0.00302)    [FEDS] K=27559  compress=89.0%  p_mean=0.500  Acc=0.3378  Loss=2.5896  TrainL=2.2430  K=27559  round=2.4s  total=285s
#
#   Round 121/200  (lr=0.00299)    [FEDS] K=30379  compress=87.9%  p_mean=0.500  Acc=0.3384  Loss=2.5947  TrainL=2.2340  K=30379  round=2.4s  total=287s
#
#   Round 122/200  (lr=0.00296)    [FEDS] K=31030  compress=87.6%  p_mean=0.500  Acc=0.3325  Loss=2.6007  TrainL=2.2406  K=31030  round=2.4s  total=290s
#
#   Round 123/200  (lr=0.00293)    [FEDS] K=18857  compress=92.5%  p_mean=0.500  Acc=0.3352  Loss=2.5951  TrainL=2.2381  K=18857  round=2.4s  total=292s
#
#   Round 124/200  (lr=0.00290)    [FEDS] K=31580  compress=87.4%  p_mean=0.500  Acc=0.3392  Loss=2.5882  TrainL=2.2285  K=31580  round=2.4s  total=294s
#
#   Round 125/200  (lr=0.00288)    [FEDS] K=34724  compress=86.2%  p_mean=0.500  Acc=0.3391  Loss=2.5898  TrainL=2.2302  K=34724  round=2.4s  total=297s
#
#   Round 126/200  (lr=0.00285)    [FEDS] K=35136  compress=86.0%  p_mean=0.500  Acc=0.3402  Loss=2.5794  TrainL=2.2234  K=35136  round=2.4s  total=299s
#
#   Round 127/200  (lr=0.00282)    [FEDS] K=29989  compress=88.1%  p_mean=0.500  Acc=0.3344  Loss=2.5798  TrainL=2.2202  K=29989  round=2.4s  total=301s
#
#   Round 128/200  (lr=0.00279)    [FEDS] K=34761  compress=86.2%  p_mean=0.500  Acc=0.3429  Loss=2.5637  TrainL=2.2193  K=34761  round=2.4s  total=304s
#
#   Round 129/200  (lr=0.00276)    [FEDS] K=25338  compress=89.9%  p_mean=0.500  Acc=0.3456  Loss=2.5569  TrainL=2.2149  K=25338  round=2.4s  total=306s
#
#   Round 130/200  (lr=0.00273)    [FEDS] K=37389  compress=85.1%  p_mean=0.500  Acc=0.3434  Loss=2.5648  TrainL=2.2042  K=37389  round=2.4s  total=309s
#
#   Round 131/200  (lr=0.00271)    [FEDS] K=30118  compress=88.0%  p_mean=0.500  Acc=0.3428  Loss=2.5563  TrainL=2.2071  K=30118  round=2.4s  total=311s
#
#   Round 132/200  (lr=0.00268)    [FEDS] K=27148  compress=89.2%  p_mean=0.500  Acc=0.3393  Loss=2.5658  TrainL=2.2000  K=27148  round=2.4s  total=313s
#
#   Round 133/200  (lr=0.00265)    [FEDS] K=43750  compress=82.6%  p_mean=0.500  Acc=0.3417  Loss=2.5593  TrainL=2.2085  K=43750  round=2.4s  total=316s
#
#   Round 134/200  (lr=0.00263)    [FEDS] K=32039  compress=87.2%  p_mean=0.500  Acc=0.3479  Loss=2.5505  TrainL=2.1880  K=32039  round=2.4s  total=318s
#
#   Round 135/200  (lr=0.00260)    [FEDS] K=31061  compress=87.6%  p_mean=0.500  Acc=0.3461  Loss=2.5421  TrainL=2.1934  K=31061  round=2.4s  total=320s
#
#   Round 136/200  (lr=0.00257)    [FEDS] K=22284  compress=91.1%  p_mean=0.500  Acc=0.3490  Loss=2.5353  TrainL=2.1853  K=22284  round=2.4s  total=323s
#
#   Round 137/200  (lr=0.00255)    [FEDS] K=39162  compress=84.4%  p_mean=0.500  Acc=0.3489  Loss=2.5379  TrainL=2.1863  K=39162  round=2.4s  total=325s
#
#   Round 138/200  (lr=0.00252)    [FEDS] K=35019  compress=86.1%  p_mean=0.500  Acc=0.3506  Loss=2.5328  TrainL=2.1870  K=35019  round=2.4s  total=327s
#
#   Round 139/200  (lr=0.00250)    [FEDS] K=34780  compress=86.2%  p_mean=0.500  Acc=0.3521  Loss=2.5250  TrainL=2.1767  K=34780  round=2.4s  total=330s
#
#   Round 140/200  (lr=0.00247)    [FEDS] K=33568  compress=86.6%  p_mean=0.500  Acc=0.3519  Loss=2.5183  TrainL=2.1820  K=33568  round=2.4s  total=332s
#
#   Round 141/200  (lr=0.00245)    [FEDS] K=50650  compress=79.8%  p_mean=0.500  Acc=0.3524  Loss=2.5255  TrainL=2.1732  K=50650  round=2.4s  total=335s
#
#   Round 142/200  (lr=0.00242)    [FEDS] K=25827  compress=89.7%  p_mean=0.500  Acc=0.3578  Loss=2.5061  TrainL=2.1823  K=25827  round=2.4s  total=337s
#
#   Round 143/200  (lr=0.00240)    [FEDS] K=39446  compress=84.3%  p_mean=0.500  Acc=0.3553  Loss=2.5185  TrainL=2.1648  K=39446  round=2.4s  total=339s
#
#   Round 144/200  (lr=0.00238)    [FEDS] K=22839  compress=90.9%  p_mean=0.500  Acc=0.3540  Loss=2.5090  TrainL=2.1773  K=22839  round=2.4s  total=342s
#
#   Round 145/200  (lr=0.00235)    [FEDS] K=37200  compress=85.2%  p_mean=0.500  Acc=0.3532  Loss=2.5169  TrainL=2.1604  K=37200  round=2.4s  total=344s
#
#   Round 146/200  (lr=0.00233)    [FEDS] K=28919  compress=88.5%  p_mean=0.500  Acc=0.3571  Loss=2.5013  TrainL=2.1620  K=28919  round=2.4s  total=346s
#
#   Round 147/200  (lr=0.00231)    [FEDS] K=35480  compress=85.9%  p_mean=0.500  Acc=0.3573  Loss=2.4994  TrainL=2.1562  K=35480  round=2.4s  total=349s
#
#   Round 148/200  (lr=0.00228)    [FEDS] K=31986  compress=87.3%  p_mean=0.500  Acc=0.3538  Loss=2.4997  TrainL=2.1566  K=31986  round=2.4s  total=351s
#
#   Round 149/200  (lr=0.00226)    [FEDS] K=36016  compress=85.7%  p_mean=0.500  Acc=0.3560  Loss=2.5032  TrainL=2.1528  K=36016  round=2.4s  total=354s
#
#   Round 150/200  (lr=0.00224)    [FEDS] K=37356  compress=85.1%  p_mean=0.500  Acc=0.3599  Loss=2.4865  TrainL=2.1527  K=37356  round=2.4s  total=356s
#
#   Round 151/200  (lr=0.00221)    [FEDS] K=28598  compress=88.6%  p_mean=0.500  Acc=0.3601  Loss=2.4850  TrainL=2.1449  K=28598  round=2.4s  total=358s
#
#   Round 152/200  (lr=0.00219)    [FEDS] K=28941  compress=88.5%  p_mean=0.500  Acc=0.3597  Loss=2.4860  TrainL=2.1425  K=28941  round=2.4s  total=361s
#
#   Round 153/200  (lr=0.00217)    [FEDS] K=30998  compress=87.7%  p_mean=0.500  Acc=0.3546  Loss=2.4900  TrainL=2.1373  K=30998  round=2.4s  total=363s
#
#   Round 154/200  (lr=0.00215)    [FEDS] K=25510  compress=89.8%  p_mean=0.500  Acc=0.3622  Loss=2.4817  TrainL=2.1389  K=25510  round=2.4s  total=365s
#
#   Round 155/200  (lr=0.00213)    [FEDS] K=32996  compress=86.9%  p_mean=0.500  Acc=0.3607  Loss=2.4758  TrainL=2.1371  K=32996  round=2.4s  total=368s
#
#   Round 156/200  (lr=0.00211)    [FEDS] K=40167  compress=84.0%  p_mean=0.500  Acc=0.3579  Loss=2.4843  TrainL=2.1374  K=40167  round=2.4s  total=370s
#
#   Round 157/200  (lr=0.00208)    [FEDS] K=41780  compress=83.4%  p_mean=0.500  Acc=0.3594  Loss=2.4765  TrainL=2.1388  K=41780  round=2.4s  total=373s
#
#   Round 158/200  (lr=0.00206)    [FEDS] K=30988  compress=87.7%  p_mean=0.500  Acc=0.3637  Loss=2.4731  TrainL=2.1315  K=30988  round=2.4s  total=375s
#
#   Round 159/200  (lr=0.00204)    [FEDS] K=29805  compress=88.1%  p_mean=0.500  Acc=0.3574  Loss=2.4782  TrainL=2.1299  K=29805  round=2.4s  total=377s
#
#   Round 160/200  (lr=0.00202)    [FEDS] K=33971  compress=86.5%  p_mean=0.500  Acc=0.3649  Loss=2.4674  TrainL=2.1308  K=33971  round=2.4s  total=380s
#
#   Round 161/200  (lr=0.00200)    [FEDS] K=32930  compress=86.9%  p_mean=0.500  Acc=0.3612  Loss=2.4761  TrainL=2.1265  K=32930  round=2.4s  total=382s
#
#   Round 162/200  (lr=0.00198)    [FEDS] K=24758  compress=90.1%  p_mean=0.500  Acc=0.3633  Loss=2.4708  TrainL=2.1256  K=24758  round=2.4s  total=384s
#
#   Round 163/200  (lr=0.00196)    [FEDS] K=41775  compress=83.4%  p_mean=0.500  Acc=0.3650  Loss=2.4604  TrainL=2.1209  K=41775  round=2.4s  total=387s
#
#   Round 164/200  (lr=0.00194)    [FEDS] K=31475  compress=87.5%  p_mean=0.500  Acc=0.3709  Loss=2.4486  TrainL=2.1181  K=31475  round=2.4s  total=389s
#
#   Round 165/200  (lr=0.00192)    [FEDS] K=25105  compress=90.0%  p_mean=0.500  Acc=0.3705  Loss=2.4494  TrainL=2.1151  K=25105  round=2.4s  total=392s
#
#   Round 166/200  (lr=0.00190)    [FEDS] K=35715  compress=85.8%  p_mean=0.500  Acc=0.3647  Loss=2.4570  TrainL=2.1165  K=35715  round=2.4s  total=394s
#
#   Round 167/200  (lr=0.00189)    [FEDS] K=38506  compress=84.7%  p_mean=0.500  Acc=0.3656  Loss=2.4554  TrainL=2.1148  K=38506  round=2.4s  total=396s
#
#   Round 168/200  (lr=0.00187)    [FEDS] K=30495  compress=87.9%  p_mean=0.500  Acc=0.3720  Loss=2.4446  TrainL=2.1115  K=30495  round=2.4s  total=399s
#
#   Round 169/200  (lr=0.00185)    [FEDS] K=41916  compress=83.3%  p_mean=0.500  Acc=0.3704  Loss=2.4435  TrainL=2.1109  K=41916  round=2.4s  total=401s
#
#   Round 170/200  (lr=0.00183)    [FEDS] K=42246  compress=83.2%  p_mean=0.500  Acc=0.3719  Loss=2.4384  TrainL=2.1087  K=42246  round=2.4s  total=403s
#
#   Round 171/200  (lr=0.00181)    [FEDS] K=42323  compress=83.1%  p_mean=0.500  Acc=0.3735  Loss=2.4409  TrainL=2.1065  K=42323  round=2.4s  total=406s
#
#   Round 172/200  (lr=0.00179)    [FEDS] K=23244  compress=90.7%  p_mean=0.500  Acc=0.3713  Loss=2.4419  TrainL=2.1019  K=23244  round=2.4s  total=408s
#
#   Round 173/200  (lr=0.00178)    [FEDS] K=38671  compress=84.6%  p_mean=0.500  Acc=0.3665  Loss=2.4473  TrainL=2.1004  K=38671  round=2.4s  total=411s
#
#   Round 174/200  (lr=0.00176)    [FEDS] K=31845  compress=87.3%  p_mean=0.500  Acc=0.3719  Loss=2.4376  TrainL=2.1032  K=31845  round=2.4s  total=413s
#
#   Round 175/200  (lr=0.00174)    [FEDS] K=42561  compress=83.1%  p_mean=0.500  Acc=0.3752  Loss=2.4266  TrainL=2.1009  K=42561  round=2.4s  total=415s
#
#   Round 176/200  (lr=0.00172)    [FEDS] K=22141  compress=91.2%  p_mean=0.500  Acc=0.3766  Loss=2.4220  TrainL=2.0920  K=22141  round=2.4s  total=418s
#
#   Round 177/200  (lr=0.00171)    [FEDS] K=36647  compress=85.4%  p_mean=0.500  Acc=0.3748  Loss=2.4336  TrainL=2.0924  K=36647  round=2.4s  total=420s
#
#   Round 178/200  (lr=0.00169)    [FEDS] K=28162  compress=88.8%  p_mean=0.500  Acc=0.3740  Loss=2.4271  TrainL=2.0939  K=28162  round=2.4s  total=422s
#
#   Round 179/200  (lr=0.00167)    [FEDS] K=32559  compress=87.0%  p_mean=0.500  Acc=0.3715  Loss=2.4276  TrainL=2.0927  K=32559  round=2.4s  total=425s
#
#   Round 180/200  (lr=0.00165)    [FEDS] K=27081  compress=89.2%  p_mean=0.500  Acc=0.3773  Loss=2.4166  TrainL=2.0904  K=27081  round=2.4s  total=427s
#
#   Round 181/200  (lr=0.00164)    [FEDS] K=32924  compress=86.9%  p_mean=0.500  Acc=0.3723  Loss=2.4248  TrainL=2.0856  K=32924  round=2.4s  total=430s
#
#   Round 182/200  (lr=0.00162)    [FEDS] K=36428  compress=85.5%  p_mean=0.500  Acc=0.3776  Loss=2.4148  TrainL=2.0842  K=36428  round=2.4s  total=432s
#
#   Round 183/200  (lr=0.00161)    [FEDS] K=27998  compress=88.9%  p_mean=0.500  Acc=0.3789  Loss=2.4106  TrainL=2.0907  K=27998  round=2.4s  total=434s
#
#   Round 184/200  (lr=0.00159)    [FEDS] K=29407  compress=88.3%  p_mean=0.500  Acc=0.3753  Loss=2.4248  TrainL=2.0840  K=29407  round=2.4s  total=437s
#
#   Round 185/200  (lr=0.00157)    [FEDS] K=37695  compress=85.0%  p_mean=0.500  Acc=0.3750  Loss=2.4224  TrainL=2.0843  K=37695  round=2.4s  total=439s
#
#   Round 186/200  (lr=0.00156)    [FEDS] K=49661  compress=80.2%  p_mean=0.500  Acc=0.3767  Loss=2.4146  TrainL=2.0880  K=49661  round=2.4s  total=441s
#
#   Round 187/200  (lr=0.00154)    [FEDS] K=42394  compress=83.1%  p_mean=0.500  Acc=0.3779  Loss=2.4098  TrainL=2.0822  K=42394  round=2.4s  total=444s
#
#   Round 188/200  (lr=0.00153)    [FEDS] K=28503  compress=88.7%  p_mean=0.500  Acc=0.3810  Loss=2.3997  TrainL=2.0770  K=28503  round=2.4s  total=446s
#
#   Round 189/200  (lr=0.00151)    [FEDS] K=19594  compress=92.2%  p_mean=0.500  Acc=0.3812  Loss=2.4015  TrainL=2.0782  K=19594  round=2.4s  total=449s
#
#   Round 190/200  (lr=0.00150)    [FEDS] K=30570  compress=87.8%  p_mean=0.500  Acc=0.3756  Loss=2.4063  TrainL=2.0748  K=30570  round=2.4s  total=451s
#
#   Round 191/200  (lr=0.00148)    [FEDS] K=31930  compress=87.3%  p_mean=0.500  Acc=0.3802  Loss=2.4078  TrainL=2.0788  K=31930  round=2.4s  total=453s
#
#   Round 192/200  (lr=0.00147)    [FEDS] K=21327  compress=91.5%  p_mean=0.500  Acc=0.3800  Loss=2.4023  TrainL=2.0757  K=21327  round=2.4s  total=456s
#
#   Round 193/200  (lr=0.00145)    [FEDS] K=30726  compress=87.8%  p_mean=0.500  Acc=0.3742  Loss=2.4130  TrainL=2.0726  K=30726  round=2.4s  total=458s
#
#   Round 194/200  (lr=0.00144)    [FEDS] K=33930  compress=86.5%  p_mean=0.500  Acc=0.3785  Loss=2.4046  TrainL=2.0760  K=33930  round=2.4s  total=460s
#
#   Round 195/200  (lr=0.00142)    [FEDS] K=45502  compress=81.9%  p_mean=0.500  Acc=0.3761  Loss=2.4123  TrainL=2.0756  K=45502  round=2.4s  total=463s
#
#   Round 196/200  (lr=0.00141)    [FEDS] K=31494  compress=87.5%  p_mean=0.500  Acc=0.3782  Loss=2.3964  TrainL=2.0737  K=31494  round=2.4s  total=465s
#
#   Round 197/200  (lr=0.00139)    [FEDS] K=34282  compress=86.4%  p_mean=0.500  Acc=0.3797  Loss=2.3945  TrainL=2.0672  K=34282  round=2.4s  total=467s
#
#   Round 198/200  (lr=0.00138)    [FEDS] K=40179  compress=84.0%  p_mean=0.500  Acc=0.3819  Loss=2.3937  TrainL=2.0685  K=40179  round=2.4s  total=470s
#
#   Round 199/200  (lr=0.00137)    [FEDS] K=27334  compress=89.1%  p_mean=0.500  Acc=0.3849  Loss=2.3824  TrainL=2.0663  K=27334  round=2.4s  total=472s
#
#   Round 200/200  (lr=0.00135)    [FEDS] K=34675  compress=86.2%  p_mean=0.500  Acc=0.3845  Loss=2.3891  TrainL=2.0637  K=34675  round=2.4s  total=475s
#
#   ✅ FEDS done — 7.9 min  | Final acc: 0.3845
#
# Summary:
# FedAvg           best=39.67% final=39.48% comm_save=N/A t=7.7m
# Fixed Top-K      best=35.59% final=35.59% comm_save=97.1% t=7.8m
# DSFL             best=28.10% final=27.65% comm_save=85.0% t=132.7m
# FEDS (Ours)      best=38.49% final=38.45% comm_save=85.0% t=7.9m

# %% [markdown]
# ## Cell 7 - Figures

# %%
import matplotlib, matplotlib.pyplot as plt
matplotlib.rcParams.update({
    "font.family":"serif","font.serif":["Times New Roman","DejaVu Serif"],
    "font.size":11,"axes.titlesize":12,"axes.labelsize":11,
    "xtick.labelsize":10,"ytick.labelsize":10,"legend.fontsize":10,
    "figure.dpi":150,"axes.grid":True,"grid.alpha":0.3,
    "grid.linestyle":"--","axes.spines.top":False,"axes.spines.right":False,
})
COLORS={"fedavg":"#2166ac","fixed_topk":"#d6604d","dsfl":"#f4a582","feds":"#1a9641"}
LABELS={"fedavg":"FedAvg","fixed_topk":"Fixed Top-K","dsfl":"DSFL","feds":"FEDS (Ours)"}
LS={"fedavg":":","fixed_topk":"-.","dsfl":"--","feds":"-"}
MK={"fedavg":"s","fixed_topk":"D","dsfl":"^","feds":"o"}
EV=max(1,NUM_ROUNDS//10)
W=EMA_SMOOTH

def ema_smooth(vals, window=10):
    alpha=2.0/(window+1); out=[vals[0]]
    for v in vals[1:]: out.append(alpha*v+(1-alpha)*out[-1])
    return out

def save_fig(name):
    for ext in ["pdf","png"]:
        plt.savefig(f"{RESULTS_DIR}/figures/{name}.{ext}",bbox_inches="tight",dpi=300 if ext=="png" else None)
    print(f"Saved {name}")

# Fig 1: Accuracy + Loss
fig,axes=plt.subplots(1,2,figsize=(10,3.5))
fig.suptitle(f"{DATASET} | Non-IID | {NUM_CLIENTS} clients | a={ALPHA_COMM} g={GAMMA_COMM}",fontsize=12,fontweight="bold")
for m,log in all_logs.items():
    r=log["round"]
    acc_raw=[a*100 for a in log["accuracy"]]
    loss_raw=log["loss"]
    acc_sm=ema_smooth(acc_raw,W); loss_sm=ema_smooth(loss_raw,W)
    axes[0].plot(r,acc_raw,color=COLORS[m],alpha=0.15,lw=0.8,ls=LS[m])
    axes[1].plot(r,loss_raw,color=COLORS[m],alpha=0.15,lw=0.8,ls=LS[m])
    kw=dict(color=COLORS[m],ls=LS[m],lw=2,label=LABELS[m],marker=MK[m],markevery=EV,ms=5)
    axes[0].plot(r,acc_sm,**kw); axes[1].plot(r,loss_sm,**kw)
axes[0].set(xlabel="Round",ylabel="Test Accuracy (%)",title="(a) Test Accuracy")
axes[0].legend(loc="lower right")
axes[1].set(xlabel="Round",ylabel="Test Loss",title="(b) Test Loss")
axes[1].legend(loc="upper right")
plt.tight_layout(); save_fig(f"fig1_acc_loss_{DATASET}"); plt.show()

# Fig 2: K trajectory
if "feds" in all_logs and "dsfl" in all_logs:
    fig,axes=plt.subplots(1,2,figsize=(10,3.5))
    fig.suptitle(f"FEDS vs DSFL K - {DATASET}",fontsize=12,fontweight="bold")
    r=all_logs["feds"]["round"]
    ka_raw=np.array(all_logs["feds"]["k_mean"])
    ks=np.array(all_logs["feds"]["k_std"])
    kd_raw=np.array(all_logs["dsfl"]["k_mean"])
    ka_sm=np.array(ema_smooth(ka_raw.tolist(),W))
    kd_sm=np.array(ema_smooth(kd_raw.tolist(),W))
    axes[0].plot(r,ka_raw,color=COLORS["feds"],alpha=0.15,lw=0.8)
    axes[0].plot(r,ka_sm,color=COLORS["feds"],lw=2,label="FEDS K")
    axes[0].fill_between(r,ka_sm-ks,ka_sm+ks,alpha=0.15,color=COLORS["feds"])
    axes[0].plot(r,kd_sm,color=COLORS["dsfl"],ls="--",lw=1.5,label="DSFL K")
    axes[0].axvline(COMP_WARMUP,color="gray",ls=":",lw=1,label="Warmup end")
    axes[0].set(xlabel="Round",ylabel="K",title="(a) K per round"); axes[0].legend(fontsize=9)
    sv=[(1-a/b)*100 if b>0 else 0 for a,b in zip(ka_raw,kd_raw)]
    sv_sm=ema_smooth(sv,W)
    axes[1].plot(r,sv,color=COLORS["feds"],alpha=0.15,lw=0.8)
    axes[1].plot(r,sv_sm,color=COLORS["feds"],lw=2)
    axes[1].axhline(0,color="gray",ls="--",lw=1)
    axes[1].fill_between(r,0,sv_sm,where=[s>0 for s in sv_sm],alpha=0.2,color=COLORS["feds"])
    axes[1].set(xlabel="Round",ylabel="Comm. Saving vs DSFL (%)",title="(b) Savings over DSFL")
    plt.tight_layout(); save_fig(f"fig2_k_{DATASET}"); plt.show()

# Fig 3: Convergence
fig,ax=plt.subplots(figsize=(5.5,3.5))
fig.suptitle(f"Rounds to Convergence - {DATASET}",fontsize=12,fontweight="bold")
max_acc=max(max(log["accuracy"]) for log in all_logs.values())
targets=[t for t in np.arange(0.1,max_acc,0.1) if t<max_acc]
for m,log in all_logs.items():
    acc_sm=ema_smooth(log["accuracy"],W); pts,seen=[],set()
    for tgt in targets:
        for ri,a in enumerate(acc_sm):
            if a>=tgt and tgt not in seen: pts.append((tgt*100,ri+1)); seen.add(tgt); break
    if pts:
        ts,rs=zip(*pts)
        ax.plot(ts,rs,color=COLORS[m],ls=LS[m],lw=2,marker=MK[m],ms=6,label=LABELS[m])
ax.set(xlabel="Target Accuracy (%)",ylabel="Rounds to reach target")
ax.legend(); plt.tight_layout(); save_fig(f"fig3_conv_{DATASET}"); plt.show()
print("All figures saved")
# Out:
# Saved fig1_acc_loss_CIFAR100
# Saved fig2_k_CIFAR100
# Saved fig3_conv_CIFAR100
# All figures saved

# %% [markdown]
# ## Cell 8 — 📋 Table (LaTeX + CSV)

# %%
import pandas as pd

LABELS = {'fedavg':'FedAvg','fixed_topk':'Fixed Top-K',
          'dsfl':'DSFL','feds':'FEDS (Ours)'}
d = next(iter(all_logs.values()))['total_params']
rows = []
for m, log in all_logs.items():
    acc = np.array(log['accuracy'])
    km  = np.array(log['k_mean'])
    rows.append({
        'Method'        : LABELS[m],
        'Best Acc (%)'  : f'{acc.max()*100:.2f}',
        'Best Round'    : int(np.argmax(acc))+1,
        'Final Acc (%)' : f'{acc[-1]*100:.2f}',
        'Final Loss'    : f'{log["loss"][-1]:.4f}',
        'Avg K'         : f'{km.mean():.0f}' if m!='fedavg' else 'N/A',
        'Comm. Saving'  : f'{(1-km.mean()/d)*100:.1f}%' if m!='fedavg' else 'N/A',
        'Time (min)'    : f'{log["total_time"]/60:.1f}',
    })

df = pd.DataFrame(rows)
print(df.to_string(index=False))
df.to_csv(f'{RESULTS_DIR}/tables/results_{DATASET}.csv', index=False)

latex = df.to_latex(
    index=False, escape=False,
    caption=f'{DATASET} (Non-IID, {NUM_CLIENTS} clients, {NUM_ROUNDS} rounds, '
            f'α={ALPHA_COMM}, γ={GAMMA_COMM}).',
    label=f'tab:{DATASET.lower()}',
    column_format='l' + 'c'*(len(df.columns)-1)
).replace('FEDS (Ours)', '\\textbf{FEDS (Ours)}')

with open(f'{RESULTS_DIR}/tables/results_{DATASET}.tex', 'w') as f:
    f.write(latex)
print('\n── LaTeX ─────────────────────────────────────────────────')
print(latex)
# Out:
#      Method Best Acc (%)  Best Round Final Acc (%) Final Loss Avg K Comm. Saving Time (min)
#      FedAvg        39.67         197         39.48     2.3401   N/A          N/A        7.7
# Fixed Top-K        35.59         200         35.59     2.5066  7206        97.1%        7.8
#        DSFL        28.10         190         27.65     2.8712 37732        85.0%      132.7
# FEDS (Ours)        38.49         199         38.45     2.3891 37580        85.0%        7.9
#
# ── LaTeX ─────────────────────────────────────────────────
# \begin{table}
# \caption{CIFAR100 (Non-IID, 10 clients, 200 rounds, α=10, γ=10).}
# \label{tab:cifar100}
# \begin{tabular}{lccccccc}
# \toprule
# Method & Best Acc (%) & Best Round & Final Acc (%) & Final Loss & Avg K & Comm. Saving & Time (min) \\
# \midrule
# FedAvg & 39.67 & 197 & 39.48 & 2.3401 & N/A & N/A & 7.7 \\
# Fixed Top-K & 35.59 & 200 & 35.59 & 2.5066 & 7206 & 97.1% & 7.8 \\
# DSFL & 28.10 & 190 & 27.65 & 2.8712 & 37732 & 85.0% & 132.7 \\
# \textbf{FEDS (Ours)} & 38.49 & 199 & 38.45 & 2.3891 & 37580 & 85.0% & 7.9 \\
# \bottomrule
# \end{tabular}
# \end{table}
